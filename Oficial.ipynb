# %% [markdown]
# # **OBTENDO OS DADOS**

# %% [markdown]
# ## Configuração

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"


# Common imports
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# ## Obtendo os dados

# %%
import os
import requests
import zipfile
import pandas as pd

url = "https://www.kaggle.com/api/v1/datasets/download/joebeachcapital/30000-spotify-songs"
zip_path = "spotify_songs.zip"
extract_path = "./datasets"
#create dataframe songs:


# Faz o download do arquivo zip
response = requests.get(url)
with open(zip_path, "wb") as file:
    file.write(response.content)
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

# %% [markdown]
# ## Conferindo rapidamente o dataset

# %%
csv_path = os.path.join(extract_path, "spotify_songs.csv")
songs = pd.read_csv(csv_path)
print(songs.head())
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
pd.set_option('display.max_rows', None)
songs["playlist_genre"].value_counts()
# Out:
# playlist_genre
# edm      6043
# rap      5746
# pop      5507
# r&b      5431
# latin    5155
# rock     4951
# Name: count, dtype: int64

# %% [markdown]
# # **PREPARANDO OS DADOS**

# %% [markdown]
# ##Definição das **Funções para tratamento dos dados**.

# %%
# REMOÇÃO DE DUPLICATAS - remove músicas repetidas

def removeDuplicates(df):
    # Adiciona uma coluna auxiliar com o nome da música em lowercase
    df['track_name_lower'] = df['track_name'].str.lower()
    # Remove duplicadas usando a coluna auxiliar
    df_unique = df.drop_duplicates(subset=['track_artist', 'track_name_lower'])
    # Remove a coluna auxiliar antes de retornar
    df_unique = df_unique.drop(columns=['track_name_lower'])
    return df_unique

# %%
# ONEHOT DE ARTITAS MAIS RELEVANTES - Já que o dataset possue uma quantidade consideravel de artistas, faz o Onehot apenas dos artistas mais populares.

def onehotTopArtists(df, n, alpha=5):
    # Verifica se as colunas necessárias existem no DataFrame
    if 'track_artist' not in df.columns or 'track_popularity' not in df.columns:
        raise ValueError("O dataset deve conter as colunas 'track_artist' e 'track_popularity'.")
    # Calcula a popularidade total por artista
    artist_total_popularity = df.groupby('track_artist')['track_popularity'].sum()
    # Conta o número de músicas por artista
    artist_song_count = df.groupby('track_artist').size()
    # Ajuste da popularidade considerando o número de músicas com o parâmetro de suavização alpha
    artist_adjusted_popularity = artist_total_popularity / (artist_song_count + alpha)
    # Seleciona os `n` artistas mais populares com a popularidade ajustada
    top_artists = artist_adjusted_popularity.sort_values(ascending=False).head(n).index.tolist()
    print("Top artistas:", top_artists)  # Verifique os artistas mais populares
    # Cria colunas one-hot para esses `n` artistas mais populares
    for artist in top_artists:
        df[f"artist_{artist}"] = (df['track_artist'] == artist).astype(int)
    return df

# %%
# REMOÇÃO DE COLUNAS - Remove colunas não úteis para a predição.

def removeColumns(df, columns_name):
    return df.drop(columns=columns_name)

# %%
# REMOÇÃO DE LINHAS - Remove linhas que possuem dados em branco e que não podem ser obtidos por meio de outros dados.

#Utilizar depois de remover as colunas que não serão necessárias para a predição do modelo.
def removeRowNaN(songs_cp):
    songs_cp_sem_nulos = songs_cp.dropna(axis=0, how='any')
    return songs_cp_sem_nulos

def dropRowsEmpty(songs_cp):
    songs_cp_sem_nulos = removeRowNaN(songs_cp)
    valores_nulos_por_coluna = songs_cp_sem_nulos.isna().sum()
    songs_cp = songs_cp_sem_nulos
    return songs_cp

# %%
# NORMALIZAÇÃO DE DADOS NUMÉRICOS

#Normaliza os dados numa escala de 0 a 1.
def normalizeColumns(df,columns_name):
    scaler = MinMaxScaler()
    df[columns_name] = scaler.fit_transform(df[columns_name])
    return df

# %%
# ONEHOT para as variáveis categóricas que possuem um número pequeno de categorias.

def onehotEncode(df, columns):
    pd.get_dummies(df, columns=columns, prefix=columns)

# %%
# PREENCHE MẼS DE LANÇAMENTO DAS MÚSICAS QUE NÃO POSSUEM ESSE DADO.

def fillMonths(songs: pd.DataFrame) -> pd.DataFrame:
    # Criar uma cópia do DataFrame para evitar modificar o original
    df = songs.copy()

    # Filtrar as linhas onde a data de lançamento tem apenas o ano (4 caracteres)
    df_ano_apenas = df[df['track_album_release_date'].str.len() == 4].copy()

    # Filtrar as linhas onde a data de lançamento tem o formato completo (ano-mês-dia)
    df_completo = df[df['track_album_release_date'].str.len() == 10].copy()

    # Extrair o mês das músicas com ano-mês-dia
    df_completo['month'] = df_completo['track_album_release_date'].str[5:7]

    # Contar a frequência de cada mês
    month_counts = df_completo['month'].value_counts()

    # Agora vamos preencher os meses nas músicas com ano apenas, de forma proporcional
    # Criação de uma lista que vai armazenar os meses a serem atribuídos
    months_to_fill = []

    # Para cada mês na distribuição, vamos adicionar o mês de forma proporcional
    for month, count in month_counts.items():
        months_to_fill.extend([month] * count)

    # Para as músicas faltando mês, vamos preencher com base na lista 'months_to_fill'
    df_ano_apenas['month'] = np.random.choice(months_to_fill, size=len(df_ano_apenas))

    # Agora vamos juntar os dois DataFrames (completo e preenchido) novamente
    # Garantindo que estamos mantendo todas as colunas, não apenas 'track_album_release_date'
    df_completo['month'] = df_completo['month']  # As músicas já completas não devem ser modificadas
    df_ano_apenas['track_album_release_date'] = df_ano_apenas['track_album_release_date'] + '-' + df_ano_apenas['month'] + '-01'

    # Substituir as linhas no DataFrame copiado
    df.update(df_completo)  # Atualiza as músicas completas
    df.update(df_ano_apenas)  # Atualiza as músicas com ano apenas

    # Retornar o DataFrame alterado
    return df

# %%
# DECOMPÕE A COLUNA 'track_album_release_date' EM 'track_year' E 'track_month'.

def decompositionDateTransform(df, date_column):
    # Como o ano é composto de 4 dígitos, iremos extrair os 4 primeiros caracteres da coluna
    def get_year(date):
        if isinstance(date, str) and len(date) >= 4 and date[:4].isdigit():
            return int(date[:4])
        return None

    # Depois dos 4 caracteres teremos um '-' que faz a divisão do ano e mês, iremos fazer
    # split e pegaremos os dois próximos dígitos
    def get_month(date):
        if isinstance(date, str) and len(date) >= 7:
            parts = date.split('-')
            if len(parts) > 1 and parts[1].isdigit():
                return f"{int(parts[1]):02d}"  # Garantir dois dígitos no mês
        return None

    # Agora adicionamos as novas colunas
    df['track_year'] = df[date_column].apply(get_year)
    df['track_month'] = df[date_column].apply(get_month)
    return df

# %%
# DECOMPÕE 'duration_ms' EM 'track_minutes' E 'track_seconds'.

def MilisecondsTransform(df, millis_column):
    def get_minutes(millis):
        if isinstance(millis, (int, float)) and millis >= 0:
            return millis // 60000
        return None

    def get_seconds(millis):
        if isinstance(millis, (int, float)) and millis >= 0:
            return (millis % 60000) // 1000
        return None

    df['track_minutes'] = df[millis_column].apply(get_minutes)
    df['track_seconds'] = df[millis_column].apply(get_seconds)
    return df

# %%
# CLASSIFICA A COLUNA 'duration_ms' EM 0,1,2,3,4,5 e 6, NA COLUNA 'track_duration_classification'

def classifyDuration(df, millis_column):
    def classify(millis):
        if isinstance(millis, (int, float)) and millis >= 0:
            duration_minutes = millis / 60000
            if duration_minutes == 0:
                return 0
            elif duration_minutes <= 1:
                return 1
            elif duration_minutes <= 2:
                return 2
            elif duration_minutes <= 3:
                return 3
            elif duration_minutes <= 4:
                return 4
            elif duration_minutes <= 5:
                return 5
            else:
                return 6
        return None

    df['track_duration_classification'] = df[millis_column].apply(classify)
    return df

# %%
# RETORNA OS DADOS DISCRETIZADOS E POSSÍVEIS OUTLIERS

def discretizeAndPossibleOutliers(data, n_bins=10, metodo='quantis'):
    if metodo == 'quantis':
        # Discretização baseada em quantis (divide os dados em n_bins intervalos com número igual de dados)
        bins = np.percentile(data, np.linspace(0, 100, n_bins+1))
        labels = [f'Intervalo {i+1}' for i in range(n_bins)]
        data_discretizada = pd.cut(data, bins=bins, labels=labels, include_lowest=True)
    elif metodo == 'igual':
        # Discretização por intervalos iguais (divide os dados em n_bins intervalos de tamanho igual)
        bins = np.linspace(data.min(), data.max(), n_bins+1)
        labels = [f'Intervalo {i+1}' for i in range(n_bins)]
        data_discretizada = pd.cut(data, bins=bins, labels=labels, include_lowest=True)
    else:
        raise ValueError("ERROR: 'quantis' ou 'igual'.")

    # Visualizar os dados discretizados
    sns.histplot(data_discretizada, kde=False, discrete=True, color='skyblue')
    plt.title('Distribuição dos Dados Discretizados')
    plt.xlabel('I')
    plt.ylabel('C')
    plt.show()

    # Identificar outliers (valores fora de 1.5 vezes o intervalo interquartil)
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1
    outliers = data[(data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))]

    return data_discretizada, outliers

# %%
# ONEHOT do gênero das músicas


def oneHotGenre(df):

  # Aplicar One-Hot Encoding e modificar os nomes das colunas
  one_hot = pd.get_dummies(df['playlist_genre'], prefix='track_genre')

  # Garantir que os valores sejam inteiros (0 ou 1)
  one_hot = one_hot.astype(int)

  # Concatenar o resultado no DataFrame original e remover a coluna original
  df = pd.concat([df, one_hot], axis=1).drop(columns=['playlist_genre'])

  return df

# %%
# TARGET ENCODING -> Utilizada apenas no conjunto de TREINO

def encode_artist_weighted_popularity(df):

    # Conta quantas músicas cada artista tem no dataset
    artist_track_counts = df['track_artist'].value_counts()

    # Calcula a média ponderada de popularidade de cada artista
    artist_weighted_popularity = df.groupby('track_artist').apply(
        lambda x: (x['track_popularity'] * (1 / artist_track_counts[x.name])).sum()
    )

    # Cria uma nova coluna com essa média ponderada
    df['artist_weighted_popularity'] = df['track_artist'].map(artist_weighted_popularity)

    # Remove a coluna original
    df.drop(columns=['track_artist'], inplace=True)

    return df

# %%
# CALCULA A POPULARIDADE DE CADA ARTISTA E RETORNA UM DF COM APENAS DUAS FEATURES: 'track_artist' E 'artist_weighted_popularity'.

def calculate_artist_weighted_popularity(df):
    # Conta quantas músicas cada artista tem no dataset
    artist_track_counts = df['track_artist'].value_counts()

    # Calcula a média ponderada de popularidade de cada artista
    artist_weighted_popularity = df.groupby('track_artist').apply(
        lambda x: (x['track_popularity'] * (1 / artist_track_counts[x.name])).sum()
    ).reset_index()

    # Renomeia as colunas para melhor entendimento
    artist_weighted_popularity.columns = ['track_artist', 'artist_weighted_popularity']

    return artist_weighted_popularity

# %%
def assign_artist_popularity(df_train, df_test):
    """
    Atribui a popularidade já calculada dos artistas no conjunto de teste,
    garantindo que cada artista receba o mesmo valor do conjunto de treino.
    Se o artista não for encontrado, preenche com a média dos artistas conhecidos.

    Parâmetros:
    df_train (pd.DataFrame): DataFrame contendo 'track_artist' e 'artist_weighted_popularity'.
    df_test (pd.DataFrame): DataFrame contendo 'track_artist' e 'artist_weighted_popularity'.

    Retorno:
    pd.DataFrame: df_test atualizado com os valores corretos de 'artist_weighted_popularity'.
    """
    # Cria um dicionário mapeando artista -> popularidade já calculada
    artist_popularity_dict = df_train.set_index('track_artist')['artist_weighted_popularity'].to_dict()

    # Calcula a média global da popularidade dos artistas conhecidos
    mean_popularity = df_train['artist_weighted_popularity'].mean()

    # Atribui a popularidade ao df_test
    df_test = df_test.copy()
    df_test['artist_weighted_popularity'] = df_test['track_artist'].map(artist_popularity_dict)

    # Preenche valores ausentes com a média global
    df_test['artist_weighted_popularity'] = df_test['artist_weighted_popularity'].fillna(mean_popularity)

    # Remove a coluna track_artist
    df_test.drop(columns=['track_artist'], inplace=True)

    return df_test

# %%
def move_feature_to_last(df, feature_name='artist_weighted_popularity'):
    """
    Move a coluna especificada para a última posição do DataFrame.

    Parâmetros:
    df (pd.DataFrame): O DataFrame em que a coluna será movida.
    feature_name (str): O nome da coluna que será movida para a última posição (padrão 'artist_weighted_popularity').

    Retorno:
    pd.DataFrame: DataFrame com a coluna movida para a última posição.
    """
    # Verifica se a coluna existe no DataFrame
    if feature_name in df.columns:
        # Cria uma lista com as colunas, removendo a coluna que vai para a última posição
        columns = [col for col in df.columns if col != feature_name]
        # Adiciona a coluna desejada na última posição
        columns.append(feature_name)
        # Reorganiza o DataFrame com as colunas na nova ordem
        df = df[columns]
    else:
        print(f"A coluna '{feature_name}' não existe no DataFrame.")

    return df

# %% [markdown]
# ##Definição das **Funções de apoio**.

# %%
# Mostra nível de popularidade por gênero

def popularityPerGenre(songs):
    # Agrupar por 'playlist_genre' e calcular a média da popularidade
    genre_popularity = songs.groupby("playlist_genre")["track_popularity"].mean()
    # Ordenar os resultados em ordem decrescente
    genre_popularity_sorted = genre_popularity.sort_values(ascending=False)
    # Exibir os gêneros com músicas mais populares
    print(genre_popularity_sorted)

# %%
# Retorna todos os artistas e suas respectivas popularidade

def getArtistsAndPopularity(df, alpha=5):
    # Verifica se as colunas necessárias existem no DataFrame
    if 'track_artist' not in df.columns or 'track_popularity' not in df.columns:
        raise ValueError("O dataset deve conter as colunas 'track_artist' e 'track_popularity'.")
    # Calcula a popularidade total por artista
    artist_total_popularity = df.groupby('track_artist')['track_popularity'].sum()
    # Conta o número de músicas por artista
    artist_song_count = df.groupby('track_artist').size()
    # Calcula a popularidade ponderada para cada artista
    artist_weighted_popularity = artist_total_popularity / (artist_song_count + alpha)
    # Ordena os artistas pela popularidade ponderada em ordem decrescente
    artist_weighted_popularity_sorted = artist_weighted_popularity.sort_values(ascending=False)
    # Retorna o DataFrame com o nome do artista e sua popularidade
    return artist_weighted_popularity_sorted.reset_index()

# %%
# Retorna as n musicas mais populares do dataset
def getTopSongs(df,n):
  return df[['track_name', 'track_popularity']].sort_values(by='track_popularity', ascending=False).head(n)

# %%
# Mostra nível de popularidade por gênero

def popularityPerGenre(songs):
    # Agrupar por 'playlist_genre' e calcular a média da popularidade
    genre_popularity = songs.groupby("playlist_genre")["track_popularity"].mean()
    # Ordenar os resultados em ordem decrescente
    genre_popularity_sorted = genre_popularity.sort_values(ascending=False)
    # Exibir os gêneros com músicas mais populares
    print(genre_popularity_sorted)

# %% [markdown]
# # **PRÉ-PROCESSAMENTO**

# %% [markdown]
# ## Subfunções

# %%
# Limpeza
def data_cleaning(df):
  #Removendo dados duplicados
  df = removeDuplicates(df)

  #Removendo linhas que possuem dados em branco e que não podem ser obtidos de forma ideal
  df = dropRowsEmpty(df)

  return df

# %%
# Seleção de Características
def feature_selection(df):
  # Dropando colunas que representam id
  df = removeColumns(df,['track_id','track_album_id','playlist_id'])

  # Dropando colunas de nomes que não irão agregar na predição do modelo
  df = removeColumns(df,['track_name','track_album_name','playlist_name', 'playlist_subgenre'])

  return df

# %%
# Engenharia de Atributos
def feature_engeneering(df, value):
  # Decompõe a coluna 'track_album_release_date' em 'track_year' e 'track_month'
  df = decompositionDateTransform(df,'track_album_release_date')

  # Transforma a coluna 'duration_ms' em 'track_minutes' e 'track_seconds'
  df = MilisecondsTransform(df,'duration_ms')

  # Categoriza as musicas por 'duration_ms' e cria a coluna 'track_duration_classification':
  df = classifyDuration(df,'duration_ms')

  # Realiza oneHot para o gênero das músicas
  df = oneHotGenre(df)

  if(value):
    df = encode_artist_weighted_popularity(df)

  return df

# %%
# Normalização dos dados
def data_normalize(df, value):
  # Colocando colunas na mesma escala (normalização)
  normalizeColumns(df,['track_popularity','danceability','energy','key','loudness','mode','speechiness',
                       'acousticness','instrumentalness','liveness','valence','tempo','track_minutes',
                       'track_seconds','track_year','track_month', 'track_duration_classification','artist_weighted_popularity'])

  if(value):
    normalizeColumns(df,['artist_weighted_popularity'])

  # Já que foram aplicadas transformações em 'track_album_release_date' e 'duration_ms' iremos remover essas colunas pois não serão mais necessárias
  df = removeColumns(df,['track_album_release_date','duration_ms', 'track_month'])

  return df

# %% [markdown]
# ## Função Principal de pré-processamento dos dados

# %%
#Função principal de pré processamento dos dados
def pipeline_pre_process(df, conjunto):
  if(conjunto == 'general'):
    df = data_cleaning(df)
  elif(conjunto == 'train'):
    df = feature_selection(df)
    df = feature_engeneering(df, True)
    df = data_normalize(df, True)
  elif(conjunto == 'test' or conjunto == 'validation'):
    df = feature_selection(df)
    df = feature_engeneering(df, False)
    df = data_normalize(df, False)
  else:
    raise ValueError("ERROR: 'train', 'test' ou 'validation'.")

  return df

# %% [markdown]
# ## Criando conjuntos de TESTE, TREINO e VALIDAÇÃO.

# %%
#to make this notebook's output identical at every run
np.random.seed(42)

# Aplicando apenas LIMPEZA nos dados gerais, antes de dividir
songs = pipeline_pre_process(songs, 'general')

# 70% treino, 30% temporário (dividido em validação e teste)
train_set, temp_set = train_test_split(songs, test_size=0.3, random_state=42)

# 50% de 30% para validação e 50% para teste (ou seja, 15% validação e 15% teste)
validation_set, test_set = train_test_split(temp_set, test_size=0.5, random_state=42)

# Verificando os tamanhos dos conjuntos
print(f"Tamanho do conjunto de treino: {len(train_set)}")
print(f"Tamanho do conjunto de validação: {len(validation_set)}")
print(f"Tamanho do conjunto de teste: {len(test_set)}")
# Out:
# Tamanho do conjunto de treino: 18312
# Tamanho do conjunto de validação: 3924
# Tamanho do conjunto de teste: 3924

# %% [markdown]
# ## Criando uma cópia dos dados para exploração.

# %%
# Cópia do conjunto de treino
train_set_cp = train_set.copy()

# Cópia do conjunto de validação
validation_set_cp = validation_set.copy()

# Cópia do conjunto de teste
test_set_cp = test_set.copy()

# %% [markdown]
# ## Aplicando pré-processamento nos conjuntos de TREINO, VALIDAÇÃO e TESTE.

# %%
# Nessa etapa iremos fazer o pré-processamento individualmente em cada conjunto para evitar DATA LEAKAGE (vazamento de dados)

df_popularity_artist = calculate_artist_weighted_popularity(train_set_cp)

# CONJUNTO DE TREINO
train_set_cp = pipeline_pre_process(train_set_cp, 'train')

# CONJUNTO DE VALIDAÇÃO
validation_set_cp = assign_artist_popularity(df_popularity_artist, validation_set_cp)
validation_set_cp = pipeline_pre_process(validation_set_cp, 'validation')

# CONJUNTO DE TESTE
test_set_cp = assign_artist_popularity(df_popularity_artist, test_set_cp)
test_set_cp = pipeline_pre_process(test_set_cp, 'test')

train_set_cp = move_feature_to_last(train_set_cp, feature_name='artist_weighted_popularity')
validation_set_cp = move_feature_to_last(validation_set_cp, feature_name='artist_weighted_popularity')
test_set_cp = move_feature_to_last(test_set_cp, feature_name='artist_weighted_popularity')
# Out:
# <ipython-input-573-3c0f6279aaad>:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   artist_weighted_popularity = df.groupby('track_artist').apply(
# <ipython-input-572-b3a891fca7f8>:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   artist_weighted_popularity = df.groupby('track_artist').apply(

# %% [markdown]
# # **TREINO E AVALIAÇÃO DOS MODELOS**

# %% [markdown]
# ## Bibliotecas utilizadas

# %%
# Importações necessárias
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.datasets import make_regression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

import seaborn as sns

import numpy as np
import matplotlib.pyplot as plt

# Lightgbm
import lightgbm as lgb

# Ridge
from sklearn.linear_model import Ridge

# CatBoost
# !pip install catboost
from catboost import CatBoostRegressor

# Linear Regression
from sklearn.linear_model import LinearRegression

#SVM
from sklearn.svm import SVR
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)

# %% [markdown]
# ## Funções de apoio

# %%
# (SUBFUNÇÃO) - SEPARA AS FEATURES E O ATRIBUTO ALVO

def split_target_features(df):

  # X_feat: variáveis independentes
  X_feat = df.drop(columns=['track_popularity'])

  # y_feat: target
  y_feat = df['track_popularity']

  return X_feat, y_feat

# %%
# (FUNÇÃO GERAL) - TREINA O MODELO

def train_model(df, model_name, params):

  X_train, y_train = split_target_features(df)

  if model_name == 'lightgbm':
    model = lgb.LGBMRegressor(**params)
  elif model_name == 'ridge':
    model = Ridge(**params)
  elif model_name == 'linear_regression':
    model = LinearRegression(**params)
  elif model_name == 'svm':
    model = SVR(**params)
  elif model_name == 'catboost':
    model = CatBoostRegressor(**params)
  else:
    raise ValueError("Modelo não suportado. Escolha entre 'lightgbm' ou 'ridge'.")

  # Treinar o modelo
  model.fit(X_train, y_train)

  # Retornar o modelo treinado
  return model

# %%
# (FUNÇÃO GERAL) - AVALIA E RETORNA A PERFORMANCE DO MODELO

def evaluate_model_performance(df, model):

  X_test, y_test = split_target_features(df)
  y_pred = model.predict(X_test)

  # MAE
  mae = mean_absolute_error(y_test, y_pred)

  # MSE
  mse = mean_squared_error(y_test, y_pred)

  # RMSE
  rmse = np.sqrt(mse)

  # R²
  r2 = r2_score(y_test, y_pred)

  # Exibindo os resultados
  print(f"MAE: {mae}")
  print(f"MSE: {mse}")
  print(f"RMSE: {rmse}")
  print(f"R²: {r2}")
  print("Predições do modelo: ")
  print(y_pred)

# %%
# (FUNÇÃO GERAL) - EXIBE O GRÁFICO DE VALORES REAIS X VALORES PREVISTOS

def plot_predictions(df, model, ax=None):
    X, y_true = split_target_features(df)
    y_pred = model.predict(X)

    if ax is None:
        fig, ax = plt.subplots()  # Cria um novo gráfico se nenhum eixo for passado

    ax.scatter(y_true, y_pred, alpha=0.5)
    ax.set_xlabel("Valores Reais")
    ax.set_ylabel("Valores Preditos")
    ax.set_title("Popularidade das Músicas")
    ax.set_title(f'Predições do {type(model).__name__}')

# %%
# (FUNÇÃO GERAL) - FAZ A VALIDAÇÃO CRUZADA COM 10 FOLDS

def cross_validation(df, model):

    X, y = split_target_features(df)

    scores = cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv=10)

    # Calcule o RMSE após a validação cruzada
    rmse_scores = np.sqrt(-scores)  # Convertendo de MSE negativo para RMSE

    print("Scores:", rmse_scores)  # Exibindo os scores (RMSE)
    print("Mean:", rmse_scores.mean())  # Média dos RMSEs
    print("Standard deviation:", rmse_scores.std())  # Desvio padrão dos RMSEs

# %%
# (SUBFUNÇÃO) - CALCULA IMPORTÂNCIA DAS VARIÁVEIS (LIGHTGBM)

def feature_importance_lightgbm(df, model):
    # Acessando a importância das características
    importances = model.booster_.feature_importance()

    # Verificando se o número de features no DataFrame é o mesmo que o número de importâncias
    feature_names = model.booster_.feature_name()

    if len(feature_names) != len(importances):
        print("Aviso: O número de features no DataFrame não corresponde ao número de importâncias.")
        return

    # Normalizando as importâncias para a escala de 0-1
    max_importance = max(importances)  # Encontrando o valor máximo de importância
    normalized_importances = [x / max_importance for x in importances]  # Normalizando

    # Criando um DataFrame com as features e suas importâncias normalizadas
    feature_importance = pd.DataFrame({
        'Feature': feature_names,  # As features do modelo
        'Importance': normalized_importances  # Importância normalizada
    })

    # Ordenando da mais importante para a menos importante
    feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

    return feature_importance

# %%
# (SUBFUNÇÃO) - CALCULA IMPORTÂNCIA DAS VARIÁVEIS (XGB)

def feature_importance_xgb(df, model):
    # Acessando a importância das características
    importances = model.feature_importances_

    # Garantindo que as features utilizadas no modelo sejam as mesmas do DataFrame
    feature_names = df.columns[:len(importances)]  # Pegando as primeiras colunas conforme o número de importâncias

    if len(feature_names) != len(importances):
        print(f"Aviso: O número de features no DataFrame ({len(feature_names)}) não corresponde ao número de importâncias ({len(importances)}).")
        return

    # Normalizando as importâncias para a escala de 0-1
    max_importance = max(importances)  # Encontrando o valor máximo de importância
    normalized_importances = [x / max_importance for x in importances]  # Normalizando

    # Criando um DataFrame com as features e suas importâncias normalizadas
    feature_importance = pd.DataFrame({
        'Feature': feature_names,  # As features do modelo
        'Importance': normalized_importances  # Importância normalizada
    })

    # Ordenando da mais importante para a menos importante
    feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

    return feature_importance

# %%
# Importância das variáveis - Linear Regression
def feature_importance_linear(df, model):
    X, _ = split_target_features(df)
    importance = np.abs(model.coef_)  # Coeficientes da regressão linear

    feature_importance = pd.DataFrame({
        'Feature': X.columns,
        'Importance': importance
    }).sort_values(by='Importance', ascending=False)

    return feature_importance

# %%
def feature_importance_svm(df, model):
    import shap

    X_train, _ = split_target_features(df) # Define X_train within the function
    # Criar um objeto SHAP para explicar o modelo usando model.predict
    explainer = shap.Explainer(model.predict, X_train)
    shap_values = explainer(X_train)

    # Criar dataframe com importâncias
    importance_df = pd.DataFrame({
        'Feature': X_train.columns,
        'Importance': np.abs(shap_values.values).mean(axis=0)
    }).sort_values(by='Importance', ascending=False)

    print(importance_df.head(20))  # Exibir as 20 mais importantes

# %%
# (SUBFUNÇÃO) - CALCULA IMPORTÂNCIA DAS VARIÁVEIS (RIDGE)

def feature_importance_ridge(df, model):
    X, y = split_target_features(df)
    # Obtendo a importância das variáveis
    importance = np.abs(model.coef_)  # Pegamos o valor absoluto dos coeficientes

    # Criando um DataFrame para visualizar melhor
    feature_importance = pd.DataFrame({
        'Feature': X.columns,
        'Importance': importance})

    # Ordenando da mais importante para a menos importante
    feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

    return feature_importance

# %%
# (FUNÇÃO GERAL) - CALCULA IMPORTÂNCIA DAS VARIÁVEIS

def feature_importance(df, model):
    if (model == LightGBM_model):
      return feature_importance_lightgbm(df, model)
    elif (model == Ridge_model):
      return feature_importance_ridge(df, model)
    elif (model == LinearRegression_model):
      return feature_importance_linear(df, model)
    elif (model == SVM_model):
      return feature_importance_svm(df, model)
    else:
      print("Modelo não suportado. Escolha entre'lightgbm' ou 'ridge'.")

# %%
# (FUNÇÃO GERAL) - EXIBE GRÁFICO DE DISTRIBUIÇÃO -> VALORES REAIS X VALORES PREVISTOS

def plot_distribution(df, model, ax=None):
    X_true, y_true = split_target_features(df)
    y_pred = model.predict(X_true)

    if ax is None:
        fig, ax = plt.subplots(figsize=(10, 6))  # Cria um novo gráfico se nenhum eixo for passado

    # Plotando os valores reais
    ax.hist(y_true, bins=50, alpha=0.5, label="Valores reais", color='blue', edgecolor='black', log=True)

    # Plotando as predições
    ax.hist(y_pred, bins=50, alpha=0.5, label="Predições", color='orange', edgecolor='black', log=True)

    ax.set_xlabel("Valores")
    ax.set_ylabel("Frequência")
    ax.set_title(f"Distribuição das predições e valores reais: {type(model).__name__}")
    ax.legend(loc="best")

# %%
# (FUNÇÃO GERAL) - EXIBE GRÁFICO DE ERROS

def plot_error(df, model, ax=None):
    X_true, y_true = split_target_features(df)
    y_pred = model.predict(X_true)
    erros = np.array(y_true) - np.array(y_pred)

    # Se 'ax' não for passado, cria um novo eixo
    if ax is None:
        fig, ax = plt.subplots(figsize=(10, 5))  # Define o tamanho do gráfico

    # Plotando o histograma dos erros
    sns.histplot(erros, bins=30, kde=True, ax=ax)  # Agora o gráfico será exibido no eixo 'ax'

    ax.set_xlabel("Erro Residual")  # Nome do eixo X
    ax.set_ylabel("Frequência")  # Nome do eixo Y
    ax.set_title(f"Distribuição dos Erros do Modelo: {type(model).__name__}")  # Título do gráfico

# %% [markdown]
# ## **Modelo: LightGBM**

# %% [markdown]
# ### Treino:

# %%
# Evitar mensagens desnecessárias
params = {'verbose': -1}

# Treinando modelo com conjunto de treino
LightGBM_model = train_model(train_set_cp, 'lightgbm', params)

# %% [markdown]
# ### Avaliação:

# %%
# SEM VALIDAÇÃO CRUZADA -> Usando o conjunto de validação
evaluate_model_performance(validation_set_cp, LightGBM_model)
# Out:
# MAE: 0.1650787850375029
# MSE: 0.0485792771516011
# RMSE: 0.22040707146459956
# R²: 0.1520332573078742
# Predições do modelo:
# [0.38737303 0.77356404 0.4203525  ... 0.42721158 0.56690908 0.6957234 ]

# %%
# COM VALIDAÇÃO CRUZADA -> Usando o conjunto de validação
cross_validation(validation_set_cp, LightGBM_model)
# Out:
# Scores: [0.21363294 0.20448382 0.20772239 0.19477896 0.20954936 0.19664478
#  0.20036623 0.20172459 0.20718759 0.20442462]
# Mean: 0.20405152761744372
# Standard deviation: 0.005527225844071641

# %%
# Visualizando dados: Previsão X Dados verdadeiros
plot_predictions(validation_set_cp, LightGBM_model)

# %%
plot_distribution(validation_set_cp, LightGBM_model)

# %% [markdown]
# ### Variáveis mais significativas

# %%
feature_importance(train_set_cp, LightGBM_model)
# Out:
#                           Feature  Importance
# 21     artist_weighted_popularity    1.000000
# 11                     track_year    0.728395
# 3                        loudness    0.532922
# 9                         valence    0.469136
# 8                        liveness    0.430041
# 10                          tempo    0.411523
# 5                     speechiness    0.395062
# 1                          energy    0.382716
# 0                    danceability    0.380658
# 6                    acousticness    0.360082
# 7                instrumentalness    0.308642
# 13                  track_seconds    0.248971
# 17                track_genre_pop    0.133745
# 2                             key    0.125514
# 12                  track_minutes    0.090535
# 15                track_genre_edm    0.074074
# 4                            mode    0.032922
# 20               track_genre_rock    0.016461
# 14  track_duration_classification    0.014403
# 19                track_genre_rap    0.014403
# 18                track_genre_r&b    0.012346
# 16              track_genre_latin    0.010288

# %% [markdown]
# ## **Modelo: Regressão Ridge**

# %% [markdown]
# ### Treino:

# %%
params = {}

# Treinando modelo com conjunto de treino
Ridge_model = train_model(train_set_cp, 'ridge', params)

# %% [markdown]
# ### Validação

# %%
# SEM VALIDAÇÃO CRUZADA -> Usando o conjunto de validação
evaluate_model_performance(validation_set_cp, Ridge_model)
# Out:
# MAE: 0.16755195846785215
# MSE: 0.05045082362268246
# RMSE: 0.22461260788896614
# R²: 0.11936481804873833
# Predições do modelo:
# [0.41953704 0.77221843 0.42023548 ... 0.42728537 0.54537783 0.66630801]

# %%
# COM VALIDAÇÃO CRUZADA -> Usando o conjunto de validação
cross_validation(validation_set_cp, Ridge_model)
# Out:
# Scores: [0.21849431 0.21138574 0.2129681  0.18818571 0.2082288  0.19810911
#  0.20686101 0.20640093 0.21325055 0.21609909]
# Mean: 0.20799833634475812
# Standard deviation: 0.008566105338665425

# %%
# Visualizando dados: Previsão X Dados verdadeiros
plot_predictions(validation_set_cp, Ridge_model)

# %%
plot_distribution(validation_set_cp, Ridge_model)

# %% [markdown]
# ### Variáveis mais significativas

# %%
feature_importance(train_set_cp, Ridge_model)
# Out:
#                           Feature  Importance
# 21     artist_weighted_popularity    0.965708
# 3                        loudness    0.096862
# 14  track_duration_classification    0.062394
# 1                          energy    0.056798
# 12                  track_minutes    0.037647
# 0                    danceability    0.031293
# 17                track_genre_pop    0.026096
# 11                     track_year    0.025747
# 15                track_genre_edm    0.016524
# 10                          tempo    0.014093
# 6                    acousticness    0.007459
# 18                track_genre_r&b    0.007067
# 19                track_genre_rap    0.006646
# 20               track_genre_rock    0.006584
# 5                     speechiness    0.004824
# 8                        liveness    0.004078
# 16              track_genre_latin    0.002443
# 2                             key    0.001847
# 4                            mode    0.001160
# 13                  track_seconds    0.000991
# 9                         valence    0.000792
# 7                instrumentalness    0.000752

# %% [markdown]
# ## **Modelo Catboost**

# %%
Catboost_model = train_model(train_set_cp, 'catboost', {})
# Out:
# Learning rate set to 0.064817
# 0:	learn: 0.2286244	total: 6.46ms	remaining: 6.46s
# 1:	learn: 0.2206752	total: 12.4ms	remaining: 6.19s
# 2:	learn: 0.2132913	total: 19.3ms	remaining: 6.43s
# 3:	learn: 0.2065216	total: 28.7ms	remaining: 7.14s
# 4:	learn: 0.2003690	total: 36.2ms	remaining: 7.2s
# 5:	learn: 0.1947240	total: 45.1ms	remaining: 7.47s
# 6:	learn: 0.1895227	total: 53.4ms	remaining: 7.58s
# 7:	learn: 0.1851015	total: 59.4ms	remaining: 7.37s
# 8:	learn: 0.1809768	total: 65.2ms	remaining: 7.18s
# 9:	learn: 0.1769712	total: 71.4ms	remaining: 7.07s
# 10:	learn: 0.1735103	total: 77.5ms	remaining: 6.96s
# 11:	learn: 0.1706036	total: 83.5ms	remaining: 6.88s
# 12:	learn: 0.1677523	total: 89.7ms	remaining: 6.81s
# 13:	learn: 0.1652562	total: 95.7ms	remaining: 6.74s
# 14:	learn: 0.1631477	total: 102ms	remaining: 6.7s
# 15:	learn: 0.1611638	total: 108ms	remaining: 6.66s
# 16:	learn: 0.1593240	total: 115ms	remaining: 6.62s
# 17:	learn: 0.1577193	total: 122ms	remaining: 6.66s
# 18:	learn: 0.1561432	total: 128ms	remaining: 6.6s
# 19:	learn: 0.1547177	total: 133ms	remaining: 6.54s
# 20:	learn: 0.1535203	total: 140ms	remaining: 6.51s
# 21:	learn: 0.1524459	total: 147ms	remaining: 6.51s
# 22:	learn: 0.1515172	total: 153ms	remaining: 6.5s
# 23:	learn: 0.1506358	total: 159ms	remaining: 6.48s
# 24:	learn: 0.1499315	total: 166ms	remaining: 6.46s
# 25:	learn: 0.1492844	total: 171ms	remaining: 6.42s
# 26:	learn: 0.1486698	total: 177ms	remaining: 6.39s
# 27:	learn: 0.1480030	total: 184ms	remaining: 6.38s
# 28:	learn: 0.1474276	total: 192ms	remaining: 6.44s
# 29:	learn: 0.1468796	total: 199ms	remaining: 6.43s
# 30:	learn: 0.1464386	total: 205ms	remaining: 6.4s
# 31:	learn: 0.1460293	total: 211ms	remaining: 6.39s
# 32:	learn: 0.1457124	total: 217ms	remaining: 6.36s
# 33:	learn: 0.1454018	total: 223ms	remaining: 6.34s
# 34:	learn: 0.1450867	total: 229ms	remaining: 6.33s
# 35:	learn: 0.1447735	total: 236ms	remaining: 6.32s
# 36:	learn: 0.1445376	total: 242ms	remaining: 6.3s
# 37:	learn: 0.1442708	total: 248ms	remaining: 6.28s
# 38:	learn: 0.1440782	total: 254ms	remaining: 6.27s
# 39:	learn: 0.1439067	total: 261ms	remaining: 6.25s
# 40:	learn: 0.1436826	total: 267ms	remaining: 6.24s
# 41:	learn: 0.1435366	total: 273ms	remaining: 6.22s
# 42:	learn: 0.1433701	total: 279ms	remaining: 6.2s
# 43:	learn: 0.1432346	total: 285ms	remaining: 6.19s
# 44:	learn: 0.1431154	total: 291ms	remaining: 6.17s
# 45:	learn: 0.1429913	total: 297ms	remaining: 6.16s
# 46:	learn: 0.1428829	total: 303ms	remaining: 6.14s
# 47:	learn: 0.1428296	total: 306ms	remaining: 6.07s
# 48:	learn: 0.1427102	total: 313ms	remaining: 6.07s
# 49:	learn: 0.1425945	total: 319ms	remaining: 6.06s
# 50:	learn: 0.1425062	total: 325ms	remaining: 6.05s
# 51:	learn: 0.1423993	total: 332ms	remaining: 6.04s
# 52:	learn: 0.1423355	total: 338ms	remaining: 6.04s
# 53:	learn: 0.1422569	total: 345ms	remaining: 6.04s
# 54:	learn: 0.1421944	total: 351ms	remaining: 6.02s
# 55:	learn: 0.1421317	total: 357ms	remaining: 6.01s
# 56:	learn: 0.1420361	total: 363ms	remaining: 6s
# 57:	learn: 0.1419806	total: 369ms	remaining: 5.99s
# 58:	learn: 0.1419085	total: 375ms	remaining: 5.98s
# 59:	learn: 0.1418565	total: 381ms	remaining: 5.97s
# 60:	learn: 0.1417981	total: 389ms	remaining: 5.99s
# 61:	learn: 0.1417227	total: 395ms	remaining: 5.98s
# 62:	learn: 0.1416626	total: 401ms	remaining: 5.96s
# 63:	learn: 0.1415844	total: 407ms	remaining: 5.95s
# 64:	learn: 0.1415320	total: 415ms	remaining: 5.97s
# 65:	learn: 0.1414947	total: 421ms	remaining: 5.96s
# 66:	learn: 0.1414497	total: 427ms	remaining: 5.95s
# 67:	learn: 0.1414008	total: 434ms	remaining: 5.94s
# 68:	learn: 0.1413295	total: 440ms	remaining: 5.93s
# 69:	learn: 0.1412895	total: 446ms	remaining: 5.93s
# 70:	learn: 0.1412504	total: 452ms	remaining: 5.92s
# 71:	learn: 0.1412173	total: 461ms	remaining: 5.95s
# 72:	learn: 0.1411551	total: 467ms	remaining: 5.93s
# 73:	learn: 0.1411228	total: 473ms	remaining: 5.92s
# 74:	learn: 0.1410938	total: 479ms	remaining: 5.91s
# 75:	learn: 0.1410730	total: 485ms	remaining: 5.89s
# 76:	learn: 0.1410299	total: 491ms	remaining: 5.88s
# 77:	learn: 0.1409948	total: 497ms	remaining: 5.88s
# 78:	learn: 0.1409499	total: 504ms	remaining: 5.87s
# 79:	learn: 0.1408957	total: 510ms	remaining: 5.87s
# 80:	learn: 0.1408687	total: 516ms	remaining: 5.85s
# 81:	learn: 0.1408346	total: 522ms	remaining: 5.85s
# 82:	learn: 0.1407802	total: 529ms	remaining: 5.84s
# 83:	learn: 0.1407563	total: 535ms	remaining: 5.83s
# 84:	learn: 0.1407272	total: 541ms	remaining: 5.82s
# 85:	learn: 0.1407093	total: 546ms	remaining: 5.81s
# 86:	learn: 0.1406752	total: 553ms	remaining: 5.8s
# 87:	learn: 0.1406525	total: 558ms	remaining: 5.79s
# 88:	learn: 0.1405955	total: 565ms	remaining: 5.78s
# 89:	learn: 0.1405641	total: 571ms	remaining: 5.77s
# 90:	learn: 0.1405147	total: 577ms	remaining: 5.77s
# 91:	learn: 0.1404860	total: 586ms	remaining: 5.79s
# 92:	learn: 0.1404527	total: 593ms	remaining: 5.78s
# 93:	learn: 0.1404100	total: 599ms	remaining: 5.77s
# 94:	learn: 0.1403559	total: 605ms	remaining: 5.76s
# 95:	learn: 0.1403280	total: 611ms	remaining: 5.75s
# 96:	learn: 0.1403047	total: 617ms	remaining: 5.74s
# 97:	learn: 0.1402734	total: 623ms	remaining: 5.74s
# 98:	learn: 0.1402438	total: 629ms	remaining: 5.72s
# 99:	learn: 0.1402054	total: 635ms	remaining: 5.72s
# 100:	learn: 0.1401718	total: 642ms	remaining: 5.71s
# 101:	learn: 0.1401235	total: 648ms	remaining: 5.71s
# 102:	learn: 0.1400930	total: 654ms	remaining: 5.7s
# 103:	learn: 0.1400578	total: 660ms	remaining: 5.69s
# 104:	learn: 0.1400232	total: 667ms	remaining: 5.68s
# 105:	learn: 0.1399968	total: 673ms	remaining: 5.67s
# 106:	learn: 0.1399519	total: 679ms	remaining: 5.66s
# 107:	learn: 0.1399140	total: 688ms	remaining: 5.68s
# 108:	learn: 0.1398939	total: 705ms	remaining: 5.76s
# 109:	learn: 0.1398587	total: 712ms	remaining: 5.76s
# 110:	learn: 0.1398256	total: 719ms	remaining: 5.75s
# 111:	learn: 0.1397950	total: 725ms	remaining: 5.75s
# 112:	learn: 0.1397728	total: 731ms	remaining: 5.74s
# 113:	learn: 0.1397517	total: 737ms	remaining: 5.73s
# 114:	learn: 0.1397277	total: 743ms	remaining: 5.72s
# 115:	learn: 0.1397002	total: 749ms	remaining: 5.71s
# 116:	learn: 0.1396675	total: 755ms	remaining: 5.7s
# 117:	learn: 0.1396487	total: 762ms	remaining: 5.7s
# 118:	learn: 0.1396186	total: 768ms	remaining: 5.69s
# 119:	learn: 0.1395763	total: 775ms	remaining: 5.68s
# 120:	learn: 0.1395412	total: 783ms	remaining: 5.68s
# 121:	learn: 0.1395139	total: 790ms	remaining: 5.68s
# 122:	learn: 0.1394935	total: 796ms	remaining: 5.67s
# 123:	learn: 0.1394313	total: 801ms	remaining: 5.66s
# 124:	learn: 0.1393908	total: 807ms	remaining: 5.65s
# 125:	learn: 0.1393698	total: 813ms	remaining: 5.64s
# 126:	learn: 0.1393382	total: 819ms	remaining: 5.63s
# 127:	learn: 0.1393089	total: 825ms	remaining: 5.62s
# 128:	learn: 0.1392763	total: 831ms	remaining: 5.61s
# 129:	learn: 0.1392263	total: 838ms	remaining: 5.6s
# 130:	learn: 0.1391922	total: 843ms	remaining: 5.59s
# 131:	learn: 0.1391630	total: 850ms	remaining: 5.59s
# 132:	learn: 0.1391386	total: 855ms	remaining: 5.58s
# 133:	learn: 0.1391144	total: 861ms	remaining: 5.57s
# 134:	learn: 0.1390847	total: 867ms	remaining: 5.56s
# 135:	learn: 0.1390463	total: 874ms	remaining: 5.55s
# 136:	learn: 0.1390228	total: 880ms	remaining: 5.54s
# 137:	learn: 0.1389971	total: 886ms	remaining: 5.53s
# 138:	learn: 0.1389725	total: 892ms	remaining: 5.53s
# 139:	learn: 0.1389468	total: 898ms	remaining: 5.51s
# 140:	learn: 0.1389206	total: 904ms	remaining: 5.51s
# 141:	learn: 0.1388757	total: 910ms	remaining: 5.5s
# 142:	learn: 0.1388571	total: 916ms	remaining: 5.49s
# 143:	learn: 0.1388222	total: 922ms	remaining: 5.48s
# 144:	learn: 0.1387910	total: 928ms	remaining: 5.47s
# 145:	learn: 0.1387555	total: 934ms	remaining: 5.46s
# 146:	learn: 0.1387302	total: 940ms	remaining: 5.45s
# 147:	learn: 0.1386988	total: 946ms	remaining: 5.45s
# 148:	learn: 0.1386585	total: 953ms	remaining: 5.44s
# 149:	learn: 0.1386269	total: 959ms	remaining: 5.43s
# 150:	learn: 0.1385909	total: 965ms	remaining: 5.42s
# 151:	learn: 0.1385499	total: 971ms	remaining: 5.41s
# 152:	learn: 0.1385284	total: 981ms	remaining: 5.43s
# 153:	learn: 0.1384806	total: 988ms	remaining: 5.43s
# 154:	learn: 0.1384385	total: 994ms	remaining: 5.42s
# 155:	learn: 0.1383926	total: 1s	remaining: 5.41s
# 156:	learn: 0.1383466	total: 1s	remaining: 5.4s
# 157:	learn: 0.1383217	total: 1.01s	remaining: 5.39s
# 158:	learn: 0.1382767	total: 1.02s	remaining: 5.38s
# 159:	learn: 0.1382480	total: 1.02s	remaining: 5.38s
# 160:	learn: 0.1382128	total: 1.03s	remaining: 5.37s
# 161:	learn: 0.1381835	total: 1.03s	remaining: 5.36s
# 162:	learn: 0.1381506	total: 1.04s	remaining: 5.35s
# 163:	learn: 0.1381244	total: 1.05s	remaining: 5.34s
# 164:	learn: 0.1380981	total: 1.05s	remaining: 5.33s
# 165:	learn: 0.1380701	total: 1.06s	remaining: 5.32s
# 166:	learn: 0.1380340	total: 1.06s	remaining: 5.31s
# 167:	learn: 0.1379917	total: 1.07s	remaining: 5.3s
# 168:	learn: 0.1379696	total: 1.08s	remaining: 5.29s
# 169:	learn: 0.1379477	total: 1.08s	remaining: 5.29s
# 170:	learn: 0.1379147	total: 1.09s	remaining: 5.28s
# 171:	learn: 0.1378935	total: 1.09s	remaining: 5.27s
# 172:	learn: 0.1378773	total: 1.1s	remaining: 5.26s
# 173:	learn: 0.1378347	total: 1.11s	remaining: 5.26s
# 174:	learn: 0.1378062	total: 1.11s	remaining: 5.25s
# 175:	learn: 0.1377822	total: 1.12s	remaining: 5.24s
# 176:	learn: 0.1377515	total: 1.13s	remaining: 5.23s
# 177:	learn: 0.1377339	total: 1.13s	remaining: 5.22s
# 178:	learn: 0.1377051	total: 1.14s	remaining: 5.21s
# 179:	learn: 0.1376620	total: 1.14s	remaining: 5.21s
# 180:	learn: 0.1376369	total: 1.15s	remaining: 5.2s
# 181:	learn: 0.1375942	total: 1.15s	remaining: 5.19s
# 182:	learn: 0.1375580	total: 1.16s	remaining: 5.18s
# 183:	learn: 0.1375322	total: 1.17s	remaining: 5.17s
# 184:	learn: 0.1374926	total: 1.17s	remaining: 5.16s
# 185:	learn: 0.1374645	total: 1.18s	remaining: 5.17s
# 186:	learn: 0.1374346	total: 1.19s	remaining: 5.16s
# 187:	learn: 0.1373949	total: 1.19s	remaining: 5.15s
# 188:	learn: 0.1373581	total: 1.2s	remaining: 5.14s
# 189:	learn: 0.1373319	total: 1.2s	remaining: 5.13s
# 190:	learn: 0.1373000	total: 1.21s	remaining: 5.13s
# 191:	learn: 0.1372668	total: 1.22s	remaining: 5.12s
# 192:	learn: 0.1372402	total: 1.22s	remaining: 5.11s
# 193:	learn: 0.1372125	total: 1.23s	remaining: 5.11s
# 194:	learn: 0.1371853	total: 1.23s	remaining: 5.1s
# 195:	learn: 0.1371465	total: 1.24s	remaining: 5.09s
# 196:	learn: 0.1371232	total: 1.25s	remaining: 5.08s
# 197:	learn: 0.1370927	total: 1.25s	remaining: 5.07s
# 198:	learn: 0.1370366	total: 1.26s	remaining: 5.07s
# 199:	learn: 0.1369799	total: 1.26s	remaining: 5.06s
# 200:	learn: 0.1369219	total: 1.27s	remaining: 5.05s
# 201:	learn: 0.1368909	total: 1.28s	remaining: 5.04s
# 202:	learn: 0.1368646	total: 1.28s	remaining: 5.04s
# 203:	learn: 0.1368324	total: 1.29s	remaining: 5.03s
# 204:	learn: 0.1368107	total: 1.29s	remaining: 5.02s
# 205:	learn: 0.1367788	total: 1.3s	remaining: 5.01s
# 206:	learn: 0.1367551	total: 1.31s	remaining: 5.01s
# 207:	learn: 0.1367244	total: 1.31s	remaining: 5s
# 208:	learn: 0.1367012	total: 1.32s	remaining: 4.99s
# 209:	learn: 0.1366694	total: 1.32s	remaining: 4.98s
# 210:	learn: 0.1366516	total: 1.33s	remaining: 4.97s
# 211:	learn: 0.1366140	total: 1.34s	remaining: 4.97s
# 212:	learn: 0.1365773	total: 1.34s	remaining: 4.96s
# 213:	learn: 0.1365478	total: 1.35s	remaining: 4.96s
# 214:	learn: 0.1365282	total: 1.35s	remaining: 4.95s
# 215:	learn: 0.1364862	total: 1.36s	remaining: 4.94s
# 216:	learn: 0.1364276	total: 1.37s	remaining: 4.94s
# 217:	learn: 0.1364082	total: 1.38s	remaining: 4.94s
# 218:	learn: 0.1363790	total: 1.38s	remaining: 4.93s
# 219:	learn: 0.1363381	total: 1.39s	remaining: 4.93s
# 220:	learn: 0.1363042	total: 1.4s	remaining: 4.92s
# 221:	learn: 0.1362736	total: 1.4s	remaining: 4.91s
# 222:	learn: 0.1362437	total: 1.41s	remaining: 4.9s
# 223:	learn: 0.1362026	total: 1.41s	remaining: 4.89s
# 224:	learn: 0.1361795	total: 1.42s	remaining: 4.89s
# 225:	learn: 0.1361581	total: 1.43s	remaining: 4.88s
# 226:	learn: 0.1361155	total: 1.43s	remaining: 4.88s
# 227:	learn: 0.1360781	total: 1.44s	remaining: 4.87s
# 228:	learn: 0.1360401	total: 1.44s	remaining: 4.86s
# 229:	learn: 0.1360268	total: 1.45s	remaining: 4.85s
# 230:	learn: 0.1360115	total: 1.46s	remaining: 4.85s
# 231:	learn: 0.1359770	total: 1.46s	remaining: 4.84s
# 232:	learn: 0.1359469	total: 1.47s	remaining: 4.83s
# 233:	learn: 0.1359186	total: 1.47s	remaining: 4.82s
# 234:	learn: 0.1358868	total: 1.48s	remaining: 4.82s
# 235:	learn: 0.1358522	total: 1.49s	remaining: 4.81s
# 236:	learn: 0.1358177	total: 1.49s	remaining: 4.8s
# 237:	learn: 0.1357815	total: 1.5s	remaining: 4.8s
# 238:	learn: 0.1357563	total: 1.5s	remaining: 4.79s
# 239:	learn: 0.1357364	total: 1.51s	remaining: 4.78s
# 240:	learn: 0.1357095	total: 1.51s	remaining: 4.77s
# 241:	learn: 0.1356861	total: 1.52s	remaining: 4.76s
# 242:	learn: 0.1356350	total: 1.53s	remaining: 4.76s
# 243:	learn: 0.1355920	total: 1.53s	remaining: 4.75s
# 244:	learn: 0.1355594	total: 1.54s	remaining: 4.74s
# 245:	learn: 0.1355341	total: 1.54s	remaining: 4.74s
# 246:	learn: 0.1355033	total: 1.55s	remaining: 4.73s
# 247:	learn: 0.1354735	total: 1.56s	remaining: 4.72s
# 248:	learn: 0.1354306	total: 1.56s	remaining: 4.72s
# 249:	learn: 0.1354004	total: 1.57s	remaining: 4.71s
# 250:	learn: 0.1353404	total: 1.58s	remaining: 4.71s
# 251:	learn: 0.1353141	total: 1.58s	remaining: 4.7s
# 252:	learn: 0.1352860	total: 1.59s	remaining: 4.7s
# 253:	learn: 0.1352447	total: 1.6s	remaining: 4.69s
# 254:	learn: 0.1352237	total: 1.6s	remaining: 4.68s
# 255:	learn: 0.1351788	total: 1.61s	remaining: 4.67s
# 256:	learn: 0.1351393	total: 1.61s	remaining: 4.67s
# 257:	learn: 0.1351047	total: 1.62s	remaining: 4.66s
# 258:	learn: 0.1350713	total: 1.63s	remaining: 4.65s
# 259:	learn: 0.1350350	total: 1.63s	remaining: 4.64s
# 260:	learn: 0.1350061	total: 1.64s	remaining: 4.64s
# 261:	learn: 0.1349691	total: 1.64s	remaining: 4.63s
# 262:	learn: 0.1349342	total: 1.65s	remaining: 4.63s
# 263:	learn: 0.1349184	total: 1.66s	remaining: 4.62s
# 264:	learn: 0.1348942	total: 1.66s	remaining: 4.61s
# 265:	learn: 0.1348692	total: 1.67s	remaining: 4.62s
# 266:	learn: 0.1348429	total: 1.69s	remaining: 4.63s
# 267:	learn: 0.1348067	total: 1.69s	remaining: 4.63s
# 268:	learn: 0.1347733	total: 1.7s	remaining: 4.62s
# 269:	learn: 0.1347219	total: 1.71s	remaining: 4.61s
# 270:	learn: 0.1346954	total: 1.71s	remaining: 4.61s
# 271:	learn: 0.1346790	total: 1.72s	remaining: 4.6s
# 272:	learn: 0.1346452	total: 1.72s	remaining: 4.59s
# 273:	learn: 0.1346125	total: 1.73s	remaining: 4.58s
# 274:	learn: 0.1345794	total: 1.74s	remaining: 4.58s
# 275:	learn: 0.1345583	total: 1.74s	remaining: 4.57s
# 276:	learn: 0.1345271	total: 1.75s	remaining: 4.56s
# 277:	learn: 0.1344982	total: 1.75s	remaining: 4.56s
# 278:	learn: 0.1344789	total: 1.76s	remaining: 4.55s
# 279:	learn: 0.1344426	total: 1.77s	remaining: 4.55s
# 280:	learn: 0.1344165	total: 1.77s	remaining: 4.54s
# 281:	learn: 0.1343896	total: 1.78s	remaining: 4.53s
# 282:	learn: 0.1343536	total: 1.79s	remaining: 4.53s
# 283:	learn: 0.1343211	total: 1.79s	remaining: 4.52s
# 284:	learn: 0.1342952	total: 1.8s	remaining: 4.51s
# 285:	learn: 0.1342574	total: 1.8s	remaining: 4.5s
# 286:	learn: 0.1342129	total: 1.81s	remaining: 4.5s
# 287:	learn: 0.1341785	total: 1.82s	remaining: 4.49s
# 288:	learn: 0.1341523	total: 1.82s	remaining: 4.48s
# 289:	learn: 0.1341156	total: 1.83s	remaining: 4.48s
# 290:	learn: 0.1340747	total: 1.83s	remaining: 4.47s
# 291:	learn: 0.1340548	total: 1.84s	remaining: 4.46s
# 292:	learn: 0.1340324	total: 1.85s	remaining: 4.46s
# 293:	learn: 0.1340064	total: 1.85s	remaining: 4.45s
# 294:	learn: 0.1339878	total: 1.86s	remaining: 4.44s
# 295:	learn: 0.1339679	total: 1.86s	remaining: 4.43s
# 296:	learn: 0.1339417	total: 1.87s	remaining: 4.43s
# 297:	learn: 0.1339150	total: 1.88s	remaining: 4.42s
# 298:	learn: 0.1338730	total: 1.88s	remaining: 4.41s
# 299:	learn: 0.1338366	total: 1.89s	remaining: 4.41s
# 300:	learn: 0.1337983	total: 1.89s	remaining: 4.4s
# 301:	learn: 0.1337728	total: 1.9s	remaining: 4.39s
# 302:	learn: 0.1337290	total: 1.91s	remaining: 4.39s
# 303:	learn: 0.1336953	total: 1.91s	remaining: 4.38s
# 304:	learn: 0.1336593	total: 1.92s	remaining: 4.37s
# 305:	learn: 0.1336211	total: 1.93s	remaining: 4.37s
# 306:	learn: 0.1335996	total: 1.93s	remaining: 4.36s
# 307:	learn: 0.1335657	total: 1.94s	remaining: 4.36s
# 308:	learn: 0.1335481	total: 1.95s	remaining: 4.35s
# 309:	learn: 0.1335172	total: 1.95s	remaining: 4.34s
# 310:	learn: 0.1334866	total: 1.96s	remaining: 4.34s
# 311:	learn: 0.1334540	total: 1.97s	remaining: 4.33s
# 312:	learn: 0.1334297	total: 1.97s	remaining: 4.33s
# 313:	learn: 0.1333874	total: 1.98s	remaining: 4.32s
# 314:	learn: 0.1333755	total: 1.98s	remaining: 4.31s
# 315:	learn: 0.1333446	total: 1.99s	remaining: 4.3s
# 316:	learn: 0.1333218	total: 2s	remaining: 4.3s
# 317:	learn: 0.1332897	total: 2s	remaining: 4.29s
# 318:	learn: 0.1332690	total: 2.01s	remaining: 4.28s
# 319:	learn: 0.1332492	total: 2.01s	remaining: 4.28s
# 320:	learn: 0.1332239	total: 2.02s	remaining: 4.27s
# 321:	learn: 0.1332124	total: 2.02s	remaining: 4.26s
# 322:	learn: 0.1331760	total: 2.03s	remaining: 4.26s
# 323:	learn: 0.1331319	total: 2.04s	remaining: 4.25s
# 324:	learn: 0.1331048	total: 2.04s	remaining: 4.24s
# 325:	learn: 0.1330735	total: 2.05s	remaining: 4.24s
# 326:	learn: 0.1330325	total: 2.06s	remaining: 4.23s
# 327:	learn: 0.1329919	total: 2.06s	remaining: 4.22s
# 328:	learn: 0.1329582	total: 2.07s	remaining: 4.22s
# 329:	learn: 0.1329336	total: 2.07s	remaining: 4.21s
# 330:	learn: 0.1329038	total: 2.08s	remaining: 4.2s
# 331:	learn: 0.1328752	total: 2.09s	remaining: 4.2s
# 332:	learn: 0.1328519	total: 2.09s	remaining: 4.19s
# 333:	learn: 0.1328405	total: 2.1s	remaining: 4.18s
# 334:	learn: 0.1328122	total: 2.1s	remaining: 4.18s
# 335:	learn: 0.1327671	total: 2.11s	remaining: 4.17s
# 336:	learn: 0.1327467	total: 2.12s	remaining: 4.16s
# 337:	learn: 0.1327263	total: 2.12s	remaining: 4.16s
# 338:	learn: 0.1326971	total: 2.13s	remaining: 4.15s
# 339:	learn: 0.1326702	total: 2.13s	remaining: 4.14s
# 340:	learn: 0.1326434	total: 2.14s	remaining: 4.14s
# 341:	learn: 0.1326119	total: 2.15s	remaining: 4.13s
# 342:	learn: 0.1325745	total: 2.15s	remaining: 4.13s
# 343:	learn: 0.1325362	total: 2.16s	remaining: 4.13s
# 344:	learn: 0.1325024	total: 2.17s	remaining: 4.12s
# 345:	learn: 0.1324764	total: 2.18s	remaining: 4.11s
# 346:	learn: 0.1324521	total: 2.18s	remaining: 4.11s
# 347:	learn: 0.1324140	total: 2.19s	remaining: 4.1s
# 348:	learn: 0.1323713	total: 2.19s	remaining: 4.09s
# 349:	learn: 0.1323433	total: 2.2s	remaining: 4.09s
# 350:	learn: 0.1323195	total: 2.21s	remaining: 4.08s
# 351:	learn: 0.1322765	total: 2.21s	remaining: 4.08s
# 352:	learn: 0.1322597	total: 2.23s	remaining: 4.08s
# 353:	learn: 0.1322331	total: 2.25s	remaining: 4.1s
# 354:	learn: 0.1322130	total: 2.26s	remaining: 4.11s
# 355:	learn: 0.1321914	total: 2.28s	remaining: 4.12s
# 356:	learn: 0.1321659	total: 2.28s	remaining: 4.11s
# 357:	learn: 0.1321369	total: 2.29s	remaining: 4.11s
# 358:	learn: 0.1321075	total: 2.3s	remaining: 4.1s
# 359:	learn: 0.1320786	total: 2.3s	remaining: 4.09s
# 360:	learn: 0.1320474	total: 2.31s	remaining: 4.09s
# 361:	learn: 0.1320188	total: 2.31s	remaining: 4.08s
# 362:	learn: 0.1319920	total: 2.32s	remaining: 4.07s
# 363:	learn: 0.1319704	total: 2.33s	remaining: 4.07s
# 364:	learn: 0.1319343	total: 2.33s	remaining: 4.06s
# 365:	learn: 0.1318873	total: 2.34s	remaining: 4.06s
# 366:	learn: 0.1318640	total: 2.35s	remaining: 4.05s
# 367:	learn: 0.1318290	total: 2.35s	remaining: 4.04s
# 368:	learn: 0.1317985	total: 2.37s	remaining: 4.04s
# 369:	learn: 0.1317763	total: 2.37s	remaining: 4.04s
# 370:	learn: 0.1317392	total: 2.38s	remaining: 4.03s
# 371:	learn: 0.1317191	total: 2.39s	remaining: 4.03s
# 372:	learn: 0.1316963	total: 2.39s	remaining: 4.02s
# 373:	learn: 0.1316669	total: 2.4s	remaining: 4.01s
# 374:	learn: 0.1316368	total: 2.4s	remaining: 4.01s
# 375:	learn: 0.1315895	total: 2.41s	remaining: 4s
# 376:	learn: 0.1315661	total: 2.42s	remaining: 3.99s
# 377:	learn: 0.1315307	total: 2.42s	remaining: 3.99s
# 378:	learn: 0.1315144	total: 2.43s	remaining: 3.98s
# 379:	learn: 0.1314799	total: 2.44s	remaining: 3.97s
# 380:	learn: 0.1314508	total: 2.44s	remaining: 3.97s
# 381:	learn: 0.1314326	total: 2.45s	remaining: 3.96s
# 382:	learn: 0.1313996	total: 2.45s	remaining: 3.95s
# 383:	learn: 0.1313738	total: 2.46s	remaining: 3.94s
# 384:	learn: 0.1313521	total: 2.46s	remaining: 3.94s
# 385:	learn: 0.1313197	total: 2.47s	remaining: 3.93s
# 386:	learn: 0.1312692	total: 2.48s	remaining: 3.92s
# 387:	learn: 0.1312291	total: 2.48s	remaining: 3.92s
# 388:	learn: 0.1311995	total: 2.49s	remaining: 3.91s
# 389:	learn: 0.1311858	total: 2.5s	remaining: 3.9s
# 390:	learn: 0.1311395	total: 2.5s	remaining: 3.9s
# 391:	learn: 0.1311213	total: 2.51s	remaining: 3.89s
# 392:	learn: 0.1310882	total: 2.52s	remaining: 3.88s
# 393:	learn: 0.1310491	total: 2.52s	remaining: 3.88s
# 394:	learn: 0.1310151	total: 2.53s	remaining: 3.87s
# 395:	learn: 0.1310042	total: 2.53s	remaining: 3.86s
# 396:	learn: 0.1309842	total: 2.54s	remaining: 3.86s
# 397:	learn: 0.1309651	total: 2.54s	remaining: 3.85s
# 398:	learn: 0.1309321	total: 2.55s	remaining: 3.84s
# 399:	learn: 0.1309034	total: 2.56s	remaining: 3.83s
# 400:	learn: 0.1308809	total: 2.57s	remaining: 3.83s
# 401:	learn: 0.1308451	total: 2.57s	remaining: 3.83s
# 402:	learn: 0.1308156	total: 2.58s	remaining: 3.82s
# 403:	learn: 0.1307879	total: 2.58s	remaining: 3.81s
# 404:	learn: 0.1307412	total: 2.59s	remaining: 3.81s
# 405:	learn: 0.1307248	total: 2.6s	remaining: 3.8s
# 406:	learn: 0.1306894	total: 2.6s	remaining: 3.79s
# 407:	learn: 0.1306665	total: 2.61s	remaining: 3.79s
# 408:	learn: 0.1306466	total: 2.62s	remaining: 3.78s
# 409:	learn: 0.1306284	total: 2.62s	remaining: 3.77s
# 410:	learn: 0.1306069	total: 2.63s	remaining: 3.77s
# 411:	learn: 0.1305855	total: 2.63s	remaining: 3.76s
# 412:	learn: 0.1305573	total: 2.64s	remaining: 3.75s
# 413:	learn: 0.1305332	total: 2.65s	remaining: 3.75s
# 414:	learn: 0.1305165	total: 2.65s	remaining: 3.74s
# 415:	learn: 0.1305080	total: 2.67s	remaining: 3.75s
# 416:	learn: 0.1304674	total: 2.68s	remaining: 3.75s
# 417:	learn: 0.1304442	total: 2.69s	remaining: 3.74s
# 418:	learn: 0.1304255	total: 2.69s	remaining: 3.73s
# 419:	learn: 0.1303939	total: 2.7s	remaining: 3.73s
# 420:	learn: 0.1303481	total: 2.7s	remaining: 3.72s
# 421:	learn: 0.1303253	total: 2.71s	remaining: 3.71s
# 422:	learn: 0.1303013	total: 2.72s	remaining: 3.71s
# 423:	learn: 0.1302807	total: 2.72s	remaining: 3.7s
# 424:	learn: 0.1302358	total: 2.73s	remaining: 3.69s
# 425:	learn: 0.1302081	total: 2.73s	remaining: 3.68s
# 426:	learn: 0.1301704	total: 2.74s	remaining: 3.68s
# 427:	learn: 0.1301442	total: 2.75s	remaining: 3.67s
# 428:	learn: 0.1301195	total: 2.75s	remaining: 3.66s
# 429:	learn: 0.1300895	total: 2.76s	remaining: 3.66s
# 430:	learn: 0.1300582	total: 2.77s	remaining: 3.65s
# 431:	learn: 0.1300282	total: 2.77s	remaining: 3.65s
# 432:	learn: 0.1299909	total: 2.78s	remaining: 3.64s
# 433:	learn: 0.1299651	total: 2.79s	remaining: 3.63s
# 434:	learn: 0.1299300	total: 2.79s	remaining: 3.63s
# 435:	learn: 0.1299108	total: 2.8s	remaining: 3.62s
# 436:	learn: 0.1298630	total: 2.8s	remaining: 3.61s
# 437:	learn: 0.1298398	total: 2.81s	remaining: 3.61s
# 438:	learn: 0.1298150	total: 2.82s	remaining: 3.6s
# 439:	learn: 0.1297910	total: 2.82s	remaining: 3.59s
# 440:	learn: 0.1297579	total: 2.83s	remaining: 3.58s
# 441:	learn: 0.1297399	total: 2.83s	remaining: 3.58s
# 442:	learn: 0.1297084	total: 2.84s	remaining: 3.57s
# 443:	learn: 0.1296752	total: 2.85s	remaining: 3.56s
# 444:	learn: 0.1296399	total: 2.85s	remaining: 3.56s
# 445:	learn: 0.1296116	total: 2.86s	remaining: 3.55s
# 446:	learn: 0.1295704	total: 2.87s	remaining: 3.54s
# 447:	learn: 0.1295561	total: 2.87s	remaining: 3.54s
# 448:	learn: 0.1295163	total: 2.88s	remaining: 3.53s
# 449:	learn: 0.1294848	total: 2.88s	remaining: 3.52s
# 450:	learn: 0.1294613	total: 2.89s	remaining: 3.52s
# 451:	learn: 0.1294344	total: 2.9s	remaining: 3.51s
# 452:	learn: 0.1294031	total: 2.9s	remaining: 3.51s
# 453:	learn: 0.1293699	total: 2.91s	remaining: 3.5s
# 454:	learn: 0.1293458	total: 2.92s	remaining: 3.5s
# 455:	learn: 0.1293068	total: 2.92s	remaining: 3.49s
# 456:	learn: 0.1292855	total: 2.93s	remaining: 3.48s
# 457:	learn: 0.1292574	total: 2.94s	remaining: 3.48s
# 458:	learn: 0.1292331	total: 2.94s	remaining: 3.47s
# 459:	learn: 0.1291980	total: 2.95s	remaining: 3.46s
# 460:	learn: 0.1291681	total: 2.96s	remaining: 3.46s
# 461:	learn: 0.1291457	total: 2.96s	remaining: 3.45s
# 462:	learn: 0.1291146	total: 2.97s	remaining: 3.45s
# 463:	learn: 0.1290818	total: 2.98s	remaining: 3.44s
# 464:	learn: 0.1290534	total: 2.98s	remaining: 3.43s
# 465:	learn: 0.1290260	total: 2.99s	remaining: 3.42s
# 466:	learn: 0.1290063	total: 3s	remaining: 3.42s
# 467:	learn: 0.1289895	total: 3s	remaining: 3.41s
# 468:	learn: 0.1289698	total: 3.01s	remaining: 3.4s
# 469:	learn: 0.1289464	total: 3.01s	remaining: 3.4s
# 470:	learn: 0.1289232	total: 3.02s	remaining: 3.39s
# 471:	learn: 0.1288774	total: 3.02s	remaining: 3.38s
# 472:	learn: 0.1288517	total: 3.03s	remaining: 3.38s
# 473:	learn: 0.1288383	total: 3.04s	remaining: 3.37s
# 474:	learn: 0.1287974	total: 3.04s	remaining: 3.36s
# 475:	learn: 0.1287836	total: 3.05s	remaining: 3.36s
# 476:	learn: 0.1287611	total: 3.06s	remaining: 3.35s
# 477:	learn: 0.1287295	total: 3.06s	remaining: 3.34s
# 478:	learn: 0.1287063	total: 3.07s	remaining: 3.34s
# 479:	learn: 0.1286834	total: 3.07s	remaining: 3.33s
# 480:	learn: 0.1286494	total: 3.08s	remaining: 3.32s
# 481:	learn: 0.1286210	total: 3.09s	remaining: 3.32s
# 482:	learn: 0.1285942	total: 3.09s	remaining: 3.31s
# 483:	learn: 0.1285695	total: 3.1s	remaining: 3.3s
# 484:	learn: 0.1285353	total: 3.1s	remaining: 3.3s
# 485:	learn: 0.1285001	total: 3.11s	remaining: 3.29s
# 486:	learn: 0.1284731	total: 3.12s	remaining: 3.28s
# 487:	learn: 0.1284513	total: 3.12s	remaining: 3.28s
# 488:	learn: 0.1284170	total: 3.13s	remaining: 3.27s
# 489:	learn: 0.1283966	total: 3.13s	remaining: 3.26s
# 490:	learn: 0.1283766	total: 3.14s	remaining: 3.26s
# 491:	learn: 0.1283416	total: 3.15s	remaining: 3.25s
# 492:	learn: 0.1283187	total: 3.15s	remaining: 3.24s
# 493:	learn: 0.1282877	total: 3.16s	remaining: 3.24s
# 494:	learn: 0.1282590	total: 3.17s	remaining: 3.23s
# 495:	learn: 0.1282417	total: 3.18s	remaining: 3.23s
# 496:	learn: 0.1282060	total: 3.18s	remaining: 3.22s
# 497:	learn: 0.1281838	total: 3.19s	remaining: 3.21s
# 498:	learn: 0.1281505	total: 3.19s	remaining: 3.21s
# 499:	learn: 0.1281353	total: 3.2s	remaining: 3.2s
# 500:	learn: 0.1281118	total: 3.21s	remaining: 3.19s
# 501:	learn: 0.1280803	total: 3.21s	remaining: 3.19s
# 502:	learn: 0.1280540	total: 3.22s	remaining: 3.18s
# 503:	learn: 0.1280286	total: 3.23s	remaining: 3.17s
# 504:	learn: 0.1279992	total: 3.23s	remaining: 3.17s
# 505:	learn: 0.1279561	total: 3.24s	remaining: 3.16s
# 506:	learn: 0.1279256	total: 3.24s	remaining: 3.15s
# 507:	learn: 0.1279140	total: 3.25s	remaining: 3.15s
# 508:	learn: 0.1278963	total: 3.25s	remaining: 3.14s
# 509:	learn: 0.1278565	total: 3.26s	remaining: 3.13s
# 510:	learn: 0.1278339	total: 3.27s	remaining: 3.13s
# 511:	learn: 0.1278133	total: 3.27s	remaining: 3.12s
# 512:	learn: 0.1277859	total: 3.28s	remaining: 3.11s
# 513:	learn: 0.1277640	total: 3.29s	remaining: 3.11s
# 514:	learn: 0.1277351	total: 3.29s	remaining: 3.1s
# 515:	learn: 0.1276918	total: 3.3s	remaining: 3.09s
# 516:	learn: 0.1276680	total: 3.31s	remaining: 3.09s
# 517:	learn: 0.1276395	total: 3.31s	remaining: 3.08s
# 518:	learn: 0.1276151	total: 3.32s	remaining: 3.08s
# 519:	learn: 0.1275978	total: 3.33s	remaining: 3.07s
# 520:	learn: 0.1275777	total: 3.33s	remaining: 3.06s
# 521:	learn: 0.1275607	total: 3.34s	remaining: 3.06s
# 522:	learn: 0.1275390	total: 3.34s	remaining: 3.05s
# 523:	learn: 0.1275218	total: 3.35s	remaining: 3.04s
# 524:	learn: 0.1274882	total: 3.36s	remaining: 3.04s
# 525:	learn: 0.1274630	total: 3.37s	remaining: 3.03s
# 526:	learn: 0.1274330	total: 3.37s	remaining: 3.03s
# 527:	learn: 0.1274102	total: 3.38s	remaining: 3.02s
# 528:	learn: 0.1273791	total: 3.38s	remaining: 3.01s
# 529:	learn: 0.1273596	total: 3.39s	remaining: 3.01s
# 530:	learn: 0.1273221	total: 3.4s	remaining: 3s
# 531:	learn: 0.1273024	total: 3.4s	remaining: 2.99s
# 532:	learn: 0.1272785	total: 3.41s	remaining: 2.99s
# 533:	learn: 0.1272470	total: 3.42s	remaining: 2.98s
# 534:	learn: 0.1272158	total: 3.42s	remaining: 2.97s
# 535:	learn: 0.1271956	total: 3.43s	remaining: 2.97s
# 536:	learn: 0.1271566	total: 3.43s	remaining: 2.96s
# 537:	learn: 0.1271285	total: 3.44s	remaining: 2.95s
# 538:	learn: 0.1271036	total: 3.44s	remaining: 2.95s
# 539:	learn: 0.1270742	total: 3.45s	remaining: 2.94s
# 540:	learn: 0.1270404	total: 3.46s	remaining: 2.93s
# 541:	learn: 0.1270020	total: 3.46s	remaining: 2.93s
# 542:	learn: 0.1269821	total: 3.47s	remaining: 2.92s
# 543:	learn: 0.1269579	total: 3.48s	remaining: 2.91s
# 544:	learn: 0.1269385	total: 3.48s	remaining: 2.91s
# 545:	learn: 0.1269160	total: 3.49s	remaining: 2.9s
# 546:	learn: 0.1268968	total: 3.5s	remaining: 2.89s
# 547:	learn: 0.1268575	total: 3.5s	remaining: 2.89s
# 548:	learn: 0.1268416	total: 3.51s	remaining: 2.88s
# 549:	learn: 0.1268199	total: 3.51s	remaining: 2.87s
# 550:	learn: 0.1267940	total: 3.52s	remaining: 2.87s
# 551:	learn: 0.1267596	total: 3.52s	remaining: 2.86s
# 552:	learn: 0.1267302	total: 3.53s	remaining: 2.85s
# 553:	learn: 0.1267095	total: 3.54s	remaining: 2.85s
# 554:	learn: 0.1266917	total: 3.54s	remaining: 2.84s
# 555:	learn: 0.1266688	total: 3.55s	remaining: 2.83s
# 556:	learn: 0.1266509	total: 3.56s	remaining: 2.83s
# 557:	learn: 0.1266278	total: 3.56s	remaining: 2.82s
# 558:	learn: 0.1266002	total: 3.57s	remaining: 2.81s
# 559:	learn: 0.1265788	total: 3.58s	remaining: 2.81s
# 560:	learn: 0.1265410	total: 3.58s	remaining: 2.8s
# 561:	learn: 0.1265311	total: 3.59s	remaining: 2.79s
# 562:	learn: 0.1265068	total: 3.59s	remaining: 2.79s
# 563:	learn: 0.1264757	total: 3.6s	remaining: 2.78s
# 564:	learn: 0.1264499	total: 3.6s	remaining: 2.77s
# 565:	learn: 0.1264153	total: 3.61s	remaining: 2.77s
# 566:	learn: 0.1263869	total: 3.62s	remaining: 2.76s
# 567:	learn: 0.1263622	total: 3.62s	remaining: 2.75s
# 568:	learn: 0.1263312	total: 3.63s	remaining: 2.75s
# 569:	learn: 0.1263041	total: 3.63s	remaining: 2.74s
# 570:	learn: 0.1262816	total: 3.65s	remaining: 2.74s
# 571:	learn: 0.1262513	total: 3.66s	remaining: 2.74s
# 572:	learn: 0.1262187	total: 3.67s	remaining: 2.73s
# 573:	learn: 0.1261907	total: 3.67s	remaining: 2.73s
# 574:	learn: 0.1261709	total: 3.68s	remaining: 2.72s
# 575:	learn: 0.1261485	total: 3.69s	remaining: 2.71s
# 576:	learn: 0.1261258	total: 3.69s	remaining: 2.71s
# 577:	learn: 0.1261014	total: 3.7s	remaining: 2.7s
# 578:	learn: 0.1260733	total: 3.7s	remaining: 2.69s
# 579:	learn: 0.1260382	total: 3.71s	remaining: 2.69s
# 580:	learn: 0.1260077	total: 3.72s	remaining: 2.68s
# 581:	learn: 0.1259857	total: 3.72s	remaining: 2.67s
# 582:	learn: 0.1259631	total: 3.73s	remaining: 2.67s
# 583:	learn: 0.1259486	total: 3.73s	remaining: 2.66s
# 584:	learn: 0.1259238	total: 3.74s	remaining: 2.65s
# 585:	learn: 0.1259029	total: 3.75s	remaining: 2.65s
# 586:	learn: 0.1258795	total: 3.75s	remaining: 2.64s
# 587:	learn: 0.1258458	total: 3.76s	remaining: 2.64s
# 588:	learn: 0.1258126	total: 3.77s	remaining: 2.63s
# 589:	learn: 0.1257912	total: 3.77s	remaining: 2.62s
# 590:	learn: 0.1257626	total: 3.78s	remaining: 2.62s
# 591:	learn: 0.1257304	total: 3.79s	remaining: 2.61s
# 592:	learn: 0.1256995	total: 3.79s	remaining: 2.6s
# 593:	learn: 0.1256785	total: 3.8s	remaining: 2.6s
# 594:	learn: 0.1256571	total: 3.81s	remaining: 2.59s
# 595:	learn: 0.1256295	total: 3.81s	remaining: 2.58s
# 596:	learn: 0.1256012	total: 3.82s	remaining: 2.58s
# 597:	learn: 0.1255884	total: 3.82s	remaining: 2.57s
# 598:	learn: 0.1255653	total: 3.83s	remaining: 2.56s
# 599:	learn: 0.1255259	total: 3.84s	remaining: 2.56s
# 600:	learn: 0.1255083	total: 3.84s	remaining: 2.55s
# 601:	learn: 0.1254870	total: 3.85s	remaining: 2.54s
# 602:	learn: 0.1254678	total: 3.85s	remaining: 2.54s
# 603:	learn: 0.1254520	total: 3.86s	remaining: 2.53s
# 604:	learn: 0.1254175	total: 3.87s	remaining: 2.53s
# 605:	learn: 0.1253904	total: 3.88s	remaining: 2.52s
# 606:	learn: 0.1253651	total: 3.88s	remaining: 2.51s
# 607:	learn: 0.1253483	total: 3.89s	remaining: 2.51s
# 608:	learn: 0.1253059	total: 3.89s	remaining: 2.5s
# 609:	learn: 0.1252906	total: 3.9s	remaining: 2.49s
# 610:	learn: 0.1252676	total: 3.91s	remaining: 2.49s
# 611:	learn: 0.1252491	total: 3.91s	remaining: 2.48s
# 612:	learn: 0.1252250	total: 3.92s	remaining: 2.47s
# 613:	learn: 0.1251968	total: 3.92s	remaining: 2.47s
# 614:	learn: 0.1251792	total: 3.93s	remaining: 2.46s
# 615:	learn: 0.1251467	total: 3.94s	remaining: 2.45s
# 616:	learn: 0.1251190	total: 3.94s	remaining: 2.45s
# 617:	learn: 0.1250997	total: 3.95s	remaining: 2.44s
# 618:	learn: 0.1250808	total: 3.96s	remaining: 2.43s
# 619:	learn: 0.1250464	total: 3.97s	remaining: 2.43s
# 620:	learn: 0.1250286	total: 3.98s	remaining: 2.43s
# 621:	learn: 0.1250091	total: 3.98s	remaining: 2.42s
# 622:	learn: 0.1249860	total: 3.99s	remaining: 2.41s
# 623:	learn: 0.1249690	total: 3.99s	remaining: 2.41s
# 624:	learn: 0.1249469	total: 4s	remaining: 2.4s
# 625:	learn: 0.1249115	total: 4s	remaining: 2.39s
# 626:	learn: 0.1248959	total: 4.01s	remaining: 2.39s
# 627:	learn: 0.1248626	total: 4.02s	remaining: 2.38s
# 628:	learn: 0.1248474	total: 4.02s	remaining: 2.37s
# 629:	learn: 0.1248189	total: 4.03s	remaining: 2.37s
# 630:	learn: 0.1247935	total: 4.04s	remaining: 2.36s
# 631:	learn: 0.1247637	total: 4.04s	remaining: 2.35s
# 632:	learn: 0.1247531	total: 4.05s	remaining: 2.35s
# 633:	learn: 0.1247259	total: 4.05s	remaining: 2.34s
# 634:	learn: 0.1246985	total: 4.06s	remaining: 2.33s
# 635:	learn: 0.1246759	total: 4.07s	remaining: 2.33s
# 636:	learn: 0.1246540	total: 4.07s	remaining: 2.32s
# 637:	learn: 0.1246301	total: 4.08s	remaining: 2.31s
# 638:	learn: 0.1246066	total: 4.08s	remaining: 2.31s
# 639:	learn: 0.1245602	total: 4.09s	remaining: 2.3s
# 640:	learn: 0.1245393	total: 4.1s	remaining: 2.29s
# 641:	learn: 0.1245072	total: 4.1s	remaining: 2.29s
# 642:	learn: 0.1244828	total: 4.11s	remaining: 2.28s
# 643:	learn: 0.1244526	total: 4.12s	remaining: 2.27s
# 644:	learn: 0.1244374	total: 4.12s	remaining: 2.27s
# 645:	learn: 0.1244111	total: 4.13s	remaining: 2.26s
# 646:	learn: 0.1243836	total: 4.13s	remaining: 2.26s
# 647:	learn: 0.1243592	total: 4.14s	remaining: 2.25s
# 648:	learn: 0.1243401	total: 4.15s	remaining: 2.24s
# 649:	learn: 0.1243190	total: 4.15s	remaining: 2.24s
# 650:	learn: 0.1242894	total: 4.16s	remaining: 2.23s
# 651:	learn: 0.1242714	total: 4.17s	remaining: 2.22s
# 652:	learn: 0.1242444	total: 4.17s	remaining: 2.22s
# 653:	learn: 0.1242161	total: 4.18s	remaining: 2.21s
# 654:	learn: 0.1242006	total: 4.19s	remaining: 2.21s
# 655:	learn: 0.1241831	total: 4.19s	remaining: 2.2s
# 656:	learn: 0.1241586	total: 4.2s	remaining: 2.19s
# 657:	learn: 0.1241347	total: 4.21s	remaining: 2.19s
# 658:	learn: 0.1241235	total: 4.21s	remaining: 2.18s
# 659:	learn: 0.1240985	total: 4.22s	remaining: 2.17s
# 660:	learn: 0.1240731	total: 4.22s	remaining: 2.17s
# 661:	learn: 0.1240555	total: 4.23s	remaining: 2.16s
# 662:	learn: 0.1240283	total: 4.24s	remaining: 2.15s
# 663:	learn: 0.1240096	total: 4.24s	remaining: 2.15s
# 664:	learn: 0.1239845	total: 4.25s	remaining: 2.14s
# 665:	learn: 0.1239628	total: 4.25s	remaining: 2.13s
# 666:	learn: 0.1239383	total: 4.26s	remaining: 2.13s
# 667:	learn: 0.1239161	total: 4.26s	remaining: 2.12s
# 668:	learn: 0.1239004	total: 4.27s	remaining: 2.11s
# 669:	learn: 0.1238710	total: 4.28s	remaining: 2.11s
# 670:	learn: 0.1238373	total: 4.28s	remaining: 2.1s
# 671:	learn: 0.1238168	total: 4.29s	remaining: 2.09s
# 672:	learn: 0.1237896	total: 4.3s	remaining: 2.09s
# 673:	learn: 0.1237630	total: 4.3s	remaining: 2.08s
# 674:	learn: 0.1237415	total: 4.31s	remaining: 2.07s
# 675:	learn: 0.1237290	total: 4.32s	remaining: 2.07s
# 676:	learn: 0.1237027	total: 4.32s	remaining: 2.06s
# 677:	learn: 0.1236755	total: 4.33s	remaining: 2.06s
# 678:	learn: 0.1236515	total: 4.34s	remaining: 2.05s
# 679:	learn: 0.1236248	total: 4.34s	remaining: 2.04s
# 680:	learn: 0.1235953	total: 4.35s	remaining: 2.04s
# 681:	learn: 0.1235653	total: 4.35s	remaining: 2.03s
# 682:	learn: 0.1235494	total: 4.36s	remaining: 2.02s
# 683:	learn: 0.1235313	total: 4.37s	remaining: 2.02s
# 684:	learn: 0.1235140	total: 4.38s	remaining: 2.01s
# 685:	learn: 0.1234918	total: 4.38s	remaining: 2s
# 686:	learn: 0.1234625	total: 4.39s	remaining: 2s
# 687:	learn: 0.1234451	total: 4.39s	remaining: 1.99s
# 688:	learn: 0.1234206	total: 4.4s	remaining: 1.99s
# 689:	learn: 0.1233939	total: 4.41s	remaining: 1.98s
# 690:	learn: 0.1233643	total: 4.41s	remaining: 1.97s
# 691:	learn: 0.1233278	total: 4.42s	remaining: 1.97s
# 692:	learn: 0.1233137	total: 4.42s	remaining: 1.96s
# 693:	learn: 0.1232900	total: 4.43s	remaining: 1.95s
# 694:	learn: 0.1232715	total: 4.44s	remaining: 1.95s
# 695:	learn: 0.1232410	total: 4.44s	remaining: 1.94s
# 696:	learn: 0.1232175	total: 4.45s	remaining: 1.93s
# 697:	learn: 0.1231986	total: 4.46s	remaining: 1.93s
# 698:	learn: 0.1231758	total: 4.46s	remaining: 1.92s
# 699:	learn: 0.1231517	total: 4.47s	remaining: 1.91s
# 700:	learn: 0.1231329	total: 4.47s	remaining: 1.91s
# 701:	learn: 0.1231040	total: 4.48s	remaining: 1.9s
# 702:	learn: 0.1230786	total: 4.49s	remaining: 1.89s
# 703:	learn: 0.1230580	total: 4.49s	remaining: 1.89s
# 704:	learn: 0.1230230	total: 4.5s	remaining: 1.88s
# 705:	learn: 0.1229947	total: 4.5s	remaining: 1.88s
# 706:	learn: 0.1229693	total: 4.51s	remaining: 1.87s
# 707:	learn: 0.1229387	total: 4.51s	remaining: 1.86s
# 708:	learn: 0.1229062	total: 4.52s	remaining: 1.85s
# 709:	learn: 0.1228925	total: 4.53s	remaining: 1.85s
# 710:	learn: 0.1228639	total: 4.53s	remaining: 1.84s
# 711:	learn: 0.1228319	total: 4.54s	remaining: 1.84s
# 712:	learn: 0.1228063	total: 4.55s	remaining: 1.83s
# 713:	learn: 0.1227807	total: 4.55s	remaining: 1.82s
# 714:	learn: 0.1227601	total: 4.56s	remaining: 1.82s
# 715:	learn: 0.1227389	total: 4.57s	remaining: 1.81s
# 716:	learn: 0.1227106	total: 4.58s	remaining: 1.81s
# 717:	learn: 0.1226870	total: 4.58s	remaining: 1.8s
# 718:	learn: 0.1226619	total: 4.59s	remaining: 1.79s
# 719:	learn: 0.1226371	total: 4.59s	remaining: 1.79s
# 720:	learn: 0.1226224	total: 4.6s	remaining: 1.78s
# 721:	learn: 0.1225954	total: 4.61s	remaining: 1.77s
# 722:	learn: 0.1225728	total: 4.61s	remaining: 1.77s
# 723:	learn: 0.1225565	total: 4.62s	remaining: 1.76s
# 724:	learn: 0.1225359	total: 4.62s	remaining: 1.75s
# 725:	learn: 0.1225059	total: 4.63s	remaining: 1.75s
# 726:	learn: 0.1224880	total: 4.65s	remaining: 1.75s
# 727:	learn: 0.1224572	total: 4.66s	remaining: 1.74s
# 728:	learn: 0.1224335	total: 4.66s	remaining: 1.73s
# 729:	learn: 0.1224104	total: 4.67s	remaining: 1.73s
# 730:	learn: 0.1223884	total: 4.68s	remaining: 1.72s
# 731:	learn: 0.1223687	total: 4.68s	remaining: 1.71s
# 732:	learn: 0.1223510	total: 4.69s	remaining: 1.71s
# 733:	learn: 0.1223276	total: 4.7s	remaining: 1.7s
# 734:	learn: 0.1223026	total: 4.7s	remaining: 1.7s
# 735:	learn: 0.1222836	total: 4.71s	remaining: 1.69s
# 736:	learn: 0.1222611	total: 4.71s	remaining: 1.68s
# 737:	learn: 0.1222427	total: 4.72s	remaining: 1.68s
# 738:	learn: 0.1222179	total: 4.72s	remaining: 1.67s
# 739:	learn: 0.1221950	total: 4.73s	remaining: 1.66s
# 740:	learn: 0.1221660	total: 4.74s	remaining: 1.66s
# 741:	learn: 0.1221382	total: 4.74s	remaining: 1.65s
# 742:	learn: 0.1221078	total: 4.75s	remaining: 1.64s
# 743:	learn: 0.1220787	total: 4.76s	remaining: 1.64s
# 744:	learn: 0.1220415	total: 4.76s	remaining: 1.63s
# 745:	learn: 0.1220269	total: 4.77s	remaining: 1.62s
# 746:	learn: 0.1220104	total: 4.78s	remaining: 1.62s
# 747:	learn: 0.1219962	total: 4.78s	remaining: 1.61s
# 748:	learn: 0.1219730	total: 4.79s	remaining: 1.6s
# 749:	learn: 0.1219497	total: 4.79s	remaining: 1.6s
# 750:	learn: 0.1219346	total: 4.8s	remaining: 1.59s
# 751:	learn: 0.1219121	total: 4.81s	remaining: 1.58s
# 752:	learn: 0.1218945	total: 4.81s	remaining: 1.58s
# 753:	learn: 0.1218690	total: 4.82s	remaining: 1.57s
# 754:	learn: 0.1218514	total: 4.83s	remaining: 1.57s
# 755:	learn: 0.1218325	total: 4.83s	remaining: 1.56s
# 756:	learn: 0.1218181	total: 4.84s	remaining: 1.55s
# 757:	learn: 0.1217965	total: 4.85s	remaining: 1.55s
# 758:	learn: 0.1217734	total: 4.85s	remaining: 1.54s
# 759:	learn: 0.1217520	total: 4.86s	remaining: 1.53s
# 760:	learn: 0.1217297	total: 4.86s	remaining: 1.53s
# 761:	learn: 0.1217093	total: 4.87s	remaining: 1.52s
# 762:	learn: 0.1216908	total: 4.88s	remaining: 1.51s
# 763:	learn: 0.1216726	total: 4.88s	remaining: 1.51s
# 764:	learn: 0.1216507	total: 4.89s	remaining: 1.5s
# 765:	learn: 0.1216264	total: 4.89s	remaining: 1.49s
# 766:	learn: 0.1216050	total: 4.9s	remaining: 1.49s
# 767:	learn: 0.1215877	total: 4.91s	remaining: 1.48s
# 768:	learn: 0.1215703	total: 4.91s	remaining: 1.48s
# 769:	learn: 0.1215443	total: 4.92s	remaining: 1.47s
# 770:	learn: 0.1215125	total: 4.92s	remaining: 1.46s
# 771:	learn: 0.1214980	total: 4.93s	remaining: 1.46s
# 772:	learn: 0.1214814	total: 4.94s	remaining: 1.45s
# 773:	learn: 0.1214647	total: 4.94s	remaining: 1.44s
# 774:	learn: 0.1214329	total: 4.95s	remaining: 1.44s
# 775:	learn: 0.1214126	total: 4.95s	remaining: 1.43s
# 776:	learn: 0.1213838	total: 4.96s	remaining: 1.42s
# 777:	learn: 0.1213740	total: 4.97s	remaining: 1.42s
# 778:	learn: 0.1213575	total: 4.98s	remaining: 1.41s
# 779:	learn: 0.1213319	total: 4.98s	remaining: 1.41s
# 780:	learn: 0.1213147	total: 4.99s	remaining: 1.4s
# 781:	learn: 0.1212807	total: 4.99s	remaining: 1.39s
# 782:	learn: 0.1212544	total: 5s	remaining: 1.39s
# 783:	learn: 0.1212339	total: 5s	remaining: 1.38s
# 784:	learn: 0.1212067	total: 5.01s	remaining: 1.37s
# 785:	learn: 0.1211807	total: 5.02s	remaining: 1.37s
# 786:	learn: 0.1211481	total: 5.02s	remaining: 1.36s
# 787:	learn: 0.1211302	total: 5.03s	remaining: 1.35s
# 788:	learn: 0.1210991	total: 5.04s	remaining: 1.35s
# 789:	learn: 0.1210728	total: 5.04s	remaining: 1.34s
# 790:	learn: 0.1210541	total: 5.05s	remaining: 1.33s
# 791:	learn: 0.1210369	total: 5.05s	remaining: 1.33s
# 792:	learn: 0.1210132	total: 5.06s	remaining: 1.32s
# 793:	learn: 0.1209926	total: 5.07s	remaining: 1.31s
# 794:	learn: 0.1209638	total: 5.07s	remaining: 1.31s
# 795:	learn: 0.1209515	total: 5.08s	remaining: 1.3s
# 796:	learn: 0.1209317	total: 5.08s	remaining: 1.29s
# 797:	learn: 0.1209228	total: 5.09s	remaining: 1.29s
# 798:	learn: 0.1208985	total: 5.09s	remaining: 1.28s
# 799:	learn: 0.1208694	total: 5.1s	remaining: 1.27s
# 800:	learn: 0.1208397	total: 5.11s	remaining: 1.27s
# 801:	learn: 0.1208234	total: 5.12s	remaining: 1.26s
# 802:	learn: 0.1208045	total: 5.12s	remaining: 1.26s
# 803:	learn: 0.1207795	total: 5.13s	remaining: 1.25s
# 804:	learn: 0.1207526	total: 5.13s	remaining: 1.24s
# 805:	learn: 0.1207232	total: 5.14s	remaining: 1.24s
# 806:	learn: 0.1207059	total: 5.15s	remaining: 1.23s
# 807:	learn: 0.1206802	total: 5.15s	remaining: 1.22s
# 808:	learn: 0.1206620	total: 5.16s	remaining: 1.22s
# 809:	learn: 0.1206415	total: 5.17s	remaining: 1.21s
# 810:	learn: 0.1206200	total: 5.18s	remaining: 1.21s
# 811:	learn: 0.1205874	total: 5.18s	remaining: 1.2s
# 812:	learn: 0.1205675	total: 5.19s	remaining: 1.19s
# 813:	learn: 0.1205435	total: 5.2s	remaining: 1.19s
# 814:	learn: 0.1205326	total: 5.2s	remaining: 1.18s
# 815:	learn: 0.1205153	total: 5.21s	remaining: 1.17s
# 816:	learn: 0.1205004	total: 5.21s	remaining: 1.17s
# 817:	learn: 0.1204880	total: 5.22s	remaining: 1.16s
# 818:	learn: 0.1204753	total: 5.22s	remaining: 1.15s
# 819:	learn: 0.1204592	total: 5.23s	remaining: 1.15s
# 820:	learn: 0.1204293	total: 5.24s	remaining: 1.14s
# 821:	learn: 0.1203994	total: 5.24s	remaining: 1.14s
# 822:	learn: 0.1203887	total: 5.25s	remaining: 1.13s
# 823:	learn: 0.1203679	total: 5.25s	remaining: 1.12s
# 824:	learn: 0.1203413	total: 5.26s	remaining: 1.11s
# 825:	learn: 0.1203302	total: 5.27s	remaining: 1.11s
# 826:	learn: 0.1203116	total: 5.27s	remaining: 1.1s
# 827:	learn: 0.1202976	total: 5.28s	remaining: 1.1s
# 828:	learn: 0.1202793	total: 5.29s	remaining: 1.09s
# 829:	learn: 0.1202576	total: 5.29s	remaining: 1.08s
# 830:	learn: 0.1202374	total: 5.3s	remaining: 1.08s
# 831:	learn: 0.1202252	total: 5.3s	remaining: 1.07s
# 832:	learn: 0.1201989	total: 5.31s	remaining: 1.06s
# 833:	learn: 0.1201619	total: 5.32s	remaining: 1.06s
# 834:	learn: 0.1201380	total: 5.32s	remaining: 1.05s
# 835:	learn: 0.1201177	total: 5.33s	remaining: 1.04s
# 836:	learn: 0.1200858	total: 5.34s	remaining: 1.04s
# 837:	learn: 0.1200747	total: 5.34s	remaining: 1.03s
# 838:	learn: 0.1200525	total: 5.35s	remaining: 1.03s
# 839:	learn: 0.1200343	total: 5.35s	remaining: 1.02s
# 840:	learn: 0.1200114	total: 5.36s	remaining: 1.01s
# 841:	learn: 0.1200018	total: 5.37s	remaining: 1.01s
# 842:	learn: 0.1199860	total: 5.38s	remaining: 1s
# 843:	learn: 0.1199581	total: 5.38s	remaining: 995ms
# 844:	learn: 0.1199370	total: 5.39s	remaining: 988ms
# 845:	learn: 0.1199219	total: 5.39s	remaining: 982ms
# 846:	learn: 0.1198947	total: 5.4s	remaining: 975ms
# 847:	learn: 0.1198806	total: 5.41s	remaining: 969ms
# 848:	learn: 0.1198549	total: 5.41s	remaining: 963ms
# 849:	learn: 0.1198342	total: 5.42s	remaining: 956ms
# 850:	learn: 0.1198099	total: 5.42s	remaining: 950ms
# 851:	learn: 0.1197854	total: 5.43s	remaining: 943ms
# 852:	learn: 0.1197633	total: 5.44s	remaining: 937ms
# 853:	learn: 0.1197525	total: 5.44s	remaining: 931ms
# 854:	learn: 0.1197376	total: 5.45s	remaining: 924ms
# 855:	learn: 0.1197099	total: 5.46s	remaining: 918ms
# 856:	learn: 0.1196870	total: 5.46s	remaining: 911ms
# 857:	learn: 0.1196633	total: 5.47s	remaining: 905ms
# 858:	learn: 0.1196457	total: 5.47s	remaining: 898ms
# 859:	learn: 0.1196229	total: 5.48s	remaining: 892ms
# 860:	learn: 0.1195997	total: 5.49s	remaining: 886ms
# 861:	learn: 0.1195795	total: 5.49s	remaining: 879ms
# 862:	learn: 0.1195456	total: 5.5s	remaining: 873ms
# 863:	learn: 0.1195344	total: 5.5s	remaining: 866ms
# 864:	learn: 0.1195290	total: 5.51s	remaining: 860ms
# 865:	learn: 0.1195099	total: 5.51s	remaining: 853ms
# 866:	learn: 0.1194875	total: 5.52s	remaining: 847ms
# 867:	learn: 0.1194635	total: 5.53s	remaining: 841ms
# 868:	learn: 0.1194475	total: 5.53s	remaining: 834ms
# 869:	learn: 0.1194203	total: 5.54s	remaining: 828ms
# 870:	learn: 0.1194071	total: 5.54s	remaining: 821ms
# 871:	learn: 0.1193845	total: 5.55s	remaining: 815ms
# 872:	learn: 0.1193653	total: 5.56s	remaining: 808ms
# 873:	learn: 0.1193401	total: 5.56s	remaining: 802ms
# 874:	learn: 0.1193189	total: 5.57s	remaining: 796ms
# 875:	learn: 0.1193008	total: 5.58s	remaining: 790ms
# 876:	learn: 0.1192778	total: 5.58s	remaining: 783ms
# 877:	learn: 0.1192656	total: 5.59s	remaining: 777ms
# 878:	learn: 0.1192244	total: 5.6s	remaining: 770ms
# 879:	learn: 0.1192084	total: 5.6s	remaining: 764ms
# 880:	learn: 0.1191944	total: 5.61s	remaining: 758ms
# 881:	learn: 0.1191537	total: 5.61s	remaining: 751ms
# 882:	learn: 0.1191388	total: 5.62s	remaining: 745ms
# 883:	learn: 0.1191292	total: 5.63s	remaining: 739ms
# 884:	learn: 0.1191059	total: 5.65s	remaining: 734ms
# 885:	learn: 0.1190862	total: 5.65s	remaining: 727ms
# 886:	learn: 0.1190672	total: 5.66s	remaining: 721ms
# 887:	learn: 0.1190454	total: 5.67s	remaining: 715ms
# 888:	learn: 0.1190124	total: 5.67s	remaining: 708ms
# 889:	learn: 0.1189964	total: 5.68s	remaining: 702ms
# 890:	learn: 0.1189791	total: 5.68s	remaining: 695ms
# 891:	learn: 0.1189571	total: 5.69s	remaining: 689ms
# 892:	learn: 0.1189413	total: 5.69s	remaining: 682ms
# 893:	learn: 0.1189164	total: 5.7s	remaining: 676ms
# 894:	learn: 0.1188997	total: 5.71s	remaining: 670ms
# 895:	learn: 0.1188764	total: 5.71s	remaining: 663ms
# 896:	learn: 0.1188552	total: 5.72s	remaining: 657ms
# 897:	learn: 0.1188378	total: 5.72s	remaining: 650ms
# 898:	learn: 0.1188201	total: 5.73s	remaining: 644ms
# 899:	learn: 0.1187947	total: 5.74s	remaining: 637ms
# 900:	learn: 0.1187725	total: 5.74s	remaining: 631ms
# 901:	learn: 0.1187561	total: 5.75s	remaining: 625ms
# 902:	learn: 0.1187339	total: 5.75s	remaining: 618ms
# 903:	learn: 0.1187158	total: 5.76s	remaining: 612ms
# 904:	learn: 0.1186885	total: 5.77s	remaining: 606ms
# 905:	learn: 0.1186696	total: 5.78s	remaining: 599ms
# 906:	learn: 0.1186505	total: 5.78s	remaining: 593ms
# 907:	learn: 0.1186362	total: 5.79s	remaining: 587ms
# 908:	learn: 0.1186029	total: 5.8s	remaining: 581ms
# 909:	learn: 0.1185774	total: 5.81s	remaining: 574ms
# 910:	learn: 0.1185565	total: 5.81s	remaining: 568ms
# 911:	learn: 0.1185380	total: 5.82s	remaining: 561ms
# 912:	learn: 0.1185084	total: 5.83s	remaining: 555ms
# 913:	learn: 0.1184874	total: 5.83s	remaining: 549ms
# 914:	learn: 0.1184684	total: 5.84s	remaining: 542ms
# 915:	learn: 0.1184340	total: 5.84s	remaining: 536ms
# 916:	learn: 0.1184106	total: 5.85s	remaining: 529ms
# 917:	learn: 0.1183874	total: 5.86s	remaining: 523ms
# 918:	learn: 0.1183645	total: 5.86s	remaining: 517ms
# 919:	learn: 0.1183417	total: 5.87s	remaining: 510ms
# 920:	learn: 0.1183107	total: 5.87s	remaining: 504ms
# 921:	learn: 0.1182880	total: 5.88s	remaining: 497ms
# 922:	learn: 0.1182738	total: 5.89s	remaining: 491ms
# 923:	learn: 0.1182413	total: 5.89s	remaining: 485ms
# 924:	learn: 0.1182015	total: 5.9s	remaining: 478ms
# 925:	learn: 0.1181827	total: 5.91s	remaining: 472ms
# 926:	learn: 0.1181599	total: 5.91s	remaining: 466ms
# 927:	learn: 0.1181362	total: 5.92s	remaining: 459ms
# 928:	learn: 0.1181217	total: 5.92s	remaining: 453ms
# 929:	learn: 0.1180991	total: 5.93s	remaining: 446ms
# 930:	learn: 0.1180802	total: 5.93s	remaining: 440ms
# 931:	learn: 0.1180573	total: 5.94s	remaining: 434ms
# 932:	learn: 0.1180429	total: 5.95s	remaining: 427ms
# 933:	learn: 0.1180132	total: 5.95s	remaining: 421ms
# 934:	learn: 0.1179896	total: 5.96s	remaining: 414ms
# 935:	learn: 0.1179757	total: 5.97s	remaining: 408ms
# 936:	learn: 0.1179583	total: 5.98s	remaining: 402ms
# 937:	learn: 0.1179413	total: 5.98s	remaining: 395ms
# 938:	learn: 0.1179157	total: 5.99s	remaining: 389ms
# 939:	learn: 0.1178856	total: 5.99s	remaining: 383ms
# 940:	learn: 0.1178619	total: 6s	remaining: 376ms
# 941:	learn: 0.1178386	total: 6.01s	remaining: 370ms
# 942:	learn: 0.1178186	total: 6.01s	remaining: 363ms
# 943:	learn: 0.1177906	total: 6.02s	remaining: 357ms
# 944:	learn: 0.1177717	total: 6.02s	remaining: 351ms
# 945:	learn: 0.1177482	total: 6.03s	remaining: 344ms
# 946:	learn: 0.1177276	total: 6.04s	remaining: 338ms
# 947:	learn: 0.1177159	total: 6.04s	remaining: 331ms
# 948:	learn: 0.1177030	total: 6.05s	remaining: 325ms
# 949:	learn: 0.1176830	total: 6.05s	remaining: 319ms
# 950:	learn: 0.1176742	total: 6.06s	remaining: 312ms
# 951:	learn: 0.1176515	total: 6.07s	remaining: 306ms
# 952:	learn: 0.1176319	total: 6.07s	remaining: 299ms
# 953:	learn: 0.1176091	total: 6.08s	remaining: 293ms
# 954:	learn: 0.1175804	total: 6.08s	remaining: 287ms
# 955:	learn: 0.1175577	total: 6.09s	remaining: 280ms
# 956:	learn: 0.1175360	total: 6.1s	remaining: 274ms
# 957:	learn: 0.1175153	total: 6.1s	remaining: 268ms
# 958:	learn: 0.1174883	total: 6.11s	remaining: 261ms
# 959:	learn: 0.1174725	total: 6.12s	remaining: 255ms
# 960:	learn: 0.1174595	total: 6.12s	remaining: 248ms
# 961:	learn: 0.1174342	total: 6.13s	remaining: 242ms
# 962:	learn: 0.1174205	total: 6.13s	remaining: 236ms
# 963:	learn: 0.1173978	total: 6.14s	remaining: 229ms
# 964:	learn: 0.1173783	total: 6.15s	remaining: 223ms
# 965:	learn: 0.1173597	total: 6.15s	remaining: 217ms
# 966:	learn: 0.1173407	total: 6.16s	remaining: 210ms
# 967:	learn: 0.1173190	total: 6.17s	remaining: 204ms
# 968:	learn: 0.1172959	total: 6.17s	remaining: 198ms
# 969:	learn: 0.1172788	total: 6.18s	remaining: 191ms
# 970:	learn: 0.1172615	total: 6.19s	remaining: 185ms
# 971:	learn: 0.1172388	total: 6.19s	remaining: 178ms
# 972:	learn: 0.1172216	total: 6.2s	remaining: 172ms
# 973:	learn: 0.1171999	total: 6.21s	remaining: 166ms
# 974:	learn: 0.1171832	total: 6.21s	remaining: 159ms
# 975:	learn: 0.1171592	total: 6.22s	remaining: 153ms
# 976:	learn: 0.1171370	total: 6.22s	remaining: 147ms
# 977:	learn: 0.1171065	total: 6.23s	remaining: 140ms
# 978:	learn: 0.1170876	total: 6.24s	remaining: 134ms
# 979:	learn: 0.1170673	total: 6.24s	remaining: 127ms
# 980:	learn: 0.1170425	total: 6.25s	remaining: 121ms
# 981:	learn: 0.1170294	total: 6.25s	remaining: 115ms
# 982:	learn: 0.1170115	total: 6.26s	remaining: 108ms
# 983:	learn: 0.1169903	total: 6.27s	remaining: 102ms
# 984:	learn: 0.1169710	total: 6.28s	remaining: 95.6ms
# 985:	learn: 0.1169501	total: 6.28s	remaining: 89.2ms
# 986:	learn: 0.1169300	total: 6.29s	remaining: 82.8ms
# 987:	learn: 0.1169155	total: 6.29s	remaining: 76.4ms
# 988:	learn: 0.1169014	total: 6.3s	remaining: 70.1ms
# 989:	learn: 0.1168901	total: 6.3s	remaining: 63.7ms
# 990:	learn: 0.1168765	total: 6.31s	remaining: 57.3ms
# 991:	learn: 0.1168574	total: 6.32s	remaining: 51ms
# 992:	learn: 0.1168394	total: 6.32s	remaining: 44.6ms
# 993:	learn: 0.1168238	total: 6.33s	remaining: 38.2ms
# 994:	learn: 0.1167996	total: 6.33s	remaining: 31.8ms
# 995:	learn: 0.1167743	total: 6.34s	remaining: 25.5ms
# 996:	learn: 0.1167543	total: 6.35s	remaining: 19.1ms
# 997:	learn: 0.1167278	total: 6.35s	remaining: 12.7ms
# 998:	learn: 0.1166917	total: 6.36s	remaining: 6.37ms
# 999:	learn: 0.1166778	total: 6.37s	remaining: 0us

# %%
evaluate_model_performance(validation_set_cp, Catboost_model)
# Out:
# MAE: 0.1639841185900714
# MSE: 0.04772501464642009
# RMSE: 0.21846055627142416
# R²: 0.16694468119880124
# Predições do modelo:
# [0.40044244 0.75679468 0.39160545 ... 0.38727437 0.55431771 0.73422476]

# %%
cross_validation(validation_set_cp, Catboost_model)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 8:	learn: 0.2209719	total: 35ms	remaining: 3.86s
# 9:	learn: 0.2194245	total: 38.8ms	remaining: 3.84s
# 10:	learn: 0.2183232	total: 42.6ms	remaining: 3.83s
# 11:	learn: 0.2171080	total: 46.3ms	remaining: 3.81s
# 12:	learn: 0.2158103	total: 50.5ms	remaining: 3.83s
# 13:	learn: 0.2147349	total: 54.3ms	remaining: 3.82s
# 14:	learn: 0.2135207	total: 58.3ms	remaining: 3.83s
# 15:	learn: 0.2127059	total: 62.3ms	remaining: 3.83s
# 16:	learn: 0.2116312	total: 66.4ms	remaining: 3.84s
# 17:	learn: 0.2108446	total: 75.5ms	remaining: 4.12s
# 18:	learn: 0.2100823	total: 82.4ms	remaining: 4.25s
# 19:	learn: 0.2094460	total: 85.8ms	remaining: 4.21s
# 20:	learn: 0.2087146	total: 89.6ms	remaining: 4.18s
# 21:	learn: 0.2081866	total: 93.4ms	remaining: 4.15s
# 22:	learn: 0.2075231	total: 97.2ms	remaining: 4.13s
# 23:	learn: 0.2068985	total: 101ms	remaining: 4.1s
# 24:	learn: 0.2063173	total: 105ms	remaining: 4.08s
# 25:	learn: 0.2056435	total: 108ms	remaining: 4.06s
# 26:	learn: 0.2050163	total: 114ms	remaining: 4.11s
# 27:	learn: 0.2045739	total: 121ms	remaining: 4.19s
# 28:	learn: 0.2040529	total: 124ms	remaining: 4.17s
# 29:	learn: 0.2036365	total: 128ms	remaining: 4.15s
# 30:	learn: 0.2032159	total: 132ms	remaining: 4.13s
# 31:	learn: 0.2029008	total: 136ms	remaining: 4.1s
# 32:	learn: 0.2026134	total: 140ms	remaining: 4.09s
# 33:	learn: 0.2022776	total: 143ms	remaining: 4.07s
# 34:	learn: 0.2019699	total: 147ms	remaining: 4.05s
# 35:	learn: 0.2015055	total: 151ms	remaining: 4.03s
# 36:	learn: 0.2012392	total: 155ms	remaining: 4.02s
# 37:	learn: 0.2009294	total: 158ms	remaining: 4.01s
# 38:	learn: 0.2005967	total: 162ms	remaining: 4s
# 39:	learn: 0.2003327	total: 166ms	remaining: 3.99s
# 40:	learn: 0.2000087	total: 170ms	remaining: 3.98s
# 41:	learn: 0.1996931	total: 174ms	remaining: 3.96s
# 42:	learn: 0.1994104	total: 178ms	remaining: 3.96s
# 43:	learn: 0.1991395	total: 182ms	remaining: 3.95s
# 44:	learn: 0.1988337	total: 186ms	remaining: 3.94s
# 45:	learn: 0.1985404	total: 189ms	remaining: 3.92s
# 46:	learn: 0.1983165	total: 193ms	remaining: 3.91s
# 47:	learn: 0.1980555	total: 197ms	remaining: 3.9s
# 48:	learn: 0.1978030	total: 200ms	remaining: 3.89s
# 49:	learn: 0.1975482	total: 204ms	remaining: 3.88s
# 50:	learn: 0.1972931	total: 208ms	remaining: 3.87s
# 51:	learn: 0.1971098	total: 212ms	remaining: 3.86s
# 52:	learn: 0.1968860	total: 215ms	remaining: 3.85s
# 53:	learn: 0.1966652	total: 219ms	remaining: 3.84s
# 54:	learn: 0.1964322	total: 223ms	remaining: 3.83s
# 55:	learn: 0.1961552	total: 226ms	remaining: 3.82s
# 56:	learn: 0.1959289	total: 230ms	remaining: 3.81s
# 57:	learn: 0.1957725	total: 234ms	remaining: 3.8s
# 58:	learn: 0.1955625	total: 238ms	remaining: 3.79s
# 59:	learn: 0.1952578	total: 241ms	remaining: 3.78s
# 60:	learn: 0.1950399	total: 245ms	remaining: 3.77s
# 61:	learn: 0.1948382	total: 249ms	remaining: 3.77s
# 62:	learn: 0.1946188	total: 253ms	remaining: 3.76s
# 63:	learn: 0.1944269	total: 256ms	remaining: 3.75s
# 64:	learn: 0.1942568	total: 260ms	remaining: 3.74s
# 65:	learn: 0.1940264	total: 264ms	remaining: 3.73s
# 66:	learn: 0.1937654	total: 273ms	remaining: 3.8s
# 67:	learn: 0.1935758	total: 278ms	remaining: 3.81s
# 68:	learn: 0.1934236	total: 282ms	remaining: 3.8s
# 69:	learn: 0.1932515	total: 285ms	remaining: 3.79s
# 70:	learn: 0.1931510	total: 289ms	remaining: 3.78s
# 71:	learn: 0.1929371	total: 293ms	remaining: 3.77s
# 72:	learn: 0.1928019	total: 296ms	remaining: 3.76s
# 73:	learn: 0.1926738	total: 300ms	remaining: 3.75s
# 74:	learn: 0.1924907	total: 304ms	remaining: 3.75s
# 75:	learn: 0.1922934	total: 308ms	remaining: 3.74s
# 76:	learn: 0.1920686	total: 312ms	remaining: 3.73s
# 77:	learn: 0.1919380	total: 315ms	remaining: 3.73s
# 78:	learn: 0.1917177	total: 319ms	remaining: 3.72s
# 79:	learn: 0.1915938	total: 323ms	remaining: 3.71s
# 80:	learn: 0.1914567	total: 326ms	remaining: 3.7s
# 81:	learn: 0.1912368	total: 333ms	remaining: 3.73s
# 82:	learn: 0.1910280	total: 343ms	remaining: 3.79s
# 83:	learn: 0.1908150	total: 357ms	remaining: 3.9s
# 84:	learn: 0.1906604	total: 368ms	remaining: 3.96s
# 85:	learn: 0.1905360	total: 375ms	remaining: 3.99s
# 86:	learn: 0.1903665	total: 379ms	remaining: 3.98s
# 87:	learn: 0.1901659	total: 384ms	remaining: 3.98s
# 88:	learn: 0.1899649	total: 388ms	remaining: 3.97s
# 89:	learn: 0.1898534	total: 392ms	remaining: 3.96s
# 90:	learn: 0.1897157	total: 396ms	remaining: 3.95s
# 91:	learn: 0.1895820	total: 400ms	remaining: 3.94s
# 92:	learn: 0.1895236	total: 404ms	remaining: 3.94s
# 93:	learn: 0.1893806	total: 407ms	remaining: 3.92s
# 94:	learn: 0.1892071	total: 411ms	remaining: 3.91s
# 95:	learn: 0.1890595	total: 415ms	remaining: 3.9s
# 96:	learn: 0.1889470	total: 418ms	remaining: 3.89s
# 97:	learn: 0.1887605	total: 422ms	remaining: 3.88s
# 98:	learn: 0.1885955	total: 426ms	remaining: 3.88s
# 99:	learn: 0.1884547	total: 430ms	remaining: 3.87s
# 100:	learn: 0.1883045	total: 434ms	remaining: 3.86s
# 101:	learn: 0.1881926	total: 437ms	remaining: 3.85s
# 102:	learn: 0.1880845	total: 441ms	remaining: 3.84s
# 103:	learn: 0.1879334	total: 445ms	remaining: 3.83s
# 104:	learn: 0.1878208	total: 448ms	remaining: 3.82s
# 105:	learn: 0.1876975	total: 452ms	remaining: 3.81s
# 106:	learn: 0.1875071	total: 456ms	remaining: 3.8s
# 107:	learn: 0.1873914	total: 459ms	remaining: 3.79s
# 108:	learn: 0.1871730	total: 463ms	remaining: 3.78s
# 109:	learn: 0.1870363	total: 469ms	remaining: 3.8s
# 110:	learn: 0.1869012	total: 479ms	remaining: 3.84s
# 111:	learn: 0.1867781	total: 484ms	remaining: 3.84s
# 112:	learn: 0.1866630	total: 488ms	remaining: 3.83s
# 113:	learn: 0.1865555	total: 491ms	remaining: 3.82s
# 114:	learn: 0.1864242	total: 495ms	remaining: 3.81s
# 115:	learn: 0.1862653	total: 498ms	remaining: 3.8s
# 116:	learn: 0.1860598	total: 502ms	remaining: 3.79s
# 117:	learn: 0.1859498	total: 505ms	remaining: 3.78s
# 118:	learn: 0.1857574	total: 511ms	remaining: 3.78s
# 119:	learn: 0.1856300	total: 516ms	remaining: 3.78s
# 120:	learn: 0.1854880	total: 519ms	remaining: 3.77s
# 121:	learn: 0.1853715	total: 522ms	remaining: 3.76s
# 122:	learn: 0.1852724	total: 526ms	remaining: 3.75s
# 123:	learn: 0.1852012	total: 529ms	remaining: 3.74s
# 124:	learn: 0.1851139	total: 533ms	remaining: 3.73s
# 125:	learn: 0.1849504	total: 536ms	remaining: 3.72s
# 126:	learn: 0.1848548	total: 540ms	remaining: 3.71s
# 127:	learn: 0.1847705	total: 544ms	remaining: 3.71s
# 128:	learn: 0.1846148	total: 548ms	remaining: 3.7s
# 129:	learn: 0.1844305	total: 552ms	remaining: 3.69s
# 130:	learn: 0.1842902	total: 555ms	remaining: 3.68s
# 131:	learn: 0.1841221	total: 559ms	remaining: 3.67s
# 132:	learn: 0.1840330	total: 563ms	remaining: 3.67s
# 133:	learn: 0.1839204	total: 566ms	remaining: 3.66s
# 134:	learn: 0.1837760	total: 570ms	remaining: 3.65s
# 135:	learn: 0.1837036	total: 574ms	remaining: 3.64s
# 136:	learn: 0.1835893	total: 577ms	remaining: 3.64s
# 137:	learn: 0.1834840	total: 581ms	remaining: 3.63s
# 138:	learn: 0.1833066	total: 585ms	remaining: 3.62s
# 139:	learn: 0.1831834	total: 589ms	remaining: 3.62s
# 140:	learn: 0.1830926	total: 593ms	remaining: 3.61s
# 141:	learn: 0.1829802	total: 597ms	remaining: 3.61s
# 142:	learn: 0.1828944	total: 601ms	remaining: 3.6s
# 143:	learn: 0.1828087	total: 604ms	remaining: 3.59s
# 144:	learn: 0.1826829	total: 608ms	remaining: 3.58s
# 145:	learn: 0.1825787	total: 611ms	remaining: 3.58s
# 146:	learn: 0.1824528	total: 615ms	remaining: 3.57s
# 147:	learn: 0.1823342	total: 619ms	remaining: 3.56s
# 148:	learn: 0.1822258	total: 622ms	remaining: 3.55s
# 149:	learn: 0.1820837	total: 626ms	remaining: 3.55s
# 150:	learn: 0.1819463	total: 630ms	remaining: 3.54s
# 151:	learn: 0.1818823	total: 638ms	remaining: 3.56s
# 152:	learn: 0.1817732	total: 645ms	remaining: 3.57s
# 153:	learn: 0.1816154	total: 649ms	remaining: 3.57s
# 154:	learn: 0.1814527	total: 656ms	remaining: 3.58s
# 155:	learn: 0.1813609	total: 664ms	remaining: 3.59s
# 156:	learn: 0.1812438	total: 672ms	remaining: 3.6s
# 157:	learn: 0.1811641	total: 676ms	remaining: 3.6s
# 158:	learn: 0.1810729	total: 680ms	remaining: 3.6s
# 159:	learn: 0.1809403	total: 684ms	remaining: 3.59s
# 160:	learn: 0.1808199	total: 688ms	remaining: 3.58s
# 161:	learn: 0.1806330	total: 691ms	remaining: 3.58s
# 162:	learn: 0.1805456	total: 695ms	remaining: 3.57s
# 163:	learn: 0.1804438	total: 699ms	remaining: 3.56s
# 164:	learn: 0.1802280	total: 702ms	remaining: 3.55s
# 165:	learn: 0.1801017	total: 706ms	remaining: 3.55s
# 166:	learn: 0.1800213	total: 710ms	remaining: 3.54s
# 167:	learn: 0.1799443	total: 713ms	remaining: 3.53s
# 168:	learn: 0.1798791	total: 717ms	remaining: 3.52s
# 169:	learn: 0.1797324	total: 721ms	remaining: 3.52s
# 170:	learn: 0.1796161	total: 726ms	remaining: 3.52s
# 171:	learn: 0.1794764	total: 729ms	remaining: 3.51s
# 172:	learn: 0.1793897	total: 733ms	remaining: 3.5s
# 173:	learn: 0.1792560	total: 737ms	remaining: 3.5s
# 174:	learn: 0.1791064	total: 740ms	remaining: 3.49s
# 175:	learn: 0.1790136	total: 744ms	remaining: 3.48s
# 176:	learn: 0.1788959	total: 748ms	remaining: 3.48s
# 177:	learn: 0.1787914	total: 751ms	remaining: 3.47s
# 178:	learn: 0.1786016	total: 755ms	remaining: 3.46s
# 179:	learn: 0.1785276	total: 758ms	remaining: 3.45s
# 180:	learn: 0.1784307	total: 762ms	remaining: 3.45s
# 181:	learn: 0.1782915	total: 766ms	remaining: 3.44s
# 182:	learn: 0.1781535	total: 769ms	remaining: 3.43s
# 183:	learn: 0.1780172	total: 773ms	remaining: 3.43s
# 184:	learn: 0.1779205	total: 776ms	remaining: 3.42s
# 185:	learn: 0.1778053	total: 780ms	remaining: 3.41s
# 186:	learn: 0.1776982	total: 783ms	remaining: 3.41s
# 187:	learn: 0.1775841	total: 790ms	remaining: 3.41s
# 188:	learn: 0.1774961	total: 796ms	remaining: 3.42s
# 189:	learn: 0.1774054	total: 801ms	remaining: 3.42s
# 190:	learn: 0.1772662	total: 805ms	remaining: 3.41s
# 191:	learn: 0.1771270	total: 809ms	remaining: 3.4s
# 192:	learn: 0.1770761	total: 813ms	remaining: 3.4s
# 193:	learn: 0.1769689	total: 816ms	remaining: 3.39s
# 194:	learn: 0.1768229	total: 820ms	remaining: 3.38s
# 195:	learn: 0.1767171	total: 824ms	remaining: 3.38s
# 196:	learn: 0.1766055	total: 828ms	remaining: 3.37s
# 197:	learn: 0.1765053	total: 831ms	remaining: 3.37s
# 198:	learn: 0.1763636	total: 835ms	remaining: 3.36s
# 199:	learn: 0.1762167	total: 838ms	remaining: 3.35s
# 200:	learn: 0.1760817	total: 842ms	remaining: 3.35s
# 201:	learn: 0.1759500	total: 846ms	remaining: 3.34s
# 202:	learn: 0.1757546	total: 849ms	remaining: 3.33s
# 203:	learn: 0.1756918	total: 853ms	remaining: 3.33s
# 204:	learn: 0.1754965	total: 857ms	remaining: 3.32s
# 205:	learn: 0.1753138	total: 864ms	remaining: 3.33s
# 206:	learn: 0.1752213	total: 869ms	remaining: 3.33s
# 207:	learn: 0.1751037	total: 878ms	remaining: 3.34s
# 208:	learn: 0.1749966	total: 882ms	remaining: 3.34s
# 209:	learn: 0.1749075	total: 886ms	remaining: 3.33s
# 210:	learn: 0.1748126	total: 889ms	remaining: 3.33s
# 211:	learn: 0.1746797	total: 893ms	remaining: 3.32s
# 212:	learn: 0.1745456	total: 897ms	remaining: 3.31s
# 213:	learn: 0.1743817	total: 901ms	remaining: 3.31s
# 214:	learn: 0.1742894	total: 904ms	remaining: 3.3s
# 215:	learn: 0.1741730	total: 908ms	remaining: 3.29s
# 216:	learn: 0.1740032	total: 912ms	remaining: 3.29s
# 217:	learn: 0.1738333	total: 916ms	remaining: 3.28s
# 218:	learn: 0.1737129	total: 920ms	remaining: 3.28s
# 219:	learn: 0.1736261	total: 923ms	remaining: 3.27s
# 220:	learn: 0.1735248	total: 927ms	remaining: 3.27s
# 221:	learn: 0.1734192	total: 931ms	remaining: 3.26s
# 222:	learn: 0.1733401	total: 934ms	remaining: 3.25s
# 223:	learn: 0.1732409	total: 938ms	remaining: 3.25s
# 224:	learn: 0.1730524	total: 941ms	remaining: 3.24s
# 225:	learn: 0.1729471	total: 945ms	remaining: 3.23s
# 226:	learn: 0.1728450	total: 948ms	remaining: 3.23s
# 227:	learn: 0.1726934	total: 952ms	remaining: 3.22s
# 228:	learn: 0.1725940	total: 956ms	remaining: 3.22s
# 229:	learn: 0.1724520	total: 959ms	remaining: 3.21s
# 230:	learn: 0.1723553	total: 963ms	remaining: 3.21s
# 231:	learn: 0.1722617	total: 967ms	remaining: 3.2s
# 232:	learn: 0.1721062	total: 970ms	remaining: 3.19s
# 233:	learn: 0.1719630	total: 974ms	remaining: 3.19s
# 234:	learn: 0.1717615	total: 978ms	remaining: 3.18s
# 235:	learn: 0.1716873	total: 982ms	remaining: 3.18s
# 236:	learn: 0.1715365	total: 985ms	remaining: 3.17s
# 237:	learn: 0.1714301	total: 989ms	remaining: 3.17s
# 238:	learn: 0.1712792	total: 993ms	remaining: 3.16s
# 239:	learn: 0.1711985	total: 996ms	remaining: 3.15s
# 240:	learn: 0.1710663	total: 1000ms	remaining: 3.15s
# 241:	learn: 0.1709773	total: 1s	remaining: 3.14s
# 242:	learn: 0.1708858	total: 1.01s	remaining: 3.14s
# 243:	learn: 0.1708017	total: 1.01s	remaining: 3.13s
# 244:	learn: 0.1707375	total: 1.01s	remaining: 3.13s
# 245:	learn: 0.1705712	total: 1.02s	remaining: 3.12s
# 246:	learn: 0.1704212	total: 1.02s	remaining: 3.12s
# 247:	learn: 0.1703140	total: 1.02s	remaining: 3.11s
# 248:	learn: 0.1701620	total: 1.03s	remaining: 3.1s
# 249:	learn: 0.1700118	total: 1.03s	remaining: 3.1s
# 250:	learn: 0.1698716	total: 1.04s	remaining: 3.09s
# 251:	learn: 0.1697099	total: 1.04s	remaining: 3.09s
# 252:	learn: 0.1695376	total: 1.04s	remaining: 3.08s
# 253:	learn: 0.1694206	total: 1.05s	remaining: 3.08s
# 254:	learn: 0.1693345	total: 1.05s	remaining: 3.07s
# 255:	learn: 0.1692580	total: 1.05s	remaining: 3.07s
# 256:	learn: 0.1690892	total: 1.06s	remaining: 3.07s
# 257:	learn: 0.1689552	total: 1.07s	remaining: 3.08s
# 258:	learn: 0.1688758	total: 1.07s	remaining: 3.07s
# 259:	learn: 0.1687616	total: 1.08s	remaining: 3.07s
# 260:	learn: 0.1686673	total: 1.08s	remaining: 3.06s
# 261:	learn: 0.1685350	total: 1.08s	remaining: 3.06s
# 262:	learn: 0.1684563	total: 1.09s	remaining: 3.05s
# 263:	learn: 0.1683065	total: 1.09s	remaining: 3.05s
# 264:	learn: 0.1682128	total: 1.1s	remaining: 3.04s
# 265:	learn: 0.1681163	total: 1.1s	remaining: 3.04s
# 266:	learn: 0.1679995	total: 1.1s	remaining: 3.03s
# 267:	learn: 0.1678539	total: 1.11s	remaining: 3.03s
# 268:	learn: 0.1677667	total: 1.11s	remaining: 3.02s
# 269:	learn: 0.1676604	total: 1.11s	remaining: 3.02s
# 270:	learn: 0.1675829	total: 1.12s	remaining: 3.01s
# 271:	learn: 0.1674494	total: 1.12s	remaining: 3s
# 272:	learn: 0.1673036	total: 1.13s	remaining: 3s
# 273:	learn: 0.1671655	total: 1.13s	remaining: 3s
# 274:	learn: 0.1670700	total: 1.13s	remaining: 2.99s
# 275:	learn: 0.1669663	total: 1.14s	remaining: 2.98s
# 276:	learn: 0.1668235	total: 1.14s	remaining: 2.98s
# 277:	learn: 0.1667361	total: 1.15s	remaining: 2.97s
# 278:	learn: 0.1665675	total: 1.15s	remaining: 2.97s
# 279:	learn: 0.1664997	total: 1.15s	remaining: 2.96s
# 280:	learn: 0.1663418	total: 1.16s	remaining: 2.96s
# 281:	learn: 0.1662483	total: 1.16s	remaining: 2.95s
# 282:	learn: 0.1661050	total: 1.16s	remaining: 2.95s
# 283:	learn: 0.1660679	total: 1.17s	remaining: 2.94s
# 284:	learn: 0.1660131	total: 1.17s	remaining: 2.94s
# 285:	learn: 0.1658854	total: 1.17s	remaining: 2.93s
# 286:	learn: 0.1657829	total: 1.18s	remaining: 2.93s
# 287:	learn: 0.1656849	total: 1.18s	remaining: 2.92s
# 288:	learn: 0.1655344	total: 1.19s	remaining: 2.92s
# 289:	learn: 0.1655017	total: 1.19s	remaining: 2.91s
# 290:	learn: 0.1654000	total: 1.19s	remaining: 2.9s
# 291:	learn: 0.1652672	total: 1.2s	remaining: 2.9s
# 292:	learn: 0.1651295	total: 1.2s	remaining: 2.9s
# 293:	learn: 0.1650029	total: 1.2s	remaining: 2.89s
# 294:	learn: 0.1649429	total: 1.21s	remaining: 2.88s
# 295:	learn: 0.1649096	total: 1.21s	remaining: 2.88s
# 296:	learn: 0.1647488	total: 1.21s	remaining: 2.88s
# 297:	learn: 0.1646614	total: 1.22s	remaining: 2.87s
# 298:	learn: 0.1645807	total: 1.22s	remaining: 2.86s
# 299:	learn: 0.1644529	total: 1.23s	remaining: 2.86s
# 300:	learn: 0.1643514	total: 1.23s	remaining: 2.85s
# 301:	learn: 0.1642317	total: 1.23s	remaining: 2.85s
# 302:	learn: 0.1640801	total: 1.24s	remaining: 2.84s
# 303:	learn: 0.1639565	total: 1.24s	remaining: 2.84s
# 304:	learn: 0.1639276	total: 1.24s	remaining: 2.83s
# 305:	learn: 0.1638276	total: 1.25s	remaining: 2.83s
# 306:	learn: 0.1637465	total: 1.25s	remaining: 2.82s
# 307:	learn: 0.1636110	total: 1.25s	remaining: 2.82s
# 308:	learn: 0.1634809	total: 1.26s	remaining: 2.82s
# 309:	learn: 0.1633712	total: 1.26s	remaining: 2.82s
# 310:	learn: 0.1633407	total: 1.27s	remaining: 2.82s
# 311:	learn: 0.1632162	total: 1.28s	remaining: 2.82s
# 312:	learn: 0.1630974	total: 1.28s	remaining: 2.82s
# 313:	learn: 0.1629686	total: 1.29s	remaining: 2.81s
# 314:	learn: 0.1628390	total: 1.29s	remaining: 2.81s
# 315:	learn: 0.1626824	total: 1.29s	remaining: 2.8s
# 316:	learn: 0.1625352	total: 1.3s	remaining: 2.8s
# 317:	learn: 0.1624996	total: 1.3s	remaining: 2.79s
# 318:	learn: 0.1623791	total: 1.3s	remaining: 2.79s
# 319:	learn: 0.1622430	total: 1.31s	remaining: 2.78s
# 320:	learn: 0.1621037	total: 1.31s	remaining: 2.78s
# 321:	learn: 0.1620044	total: 1.32s	remaining: 2.77s
# 322:	learn: 0.1618159	total: 1.32s	remaining: 2.77s
# 323:	learn: 0.1617327	total: 1.32s	remaining: 2.76s
# 324:	learn: 0.1616125	total: 1.33s	remaining: 2.76s
# 325:	learn: 0.1615007	total: 1.33s	remaining: 2.75s
# 326:	learn: 0.1614624	total: 1.33s	remaining: 2.75s
# 327:	learn: 0.1613064	total: 1.34s	remaining: 2.74s
# 328:	learn: 0.1611816	total: 1.34s	remaining: 2.74s
# 329:	learn: 0.1609634	total: 1.34s	remaining: 2.73s
# 330:	learn: 0.1608766	total: 1.35s	remaining: 2.73s
# 331:	learn: 0.1608030	total: 1.35s	remaining: 2.73s
# 332:	learn: 0.1606798	total: 1.36s	remaining: 2.72s
# 333:	learn: 0.1605444	total: 1.36s	remaining: 2.72s
# 334:	learn: 0.1604090	total: 1.37s	remaining: 2.71s
# 335:	learn: 0.1602587	total: 1.37s	remaining: 2.71s
# 336:	learn: 0.1601048	total: 1.37s	remaining: 2.7s
# 337:	learn: 0.1599898	total: 1.38s	remaining: 2.7s
# 338:	learn: 0.1599220	total: 1.38s	remaining: 2.69s
# 339:	learn: 0.1597380	total: 1.39s	remaining: 2.69s
# 340:	learn: 0.1596576	total: 1.39s	remaining: 2.68s
# 341:	learn: 0.1595300	total: 1.39s	remaining: 2.68s
# 342:	learn: 0.1594057	total: 1.4s	remaining: 2.67s
# 343:	learn: 0.1593729	total: 1.4s	remaining: 2.67s
# 344:	learn: 0.1592340	total: 1.4s	remaining: 2.66s
# 345:	learn: 0.1591036	total: 1.41s	remaining: 2.66s
# 346:	learn: 0.1589078	total: 1.41s	remaining: 2.65s
# 347:	learn: 0.1587913	total: 1.41s	remaining: 2.65s
# 348:	learn: 0.1586988	total: 1.42s	remaining: 2.64s
# 349:	learn: 0.1585956	total: 1.42s	remaining: 2.64s
# 350:	learn: 0.1584538	total: 1.43s	remaining: 2.63s
# 351:	learn: 0.1583477	total: 1.43s	remaining: 2.63s
# 352:	learn: 0.1581710	total: 1.43s	remaining: 2.63s
# 353:	learn: 0.1580620	total: 1.44s	remaining: 2.62s
# 354:	learn: 0.1579642	total: 1.44s	remaining: 2.62s
# 355:	learn: 0.1578036	total: 1.44s	remaining: 2.61s
# 356:	learn: 0.1577107	total: 1.45s	remaining: 2.61s
# 357:	learn: 0.1576312	total: 1.45s	remaining: 2.6s
# 358:	learn: 0.1575396	total: 1.46s	remaining: 2.6s
# 359:	learn: 0.1574528	total: 1.46s	remaining: 2.59s
# 360:	learn: 0.1573275	total: 1.47s	remaining: 2.6s
# 361:	learn: 0.1572399	total: 1.47s	remaining: 2.6s
# 362:	learn: 0.1571537	total: 1.48s	remaining: 2.6s
# 363:	learn: 0.1570093	total: 1.48s	remaining: 2.59s
# 364:	learn: 0.1569127	total: 1.49s	remaining: 2.59s
# 365:	learn: 0.1567782	total: 1.49s	remaining: 2.58s
# 366:	learn: 0.1566930	total: 1.5s	remaining: 2.58s
# 367:	learn: 0.1566044	total: 1.5s	remaining: 2.58s
# 368:	learn: 0.1564810	total: 1.5s	remaining: 2.57s
# 369:	learn: 0.1563935	total: 1.51s	remaining: 2.57s
# 370:	learn: 0.1562781	total: 1.51s	remaining: 2.56s
# 371:	learn: 0.1561655	total: 1.51s	remaining: 2.56s
# 372:	learn: 0.1560769	total: 1.52s	remaining: 2.55s
# 373:	learn: 0.1560042	total: 1.52s	remaining: 2.55s
# 374:	learn: 0.1559061	total: 1.52s	remaining: 2.54s
# 375:	learn: 0.1557563	total: 1.53s	remaining: 2.54s
# 376:	learn: 0.1556743	total: 1.53s	remaining: 2.53s
# 377:	learn: 0.1555951	total: 1.54s	remaining: 2.53s
# 378:	learn: 0.1554816	total: 1.54s	remaining: 2.52s
# 379:	learn: 0.1553644	total: 1.54s	remaining: 2.52s
# 380:	learn: 0.1552268	total: 1.55s	remaining: 2.51s
# 381:	learn: 0.1551283	total: 1.55s	remaining: 2.51s
# 382:	learn: 0.1550236	total: 1.55s	remaining: 2.5s
# 383:	learn: 0.1549197	total: 1.56s	remaining: 2.5s
# 384:	learn: 0.1548114	total: 1.56s	remaining: 2.49s
# 385:	learn: 0.1547151	total: 1.56s	remaining: 2.49s
# 386:	learn: 0.1545712	total: 1.57s	remaining: 2.48s
# 387:	learn: 0.1544628	total: 1.57s	remaining: 2.48s
# 388:	learn: 0.1544415	total: 1.57s	remaining: 2.48s
# 389:	learn: 0.1544058	total: 1.58s	remaining: 2.47s
# 390:	learn: 0.1543394	total: 1.58s	remaining: 2.46s
# 391:	learn: 0.1542239	total: 1.59s	remaining: 2.46s
# 392:	learn: 0.1541361	total: 1.59s	remaining: 2.46s
# 393:	learn: 0.1540630	total: 1.59s	remaining: 2.45s
# 394:	learn: 0.1539423	total: 1.6s	remaining: 2.45s
# 395:	learn: 0.1538554	total: 1.6s	remaining: 2.44s
# 396:	learn: 0.1537352	total: 1.6s	remaining: 2.44s
# 397:	learn: 0.1536811	total: 1.61s	remaining: 2.43s
# 398:	learn: 0.1536110	total: 1.61s	remaining: 2.43s
# 399:	learn: 0.1535391	total: 1.62s	remaining: 2.42s
# 400:	learn: 0.1533909	total: 1.62s	remaining: 2.43s
# 401:	learn: 0.1533037	total: 1.63s	remaining: 2.43s
# 402:	learn: 0.1531468	total: 1.64s	remaining: 2.43s
# 403:	learn: 0.1530689	total: 1.65s	remaining: 2.43s
# 404:	learn: 0.1529717	total: 1.65s	remaining: 2.42s
# 405:	learn: 0.1528688	total: 1.65s	remaining: 2.42s
# 406:	learn: 0.1528174	total: 1.66s	remaining: 2.41s
# 407:	learn: 0.1527194	total: 1.66s	remaining: 2.41s
# 408:	learn: 0.1526518	total: 1.67s	remaining: 2.41s
# 409:	learn: 0.1525762	total: 1.67s	remaining: 2.41s
# 410:	learn: 0.1524537	total: 1.68s	remaining: 2.4s
# 411:	learn: 0.1524105	total: 1.68s	remaining: 2.4s
# 412:	learn: 0.1523240	total: 1.69s	remaining: 2.4s
# 413:	learn: 0.1522245	total: 1.69s	remaining: 2.39s
# 414:	learn: 0.1521228	total: 1.69s	remaining: 2.39s
# 415:	learn: 0.1519885	total: 1.7s	remaining: 2.38s
# 416:	learn: 0.1518727	total: 1.7s	remaining: 2.38s
# 417:	learn: 0.1518035	total: 1.7s	remaining: 2.37s
# 418:	learn: 0.1517198	total: 1.71s	remaining: 2.37s
# 419:	learn: 0.1516373	total: 1.71s	remaining: 2.36s
# 420:	learn: 0.1515419	total: 1.72s	remaining: 2.36s
# 421:	learn: 0.1513694	total: 1.72s	remaining: 2.35s
# 422:	learn: 0.1512998	total: 1.72s	remaining: 2.35s
# 423:	learn: 0.1512074	total: 1.73s	remaining: 2.34s
# 424:	learn: 0.1511382	total: 1.73s	remaining: 2.34s
# 425:	learn: 0.1510527	total: 1.73s	remaining: 2.33s
# 426:	learn: 0.1509658	total: 1.74s	remaining: 2.33s
# 427:	learn: 0.1508926	total: 1.74s	remaining: 2.33s
# 428:	learn: 0.1508167	total: 1.74s	remaining: 2.32s
# 429:	learn: 0.1507166	total: 1.75s	remaining: 2.32s
# 430:	learn: 0.1506296	total: 1.75s	remaining: 2.31s
# 431:	learn: 0.1506046	total: 1.75s	remaining: 2.31s
# 432:	learn: 0.1504882	total: 1.76s	remaining: 2.3s
# 433:	learn: 0.1504257	total: 1.76s	remaining: 2.3s
# 434:	learn: 0.1504051	total: 1.76s	remaining: 2.29s
# 435:	learn: 0.1503231	total: 1.77s	remaining: 2.29s
# 436:	learn: 0.1502158	total: 1.77s	remaining: 2.28s
# 437:	learn: 0.1501468	total: 1.77s	remaining: 2.28s
# 438:	learn: 0.1499965	total: 1.78s	remaining: 2.27s
# 439:	learn: 0.1499056	total: 1.78s	remaining: 2.27s
# 440:	learn: 0.1498014	total: 1.79s	remaining: 2.27s
# 441:	learn: 0.1497346	total: 1.79s	remaining: 2.26s
# 442:	learn: 0.1496836	total: 1.79s	remaining: 2.26s
# 443:	learn: 0.1496130	total: 1.8s	remaining: 2.25s
# 444:	learn: 0.1494793	total: 1.8s	remaining: 2.25s
# 445:	learn: 0.1494329	total: 1.8s	remaining: 2.24s
# 446:	learn: 0.1493197	total: 1.81s	remaining: 2.24s
# 447:	learn: 0.1492590	total: 1.81s	remaining: 2.23s
# 448:	learn: 0.1491763	total: 1.82s	remaining: 2.23s
# 449:	learn: 0.1490997	total: 1.82s	remaining: 2.23s
# 450:	learn: 0.1490223	total: 1.82s	remaining: 2.22s
# 451:	learn: 0.1489501	total: 1.83s	remaining: 2.22s
# 452:	learn: 0.1488700	total: 1.83s	remaining: 2.21s
# 453:	learn: 0.1487807	total: 1.84s	remaining: 2.21s
# 454:	learn: 0.1487005	total: 1.84s	remaining: 2.2s
# 455:	learn: 0.1486154	total: 1.84s	remaining: 2.2s
# 456:	learn: 0.1484997	total: 1.85s	remaining: 2.19s
# 457:	learn: 0.1483920	total: 1.85s	remaining: 2.19s
# 458:	learn: 0.1483076	total: 1.85s	remaining: 2.19s
# 459:	learn: 0.1481885	total: 1.86s	remaining: 2.18s
# 460:	learn: 0.1480849	total: 1.86s	remaining: 2.18s
# 461:	learn: 0.1479798	total: 1.86s	remaining: 2.17s
# 462:	learn: 0.1479236	total: 1.87s	remaining: 2.17s
# 463:	learn: 0.1478486	total: 1.88s	remaining: 2.17s
# 464:	learn: 0.1477450	total: 1.88s	remaining: 2.17s
# 465:	learn: 0.1476173	total: 1.89s	remaining: 2.16s
# 466:	learn: 0.1474708	total: 1.89s	remaining: 2.16s
# 467:	learn: 0.1474097	total: 1.89s	remaining: 2.15s
# 468:	learn: 0.1472753	total: 1.9s	remaining: 2.15s
# 469:	learn: 0.1472137	total: 1.9s	remaining: 2.14s
# 470:	learn: 0.1470987	total: 1.9s	remaining: 2.14s
# 471:	learn: 0.1470196	total: 1.91s	remaining: 2.13s
# 472:	learn: 0.1469379	total: 1.91s	remaining: 2.13s
# 473:	learn: 0.1468889	total: 1.92s	remaining: 2.13s
# 474:	learn: 0.1467610	total: 1.92s	remaining: 2.12s
# 475:	learn: 0.1466590	total: 1.92s	remaining: 2.12s
# 476:	learn: 0.1465982	total: 1.93s	remaining: 2.11s
# 477:	learn: 0.1465394	total: 1.93s	remaining: 2.11s
# 478:	learn: 0.1464242	total: 1.93s	remaining: 2.1s
# 479:	learn: 0.1463778	total: 1.94s	remaining: 2.1s
# 480:	learn: 0.1462850	total: 1.94s	remaining: 2.1s
# 481:	learn: 0.1462390	total: 1.95s	remaining: 2.09s
# 482:	learn: 0.1461452	total: 1.95s	remaining: 2.09s
# 483:	learn: 0.1460468	total: 1.95s	remaining: 2.08s
# 484:	learn: 0.1459729	total: 1.96s	remaining: 2.08s
# 485:	learn: 0.1459525	total: 1.96s	remaining: 2.07s
# 486:	learn: 0.1458080	total: 1.96s	remaining: 2.07s
# 487:	learn: 0.1457070	total: 1.97s	remaining: 2.06s
# 488:	learn: 0.1455937	total: 1.97s	remaining: 2.06s
# 489:	learn: 0.1455083	total: 1.98s	remaining: 2.06s
# 490:	learn: 0.1454452	total: 1.98s	remaining: 2.05s
# 491:	learn: 0.1452996	total: 1.98s	remaining: 2.05s
# 492:	learn: 0.1452475	total: 1.99s	remaining: 2.04s
# 493:	learn: 0.1450987	total: 1.99s	remaining: 2.04s
# 494:	learn: 0.1449456	total: 1.99s	remaining: 2.03s
# 495:	learn: 0.1448801	total: 2s	remaining: 2.03s
# 496:	learn: 0.1448095	total: 2s	remaining: 2.02s
# 497:	learn: 0.1447623	total: 2s	remaining: 2.02s
# 498:	learn: 0.1446803	total: 2.01s	remaining: 2.02s
# 499:	learn: 0.1446055	total: 2.01s	remaining: 2.01s
# 500:	learn: 0.1445659	total: 2.02s	remaining: 2.01s
# 501:	learn: 0.1444679	total: 2.02s	remaining: 2s
# 502:	learn: 0.1443782	total: 2.02s	remaining: 2s
# 503:	learn: 0.1442875	total: 2.03s	remaining: 2s
# 504:	learn: 0.1442375	total: 2.03s	remaining: 1.99s
# 505:	learn: 0.1441752	total: 2.04s	remaining: 1.99s
# 506:	learn: 0.1441214	total: 2.04s	remaining: 1.98s
# 507:	learn: 0.1440421	total: 2.04s	remaining: 1.98s
# 508:	learn: 0.1439992	total: 2.05s	remaining: 1.97s
# 509:	learn: 0.1438751	total: 2.05s	remaining: 1.97s
# 510:	learn: 0.1437528	total: 2.05s	remaining: 1.97s
# 511:	learn: 0.1436322	total: 2.06s	remaining: 1.96s
# 512:	learn: 0.1435510	total: 2.06s	remaining: 1.96s
# 513:	learn: 0.1434485	total: 2.06s	remaining: 1.95s
# 514:	learn: 0.1434038	total: 2.07s	remaining: 1.95s
# 515:	learn: 0.1433400	total: 2.08s	remaining: 1.95s
# 516:	learn: 0.1432242	total: 2.09s	remaining: 1.95s
# 517:	learn: 0.1431397	total: 2.09s	remaining: 1.95s
# 518:	learn: 0.1430302	total: 2.1s	remaining: 1.95s
# 519:	learn: 0.1429199	total: 2.11s	remaining: 1.95s
# 520:	learn: 0.1428223	total: 2.11s	remaining: 1.94s
# 521:	learn: 0.1426760	total: 2.12s	remaining: 1.94s
# 522:	learn: 0.1425297	total: 2.13s	remaining: 1.94s
# 523:	learn: 0.1424727	total: 2.13s	remaining: 1.94s
# 524:	learn: 0.1423833	total: 2.14s	remaining: 1.94s
# 525:	learn: 0.1423290	total: 2.15s	remaining: 1.93s
# 526:	learn: 0.1422587	total: 2.15s	remaining: 1.93s
# 527:	learn: 0.1421555	total: 2.16s	remaining: 1.93s
# 528:	learn: 0.1421125	total: 2.16s	remaining: 1.92s
# 529:	learn: 0.1419967	total: 2.17s	remaining: 1.92s
# 530:	learn: 0.1419129	total: 2.17s	remaining: 1.92s
# 531:	learn: 0.1418027	total: 2.18s	remaining: 1.92s
# 532:	learn: 0.1417239	total: 2.19s	remaining: 1.92s
# 533:	learn: 0.1416691	total: 2.2s	remaining: 1.92s
# 534:	learn: 0.1416322	total: 2.2s	remaining: 1.91s
# 535:	learn: 0.1415615	total: 2.21s	remaining: 1.91s
# 536:	learn: 0.1414575	total: 2.22s	remaining: 1.92s
# 537:	learn: 0.1413874	total: 2.23s	remaining: 1.91s
# 538:	learn: 0.1412808	total: 2.23s	remaining: 1.91s
# 539:	learn: 0.1411972	total: 2.24s	remaining: 1.91s
# 540:	learn: 0.1411153	total: 2.25s	remaining: 1.91s
# 541:	learn: 0.1410756	total: 2.26s	remaining: 1.91s
# 542:	learn: 0.1409996	total: 2.28s	remaining: 1.92s
# 543:	learn: 0.1409197	total: 2.29s	remaining: 1.92s
# 544:	learn: 0.1408824	total: 2.3s	remaining: 1.92s
# 545:	learn: 0.1408352	total: 2.31s	remaining: 1.92s
# 546:	learn: 0.1407441	total: 2.32s	remaining: 1.92s
# 547:	learn: 0.1406360	total: 2.32s	remaining: 1.92s
# 548:	learn: 0.1405495	total: 2.33s	remaining: 1.92s
# 549:	learn: 0.1404911	total: 2.34s	remaining: 1.92s
# 550:	learn: 0.1404022	total: 2.35s	remaining: 1.91s
# 551:	learn: 0.1403475	total: 2.36s	remaining: 1.91s
# 552:	learn: 0.1402385	total: 2.37s	remaining: 1.92s
# 553:	learn: 0.1401766	total: 2.38s	remaining: 1.92s
# 554:	learn: 0.1400820	total: 2.39s	remaining: 1.92s
# 555:	learn: 0.1400313	total: 2.4s	remaining: 1.92s
# 556:	learn: 0.1399892	total: 2.41s	remaining: 1.91s
# 557:	learn: 0.1399273	total: 2.42s	remaining: 1.91s
# 558:	learn: 0.1398390	total: 2.42s	remaining: 1.91s
# 559:	learn: 0.1397785	total: 2.43s	remaining: 1.91s
# 560:	learn: 0.1396656	total: 2.44s	remaining: 1.91s
# 561:	learn: 0.1396094	total: 2.45s	remaining: 1.91s
# 562:	learn: 0.1395765	total: 2.46s	remaining: 1.91s
# 563:	learn: 0.1394701	total: 2.47s	remaining: 1.91s
# 564:	learn: 0.1393983	total: 2.48s	remaining: 1.91s
# 565:	learn: 0.1392457	total: 2.49s	remaining: 1.91s
# 566:	learn: 0.1391465	total: 2.5s	remaining: 1.91s
# 567:	learn: 0.1390938	total: 2.51s	remaining: 1.91s
# 568:	learn: 0.1389650	total: 2.52s	remaining: 1.91s
# 569:	learn: 0.1388726	total: 2.53s	remaining: 1.91s
# 570:	learn: 0.1387759	total: 2.54s	remaining: 1.91s
# 571:	learn: 0.1387064	total: 2.55s	remaining: 1.91s
# 572:	learn: 0.1385664	total: 2.56s	remaining: 1.91s
# 573:	learn: 0.1385065	total: 2.57s	remaining: 1.91s
# 574:	learn: 0.1384258	total: 2.58s	remaining: 1.91s
# 575:	learn: 0.1383642	total: 2.59s	remaining: 1.91s
# 576:	learn: 0.1382746	total: 2.6s	remaining: 1.91s
# 577:	learn: 0.1381892	total: 2.62s	remaining: 1.91s
# 578:	learn: 0.1380514	total: 2.62s	remaining: 1.91s
# 579:	learn: 0.1379626	total: 2.63s	remaining: 1.91s
# 580:	learn: 0.1378768	total: 2.64s	remaining: 1.91s
# 581:	learn: 0.1377963	total: 2.65s	remaining: 1.91s
# 582:	learn: 0.1377332	total: 2.67s	remaining: 1.91s
# 583:	learn: 0.1376356	total: 2.68s	remaining: 1.91s
# 584:	learn: 0.1375779	total: 2.69s	remaining: 1.91s
# 585:	learn: 0.1374824	total: 2.7s	remaining: 1.91s
# 586:	learn: 0.1373879	total: 2.71s	remaining: 1.91s
# 587:	learn: 0.1372880	total: 2.72s	remaining: 1.91s
# 588:	learn: 0.1372073	total: 2.73s	remaining: 1.91s
# 589:	learn: 0.1370598	total: 2.75s	remaining: 1.91s
# 590:	learn: 0.1369438	total: 2.76s	remaining: 1.91s
# 591:	learn: 0.1368537	total: 2.77s	remaining: 1.91s
# 592:	learn: 0.1367522	total: 2.77s	remaining: 1.9s
# 593:	learn: 0.1366971	total: 2.78s	remaining: 1.9s
# 594:	learn: 0.1366227	total: 2.8s	remaining: 1.9s
# 595:	learn: 0.1364993	total: 2.81s	remaining: 1.9s
# 596:	learn: 0.1364191	total: 2.82s	remaining: 1.9s
# 597:	learn: 0.1363186	total: 2.83s	remaining: 1.9s
# 598:	learn: 0.1361694	total: 2.84s	remaining: 1.9s
# 599:	learn: 0.1360996	total: 2.85s	remaining: 1.9s
# 600:	learn: 0.1359645	total: 2.86s	remaining: 1.9s
# 601:	learn: 0.1358978	total: 2.88s	remaining: 1.9s
# 602:	learn: 0.1358020	total: 2.89s	remaining: 1.9s
# 603:	learn: 0.1356533	total: 2.9s	remaining: 1.9s
# 604:	learn: 0.1355535	total: 2.91s	remaining: 1.9s
# 605:	learn: 0.1354698	total: 2.92s	remaining: 1.9s
# 606:	learn: 0.1353976	total: 2.93s	remaining: 1.9s
# 607:	learn: 0.1353458	total: 2.94s	remaining: 1.9s
# 608:	learn: 0.1352690	total: 2.95s	remaining: 1.89s
# 609:	learn: 0.1351896	total: 2.95s	remaining: 1.89s
# 610:	learn: 0.1350783	total: 2.96s	remaining: 1.88s
# 611:	learn: 0.1349752	total: 2.97s	remaining: 1.88s
# 612:	learn: 0.1348960	total: 2.98s	remaining: 1.88s
# 613:	learn: 0.1348370	total: 2.99s	remaining: 1.88s
# 614:	learn: 0.1347477	total: 3s	remaining: 1.88s
# 615:	learn: 0.1346870	total: 3.01s	remaining: 1.87s
# 616:	learn: 0.1345896	total: 3.02s	remaining: 1.87s
# 617:	learn: 0.1345238	total: 3.02s	remaining: 1.87s
# 618:	learn: 0.1344547	total: 3.04s	remaining: 1.87s
# 619:	learn: 0.1343602	total: 3.04s	remaining: 1.87s
# 620:	learn: 0.1342996	total: 3.06s	remaining: 1.86s
# 621:	learn: 0.1342292	total: 3.06s	remaining: 1.86s
# 622:	learn: 0.1341407	total: 3.08s	remaining: 1.86s
# 623:	learn: 0.1340971	total: 3.09s	remaining: 1.86s
# 624:	learn: 0.1340016	total: 3.1s	remaining: 1.86s
# 625:	learn: 0.1339089	total: 3.11s	remaining: 1.86s
# 626:	learn: 0.1338748	total: 3.12s	remaining: 1.86s
# 627:	learn: 0.1337875	total: 3.13s	remaining: 1.85s
# 628:	learn: 0.1337414	total: 3.14s	remaining: 1.85s
# 629:	learn: 0.1335812	total: 3.15s	remaining: 1.85s
# 630:	learn: 0.1334989	total: 3.16s	remaining: 1.85s
# 631:	learn: 0.1334044	total: 3.17s	remaining: 1.85s
# 632:	learn: 0.1332841	total: 3.18s	remaining: 1.84s
# 633:	learn: 0.1331745	total: 3.19s	remaining: 1.84s
# 634:	learn: 0.1331012	total: 3.2s	remaining: 1.84s
# 635:	learn: 0.1329712	total: 3.21s	remaining: 1.84s
# 636:	learn: 0.1328462	total: 3.22s	remaining: 1.84s
# 637:	learn: 0.1327737	total: 3.23s	remaining: 1.83s
# 638:	learn: 0.1326850	total: 3.24s	remaining: 1.83s
# 639:	learn: 0.1326344	total: 3.25s	remaining: 1.83s
# 640:	learn: 0.1325474	total: 3.26s	remaining: 1.82s
# 641:	learn: 0.1324715	total: 3.27s	remaining: 1.82s
# 642:	learn: 0.1323943	total: 3.29s	remaining: 1.82s
# 643:	learn: 0.1323572	total: 3.29s	remaining: 1.82s
# 644:	learn: 0.1323089	total: 3.3s	remaining: 1.82s
# 645:	learn: 0.1322476	total: 3.31s	remaining: 1.82s
# 646:	learn: 0.1321422	total: 3.32s	remaining: 1.81s
# 647:	learn: 0.1320896	total: 3.33s	remaining: 1.81s
# 648:	learn: 0.1320050	total: 3.34s	remaining: 1.81s
# 649:	learn: 0.1319268	total: 3.35s	remaining: 1.8s
# 650:	learn: 0.1318963	total: 3.36s	remaining: 1.8s
# 651:	learn: 0.1318208	total: 3.38s	remaining: 1.8s
# 652:	learn: 0.1317332	total: 3.38s	remaining: 1.8s
# 653:	learn: 0.1316414	total: 3.39s	remaining: 1.79s
# 654:	learn: 0.1315408	total: 3.4s	remaining: 1.79s
# 655:	learn: 0.1314509	total: 3.41s	remaining: 1.79s
# 656:	learn: 0.1313573	total: 3.42s	remaining: 1.79s
# 657:	learn: 0.1312743	total: 3.43s	remaining: 1.78s
# 658:	learn: 0.1311663	total: 3.44s	remaining: 1.78s
# 659:	learn: 0.1310953	total: 3.45s	remaining: 1.78s
# 660:	learn: 0.1309901	total: 3.46s	remaining: 1.77s
# 661:	learn: 0.1309383	total: 3.46s	remaining: 1.77s
# 662:	learn: 0.1308616	total: 3.47s	remaining: 1.76s
# 663:	learn: 0.1308040	total: 3.48s	remaining: 1.76s
# 664:	learn: 0.1307416	total: 3.49s	remaining: 1.76s
# 665:	learn: 0.1306376	total: 3.5s	remaining: 1.75s
# 666:	learn: 0.1305442	total: 3.51s	remaining: 1.75s
# 667:	learn: 0.1304254	total: 3.51s	remaining: 1.75s
# 668:	learn: 0.1303396	total: 3.52s	remaining: 1.74s
# 669:	learn: 0.1302432	total: 3.53s	remaining: 1.74s
# 670:	learn: 0.1301762	total: 3.54s	remaining: 1.74s
# 671:	learn: 0.1301073	total: 3.55s	remaining: 1.73s
# 672:	learn: 0.1300126	total: 3.56s	remaining: 1.73s
# 673:	learn: 0.1299469	total: 3.58s	remaining: 1.73s
# 674:	learn: 0.1298598	total: 3.59s	remaining: 1.73s
# 675:	learn: 0.1297801	total: 3.6s	remaining: 1.72s
# 676:	learn: 0.1297093	total: 3.61s	remaining: 1.72s
# 677:	learn: 0.1296264	total: 3.62s	remaining: 1.72s
# 678:	learn: 0.1295353	total: 3.63s	remaining: 1.72s
# 679:	learn: 0.1294507	total: 3.64s	remaining: 1.71s
# 680:	learn: 0.1293050	total: 3.65s	remaining: 1.71s
# 681:	learn: 0.1291996	total: 3.66s	remaining: 1.71s
# 682:	learn: 0.1291083	total: 3.67s	remaining: 1.7s
# 683:	learn: 0.1290474	total: 3.67s	remaining: 1.7s
# 684:	learn: 0.1289516	total: 3.69s	remaining: 1.7s
# 685:	learn: 0.1288933	total: 3.69s	remaining: 1.69s
# 686:	learn: 0.1287997	total: 3.7s	remaining: 1.69s
# 687:	learn: 0.1287334	total: 3.71s	remaining: 1.68s
# 688:	learn: 0.1286221	total: 3.72s	remaining: 1.68s
# 689:	learn: 0.1285554	total: 3.73s	remaining: 1.68s
# 690:	learn: 0.1284446	total: 3.74s	remaining: 1.67s
# 691:	learn: 0.1284046	total: 3.75s	remaining: 1.67s
# 692:	learn: 0.1283470	total: 3.76s	remaining: 1.66s
# 693:	learn: 0.1282673	total: 3.77s	remaining: 1.66s
# 694:	learn: 0.1281595	total: 3.78s	remaining: 1.66s
# 695:	learn: 0.1281164	total: 3.78s	remaining: 1.65s
# 696:	learn: 0.1280655	total: 3.79s	remaining: 1.65s
# 697:	learn: 0.1280134	total: 3.79s	remaining: 1.64s
# 698:	learn: 0.1279646	total: 3.8s	remaining: 1.63s
# 699:	learn: 0.1279090	total: 3.8s	remaining: 1.63s
# 700:	learn: 0.1278310	total: 3.81s	remaining: 1.62s
# 701:	learn: 0.1277450	total: 3.81s	remaining: 1.62s
# 702:	learn: 0.1276890	total: 3.83s	remaining: 1.62s
# 703:	learn: 0.1276246	total: 3.83s	remaining: 1.61s
# 704:	learn: 0.1275687	total: 3.85s	remaining: 1.61s
# 705:	learn: 0.1274994	total: 3.85s	remaining: 1.6s
# 706:	learn: 0.1274273	total: 3.86s	remaining: 1.6s
# 707:	learn: 0.1273672	total: 3.87s	remaining: 1.6s
# 708:	learn: 0.1273026	total: 3.88s	remaining: 1.59s
# 709:	learn: 0.1272563	total: 3.89s	remaining: 1.59s
# 710:	learn: 0.1271826	total: 3.9s	remaining: 1.59s
# 711:	learn: 0.1271247	total: 3.91s	remaining: 1.58s
# 712:	learn: 0.1270733	total: 3.92s	remaining: 1.58s
# 713:	learn: 0.1269517	total: 3.93s	remaining: 1.57s
# 714:	learn: 0.1268538	total: 3.94s	remaining: 1.57s
# 715:	learn: 0.1267687	total: 3.94s	remaining: 1.56s
# 716:	learn: 0.1266782	total: 3.95s	remaining: 1.56s
# 717:	learn: 0.1265950	total: 3.96s	remaining: 1.55s
# 718:	learn: 0.1265458	total: 3.97s	remaining: 1.55s
# 719:	learn: 0.1264970	total: 3.98s	remaining: 1.55s
# 720:	learn: 0.1264288	total: 3.99s	remaining: 1.54s
# 721:	learn: 0.1263578	total: 4s	remaining: 1.54s
# 722:	learn: 0.1262997	total: 4.01s	remaining: 1.53s
# 723:	learn: 0.1262616	total: 4.02s	remaining: 1.53s
# 724:	learn: 0.1262006	total: 4.03s	remaining: 1.53s
# 725:	learn: 0.1261571	total: 4.03s	remaining: 1.52s
# 726:	learn: 0.1260594	total: 4.03s	remaining: 1.51s
# 727:	learn: 0.1259613	total: 4.04s	remaining: 1.51s
# 728:	learn: 0.1258927	total: 4.04s	remaining: 1.5s
# 729:	learn: 0.1258501	total: 4.05s	remaining: 1.5s
# 730:	learn: 0.1258127	total: 4.06s	remaining: 1.49s
# 731:	learn: 0.1257517	total: 4.06s	remaining: 1.49s
# 732:	learn: 0.1256684	total: 4.07s	remaining: 1.48s
# 733:	learn: 0.1255596	total: 4.08s	remaining: 1.48s
# 734:	learn: 0.1254788	total: 4.09s	remaining: 1.47s
# 735:	learn: 0.1253902	total: 4.09s	remaining: 1.47s
# 736:	learn: 0.1253243	total: 4.09s	remaining: 1.46s
# 737:	learn: 0.1252600	total: 4.1s	remaining: 1.46s
# 738:	learn: 0.1252334	total: 4.11s	remaining: 1.45s
# 739:	learn: 0.1251448	total: 4.11s	remaining: 1.44s
# 740:	learn: 0.1250544	total: 4.11s	remaining: 1.44s
# 741:	learn: 0.1250017	total: 4.12s	remaining: 1.43s
# 742:	learn: 0.1249600	total: 4.13s	remaining: 1.43s
# 743:	learn: 0.1249081	total: 4.13s	remaining: 1.42s
# 744:	learn: 0.1248088	total: 4.14s	remaining: 1.42s
# 745:	learn: 0.1247152	total: 4.14s	remaining: 1.41s
# 746:	learn: 0.1245854	total: 4.15s	remaining: 1.41s
# 747:	learn: 0.1245119	total: 4.16s	remaining: 1.4s
# 748:	learn: 0.1244684	total: 4.17s	remaining: 1.4s
# 749:	learn: 0.1244239	total: 4.18s	remaining: 1.39s
# 750:	learn: 0.1243493	total: 4.18s	remaining: 1.39s
# 751:	learn: 0.1242633	total: 4.19s	remaining: 1.38s
# 752:	learn: 0.1241996	total: 4.19s	remaining: 1.37s
# 753:	learn: 0.1241222	total: 4.2s	remaining: 1.37s
# 754:	learn: 0.1240728	total: 4.2s	remaining: 1.36s
# 755:	learn: 0.1240150	total: 4.2s	remaining: 1.36s
# 756:	learn: 0.1239475	total: 4.21s	remaining: 1.35s
# 757:	learn: 0.1239121	total: 4.21s	remaining: 1.34s
# 758:	learn: 0.1238405	total: 4.22s	remaining: 1.34s
# 759:	learn: 0.1237627	total: 4.22s	remaining: 1.33s
# 760:	learn: 0.1236690	total: 4.23s	remaining: 1.33s
# 761:	learn: 0.1236195	total: 4.23s	remaining: 1.32s
# 762:	learn: 0.1235583	total: 4.23s	remaining: 1.31s
# 763:	learn: 0.1234885	total: 4.24s	remaining: 1.31s
# 764:	learn: 0.1234034	total: 4.24s	remaining: 1.3s
# 765:	learn: 0.1233214	total: 4.25s	remaining: 1.3s
# 766:	learn: 0.1232462	total: 4.25s	remaining: 1.29s
# 767:	learn: 0.1231883	total: 4.26s	remaining: 1.29s
# 768:	learn: 0.1231173	total: 4.26s	remaining: 1.28s
# 769:	learn: 0.1230525	total: 4.27s	remaining: 1.27s
# 770:	learn: 0.1229999	total: 4.27s	remaining: 1.27s
# 771:	learn: 0.1229310	total: 4.28s	remaining: 1.26s
# 772:	learn: 0.1228196	total: 4.28s	remaining: 1.26s
# 773:	learn: 0.1227640	total: 4.29s	remaining: 1.25s
# 774:	learn: 0.1227027	total: 4.29s	remaining: 1.25s
# 775:	learn: 0.1226629	total: 4.3s	remaining: 1.24s
# 776:	learn: 0.1226173	total: 4.31s	remaining: 1.24s
# 777:	learn: 0.1225503	total: 4.32s	remaining: 1.23s
# 778:	learn: 0.1224859	total: 4.33s	remaining: 1.23s
# 779:	learn: 0.1223769	total: 4.34s	remaining: 1.23s
# 780:	learn: 0.1222773	total: 4.35s	remaining: 1.22s
# 781:	learn: 0.1222342	total: 4.36s	remaining: 1.22s
# 782:	learn: 0.1222019	total: 4.37s	remaining: 1.21s
# 783:	learn: 0.1221445	total: 4.38s	remaining: 1.21s
# 784:	learn: 0.1220634	total: 4.39s	remaining: 1.2s
# 785:	learn: 0.1220027	total: 4.4s	remaining: 1.2s
# 786:	learn: 0.1219452	total: 4.41s	remaining: 1.19s
# 787:	learn: 0.1219148	total: 4.42s	remaining: 1.19s
# 788:	learn: 0.1218679	total: 4.44s	remaining: 1.19s
# 789:	learn: 0.1217675	total: 4.45s	remaining: 1.18s
# 790:	learn: 0.1217079	total: 4.46s	remaining: 1.18s
# 791:	learn: 0.1216200	total: 4.47s	remaining: 1.17s
# 792:	learn: 0.1215641	total: 4.48s	remaining: 1.17s
# 793:	learn: 0.1215226	total: 4.49s	remaining: 1.16s
# 794:	learn: 0.1214742	total: 4.5s	remaining: 1.16s
# 795:	learn: 0.1213832	total: 4.51s	remaining: 1.16s
# 796:	learn: 0.1213499	total: 4.52s	remaining: 1.15s
# 797:	learn: 0.1212690	total: 4.53s	remaining: 1.15s
# 798:	learn: 0.1212210	total: 4.54s	remaining: 1.14s
# 799:	learn: 0.1211426	total: 4.55s	remaining: 1.14s
# 800:	learn: 0.1211004	total: 4.56s	remaining: 1.13s
# 801:	learn: 0.1210191	total: 4.57s	remaining: 1.13s
# 802:	learn: 0.1209601	total: 4.58s	remaining: 1.12s
# 803:	learn: 0.1209049	total: 4.59s	remaining: 1.12s
# 804:	learn: 0.1208016	total: 4.6s	remaining: 1.11s
# 805:	learn: 0.1207374	total: 4.62s	remaining: 1.11s
# 806:	learn: 0.1206138	total: 4.63s	remaining: 1.11s
# 807:	learn: 0.1205687	total: 4.64s	remaining: 1.1s
# 808:	learn: 0.1205125	total: 4.65s	remaining: 1.1s
# 809:	learn: 0.1204358	total: 4.66s	remaining: 1.09s
# 810:	learn: 0.1203689	total: 4.67s	remaining: 1.09s
# 811:	learn: 0.1203220	total: 4.68s	remaining: 1.08s
# 812:	learn: 0.1202394	total: 4.69s	remaining: 1.08s
# 813:	learn: 0.1201636	total: 4.7s	remaining: 1.07s
# 814:	learn: 0.1201413	total: 4.71s	remaining: 1.07s
# 815:	learn: 0.1200800	total: 4.72s	remaining: 1.06s
# 816:	learn: 0.1199842	total: 4.73s	remaining: 1.06s
# 817:	learn: 0.1199133	total: 4.74s	remaining: 1.05s
# 818:	learn: 0.1198136	total: 4.75s	remaining: 1.05s
# 819:	learn: 0.1197524	total: 4.76s	remaining: 1.04s
# 820:	learn: 0.1196763	total: 4.77s	remaining: 1.04s
# 821:	learn: 0.1196456	total: 4.78s	remaining: 1.03s
# 822:	learn: 0.1195821	total: 4.79s	remaining: 1.03s
# 823:	learn: 0.1195428	total: 4.8s	remaining: 1.02s
# 824:	learn: 0.1194595	total: 4.81s	remaining: 1.02s
# 825:	learn: 0.1193924	total: 4.82s	remaining: 1.02s
# 826:	learn: 0.1193315	total: 4.84s	remaining: 1.01s
# 827:	learn: 0.1193030	total: 4.85s	remaining: 1.01s
# 828:	learn: 0.1192551	total: 4.86s	remaining: 1s
# 829:	learn: 0.1192083	total: 4.87s	remaining: 997ms
# 830:	learn: 0.1191729	total: 4.88s	remaining: 992ms
# 831:	learn: 0.1191007	total: 4.89s	remaining: 987ms
# 832:	learn: 0.1190123	total: 4.9s	remaining: 982ms
# 833:	learn: 0.1189648	total: 4.91s	remaining: 977ms
# 834:	learn: 0.1188975	total: 4.92s	remaining: 972ms
# 835:	learn: 0.1188470	total: 4.93s	remaining: 967ms
# 836:	learn: 0.1187880	total: 4.94s	remaining: 962ms
# 837:	learn: 0.1187253	total: 4.95s	remaining: 957ms
# 838:	learn: 0.1186563	total: 4.96s	remaining: 952ms
# 839:	learn: 0.1185988	total: 4.97s	remaining: 947ms
# 840:	learn: 0.1185127	total: 4.98s	remaining: 942ms
# 841:	learn: 0.1184353	total: 4.99s	remaining: 937ms
# 842:	learn: 0.1183359	total: 5s	remaining: 932ms
# 843:	learn: 0.1182719	total: 5.01s	remaining: 927ms
# 844:	learn: 0.1181961	total: 5.02s	remaining: 921ms
# 845:	learn: 0.1181440	total: 5.04s	remaining: 917ms
# 846:	learn: 0.1181051	total: 5.04s	remaining: 911ms
# 847:	learn: 0.1180646	total: 5.05s	remaining: 906ms
# 848:	learn: 0.1180160	total: 5.07s	remaining: 901ms
# 849:	learn: 0.1179415	total: 5.08s	remaining: 896ms
# 850:	learn: 0.1178901	total: 5.09s	remaining: 891ms
# 851:	learn: 0.1178236	total: 5.1s	remaining: 886ms
# 852:	learn: 0.1178054	total: 5.11s	remaining: 880ms
# 853:	learn: 0.1177321	total: 5.12s	remaining: 875ms
# 854:	learn: 0.1176406	total: 5.13s	remaining: 869ms
# 855:	learn: 0.1175822	total: 5.14s	remaining: 864ms
# 856:	learn: 0.1174995	total: 5.15s	remaining: 859ms
# 857:	learn: 0.1174235	total: 5.16s	remaining: 853ms
# 858:	learn: 0.1173595	total: 5.16s	remaining: 848ms
# 859:	learn: 0.1172703	total: 5.17s	remaining: 842ms
# 860:	learn: 0.1172085	total: 5.18s	remaining: 836ms
# 861:	learn: 0.1171523	total: 5.19s	remaining: 831ms
# 862:	learn: 0.1170987	total: 5.2s	remaining: 825ms
# 863:	learn: 0.1170486	total: 5.21s	remaining: 820ms
# 864:	learn: 0.1169759	total: 5.22s	remaining: 815ms
# 865:	learn: 0.1169125	total: 5.23s	remaining: 810ms
# 866:	learn: 0.1168177	total: 5.24s	remaining: 804ms
# 867:	learn: 0.1167609	total: 5.25s	remaining: 798ms
# 868:	learn: 0.1166662	total: 5.26s	remaining: 793ms
# 869:	learn: 0.1165701	total: 5.27s	remaining: 788ms
# 870:	learn: 0.1164849	total: 5.28s	remaining: 782ms
# 871:	learn: 0.1164286	total: 5.29s	remaining: 777ms
# 872:	learn: 0.1163880	total: 5.3s	remaining: 771ms
# 873:	learn: 0.1163143	total: 5.31s	remaining: 766ms
# 874:	learn: 0.1162579	total: 5.32s	remaining: 760ms
# 875:	learn: 0.1162098	total: 5.33s	remaining: 755ms
# 876:	learn: 0.1161392	total: 5.34s	remaining: 749ms
# 877:	learn: 0.1160800	total: 5.35s	remaining: 743ms
# 878:	learn: 0.1160078	total: 5.36s	remaining: 738ms
# 879:	learn: 0.1159337	total: 5.37s	remaining: 732ms
# 880:	learn: 0.1158653	total: 5.38s	remaining: 727ms
# 881:	learn: 0.1157888	total: 5.39s	remaining: 721ms
# 882:	learn: 0.1157171	total: 5.4s	remaining: 715ms
# 883:	learn: 0.1156573	total: 5.41s	remaining: 709ms
# 884:	learn: 0.1156233	total: 5.41s	remaining: 704ms
# 885:	learn: 0.1155900	total: 5.43s	remaining: 698ms
# 886:	learn: 0.1155286	total: 5.44s	remaining: 693ms
# 887:	learn: 0.1154945	total: 5.45s	remaining: 687ms
# 888:	learn: 0.1154586	total: 5.46s	remaining: 682ms
# 889:	learn: 0.1154083	total: 5.47s	remaining: 676ms
# 890:	learn: 0.1153416	total: 5.48s	remaining: 670ms
# 891:	learn: 0.1152823	total: 5.49s	remaining: 665ms
# 892:	learn: 0.1151979	total: 5.5s	remaining: 659ms
# 893:	learn: 0.1151514	total: 5.51s	remaining: 653ms
# 894:	learn: 0.1150714	total: 5.52s	remaining: 648ms
# 895:	learn: 0.1150328	total: 5.53s	remaining: 642ms
# 896:	learn: 0.1149969	total: 5.54s	remaining: 636ms
# 897:	learn: 0.1149617	total: 5.55s	remaining: 631ms
# 898:	learn: 0.1148859	total: 5.57s	remaining: 625ms
# 899:	learn: 0.1148076	total: 5.58s	remaining: 620ms
# 900:	learn: 0.1147642	total: 5.58s	remaining: 614ms
# 901:	learn: 0.1147429	total: 5.59s	remaining: 607ms
# 902:	learn: 0.1147221	total: 5.59s	remaining: 601ms
# 903:	learn: 0.1146447	total: 5.6s	remaining: 595ms
# 904:	learn: 0.1146027	total: 5.6s	remaining: 588ms
# 905:	learn: 0.1145290	total: 5.61s	remaining: 582ms
# 906:	learn: 0.1144404	total: 5.61s	remaining: 575ms
# 907:	learn: 0.1144162	total: 5.61s	remaining: 569ms
# 908:	learn: 0.1143413	total: 5.62s	remaining: 563ms
# 909:	learn: 0.1142711	total: 5.63s	remaining: 557ms
# 910:	learn: 0.1142209	total: 5.63s	remaining: 550ms
# 911:	learn: 0.1141471	total: 5.64s	remaining: 544ms
# 912:	learn: 0.1141171	total: 5.64s	remaining: 538ms
# 913:	learn: 0.1140583	total: 5.64s	remaining: 531ms
# 914:	learn: 0.1139933	total: 5.65s	remaining: 525ms
# 915:	learn: 0.1139351	total: 5.65s	remaining: 518ms
# 916:	learn: 0.1138793	total: 5.66s	remaining: 512ms
# 917:	learn: 0.1138345	total: 5.66s	remaining: 506ms
# 918:	learn: 0.1137963	total: 5.66s	remaining: 499ms
# 919:	learn: 0.1137443	total: 5.67s	remaining: 493ms
# 920:	learn: 0.1136910	total: 5.67s	remaining: 486ms
# 921:	learn: 0.1136036	total: 5.67s	remaining: 480ms
# 922:	learn: 0.1135550	total: 5.68s	remaining: 474ms
# 923:	learn: 0.1135146	total: 5.68s	remaining: 467ms
# 924:	learn: 0.1134390	total: 5.68s	remaining: 461ms
# 925:	learn: 0.1133578	total: 5.69s	remaining: 455ms
# 926:	learn: 0.1133156	total: 5.69s	remaining: 448ms
# 927:	learn: 0.1132632	total: 5.7s	remaining: 442ms
# 928:	learn: 0.1132182	total: 5.7s	remaining: 436ms
# 929:	learn: 0.1131303	total: 5.7s	remaining: 429ms
# 930:	learn: 0.1130572	total: 5.71s	remaining: 423ms
# 931:	learn: 0.1130147	total: 5.71s	remaining: 417ms
# 932:	learn: 0.1129578	total: 5.71s	remaining: 410ms
# 933:	learn: 0.1129214	total: 5.72s	remaining: 404ms
# 934:	learn: 0.1128752	total: 5.72s	remaining: 398ms
# ...
# 696:	learn: 0.1260725	total: 2.72s	remaining: 1.18s
# 697:	learn: 0.1260078	total: 2.72s	remaining: 1.18s
# 698:	learn: 0.1259567	total: 2.73s	remaining: 1.17s
# 699:	learn: 0.1258729	total: 2.73s	remaining: 1.17s
# 700:	learn: 0.1258137	total: 2.73s	remaining: 1.17s
# 701:	learn: 0.1257331	total: 2.74s	remaining: 1.16s
# 702:	learn: 0.1256648	total: 2.74s	remaining: 1.16s
# 703:	learn: 0.1255751	total: 2.75s	remaining: 1.15s
# 704:	learn: 0.1255062	total: 2.75s	remaining: 1.15s
# 705:	learn: 0.1254605	total: 2.75s	remaining: 1.15s
# 706:	learn: 0.1253783	total: 2.76s	remaining: 1.14s
# 707:	learn: 0.1253264	total: 2.76s	remaining: 1.14s
# 708:	learn: 0.1252802	total: 2.76s	remaining: 1.13s
# 709:	learn: 0.1252369	total: 2.77s	remaining: 1.13s
# 710:	learn: 0.1251628	total: 2.77s	remaining: 1.13s
# 711:	learn: 0.1250433	total: 2.77s	remaining: 1.12s
# 712:	learn: 0.1249866	total: 2.78s	remaining: 1.12s
# 713:	learn: 0.1249019	total: 2.78s	remaining: 1.11s
# 714:	learn: 0.1247772	total: 2.79s	remaining: 1.11s
# 715:	learn: 0.1247135	total: 2.79s	remaining: 1.11s
# 716:	learn: 0.1246649	total: 2.79s	remaining: 1.1s
# 717:	learn: 0.1246010	total: 2.8s	remaining: 1.1s
# 718:	learn: 0.1245060	total: 2.8s	remaining: 1.09s
# 719:	learn: 0.1244729	total: 2.8s	remaining: 1.09s
# 720:	learn: 0.1243832	total: 2.81s	remaining: 1.09s
# 721:	learn: 0.1243310	total: 2.82s	remaining: 1.08s
# 722:	learn: 0.1242625	total: 2.82s	remaining: 1.08s
# 723:	learn: 0.1241800	total: 2.82s	remaining: 1.08s
# 724:	learn: 0.1241047	total: 2.83s	remaining: 1.07s
# 725:	learn: 0.1240211	total: 2.83s	remaining: 1.07s
# 726:	learn: 0.1239168	total: 2.83s	remaining: 1.06s
# 727:	learn: 0.1238648	total: 2.84s	remaining: 1.06s
# 728:	learn: 0.1238019	total: 2.85s	remaining: 1.06s
# 729:	learn: 0.1237186	total: 2.85s	remaining: 1.05s
# 730:	learn: 0.1236391	total: 2.85s	remaining: 1.05s
# 731:	learn: 0.1235417	total: 2.86s	remaining: 1.05s
# 732:	learn: 0.1234342	total: 2.86s	remaining: 1.04s
# 733:	learn: 0.1233802	total: 2.87s	remaining: 1.04s
# 734:	learn: 0.1232890	total: 2.87s	remaining: 1.03s
# 735:	learn: 0.1232440	total: 2.87s	remaining: 1.03s
# 736:	learn: 0.1231924	total: 2.88s	remaining: 1.03s
# 737:	learn: 0.1231580	total: 2.88s	remaining: 1.02s
# 738:	learn: 0.1231044	total: 2.88s	remaining: 1.02s
# 739:	learn: 0.1230240	total: 2.89s	remaining: 1.01s
# 740:	learn: 0.1229311	total: 2.89s	remaining: 1.01s
# 741:	learn: 0.1228251	total: 2.9s	remaining: 1.01s
# 742:	learn: 0.1227399	total: 2.9s	remaining: 1s
# 743:	learn: 0.1226861	total: 2.9s	remaining: 999ms
# 744:	learn: 0.1226087	total: 2.91s	remaining: 995ms
# 745:	learn: 0.1225356	total: 2.91s	remaining: 991ms
# 746:	learn: 0.1224620	total: 2.91s	remaining: 987ms
# 747:	learn: 0.1224077	total: 2.92s	remaining: 983ms
# 748:	learn: 0.1223483	total: 2.92s	remaining: 979ms
# 749:	learn: 0.1222912	total: 2.92s	remaining: 975ms
# 750:	learn: 0.1222564	total: 2.93s	remaining: 971ms
# 751:	learn: 0.1222059	total: 2.93s	remaining: 967ms
# 752:	learn: 0.1221379	total: 2.94s	remaining: 963ms
# 753:	learn: 0.1220751	total: 2.94s	remaining: 959ms
# 754:	learn: 0.1219925	total: 2.94s	remaining: 955ms
# 755:	learn: 0.1219548	total: 2.95s	remaining: 951ms
# 756:	learn: 0.1218968	total: 2.95s	remaining: 947ms
# 757:	learn: 0.1218118	total: 2.95s	remaining: 943ms
# 758:	learn: 0.1217492	total: 2.96s	remaining: 939ms
# 759:	learn: 0.1217053	total: 2.96s	remaining: 936ms
# 760:	learn: 0.1215982	total: 2.97s	remaining: 932ms
# 761:	learn: 0.1215117	total: 2.97s	remaining: 928ms
# 762:	learn: 0.1213923	total: 2.97s	remaining: 924ms
# 763:	learn: 0.1213219	total: 2.98s	remaining: 920ms
# 764:	learn: 0.1212514	total: 2.98s	remaining: 916ms
# 765:	learn: 0.1211445	total: 2.98s	remaining: 912ms
# 766:	learn: 0.1210706	total: 2.99s	remaining: 908ms
# 767:	learn: 0.1209963	total: 2.99s	remaining: 904ms
# 768:	learn: 0.1209604	total: 3s	remaining: 900ms
# 769:	learn: 0.1209027	total: 3s	remaining: 896ms
# 770:	learn: 0.1208583	total: 3s	remaining: 892ms
# 771:	learn: 0.1207879	total: 3.01s	remaining: 888ms
# 772:	learn: 0.1207614	total: 3.01s	remaining: 884ms
# 773:	learn: 0.1206332	total: 3.01s	remaining: 880ms
# 774:	learn: 0.1205543	total: 3.02s	remaining: 876ms
# 775:	learn: 0.1204837	total: 3.02s	remaining: 872ms
# 776:	learn: 0.1204241	total: 3.02s	remaining: 868ms
# 777:	learn: 0.1203471	total: 3.03s	remaining: 864ms
# 778:	learn: 0.1202740	total: 3.03s	remaining: 861ms
# 779:	learn: 0.1201963	total: 3.04s	remaining: 857ms
# 780:	learn: 0.1201082	total: 3.04s	remaining: 854ms
# 781:	learn: 0.1200398	total: 3.05s	remaining: 851ms
# 782:	learn: 0.1199745	total: 3.06s	remaining: 847ms
# 783:	learn: 0.1198908	total: 3.06s	remaining: 843ms
# 784:	learn: 0.1198267	total: 3.06s	remaining: 839ms
# 785:	learn: 0.1197408	total: 3.07s	remaining: 835ms
# 786:	learn: 0.1196636	total: 3.07s	remaining: 831ms
# 787:	learn: 0.1195778	total: 3.08s	remaining: 827ms
# 788:	learn: 0.1195187	total: 3.08s	remaining: 823ms
# 789:	learn: 0.1194504	total: 3.08s	remaining: 820ms
# 790:	learn: 0.1193952	total: 3.09s	remaining: 816ms
# 791:	learn: 0.1193349	total: 3.09s	remaining: 812ms
# 792:	learn: 0.1192730	total: 3.09s	remaining: 808ms
# 793:	learn: 0.1192184	total: 3.1s	remaining: 804ms
# 794:	learn: 0.1191729	total: 3.1s	remaining: 800ms
# 795:	learn: 0.1191250	total: 3.1s	remaining: 796ms
# 796:	learn: 0.1190845	total: 3.11s	remaining: 792ms
# 797:	learn: 0.1190275	total: 3.11s	remaining: 788ms
# 798:	learn: 0.1189621	total: 3.12s	remaining: 784ms
# 799:	learn: 0.1189009	total: 3.12s	remaining: 780ms
# 800:	learn: 0.1188071	total: 3.12s	remaining: 776ms
# 801:	learn: 0.1187532	total: 3.13s	remaining: 772ms
# 802:	learn: 0.1186790	total: 3.13s	remaining: 768ms
# 803:	learn: 0.1186035	total: 3.13s	remaining: 764ms
# 804:	learn: 0.1185227	total: 3.14s	remaining: 760ms
# 805:	learn: 0.1184522	total: 3.14s	remaining: 756ms
# 806:	learn: 0.1183777	total: 3.15s	remaining: 752ms
# 807:	learn: 0.1183038	total: 3.15s	remaining: 748ms
# 808:	learn: 0.1182290	total: 3.15s	remaining: 744ms
# 809:	learn: 0.1181359	total: 3.16s	remaining: 741ms
# 810:	learn: 0.1180560	total: 3.16s	remaining: 737ms
# 811:	learn: 0.1179697	total: 3.16s	remaining: 733ms
# 812:	learn: 0.1179139	total: 3.17s	remaining: 729ms
# 813:	learn: 0.1178167	total: 3.17s	remaining: 725ms
# 814:	learn: 0.1177392	total: 3.17s	remaining: 721ms
# 815:	learn: 0.1176803	total: 3.18s	remaining: 717ms
# 816:	learn: 0.1176371	total: 3.18s	remaining: 713ms
# 817:	learn: 0.1175485	total: 3.19s	remaining: 709ms
# 818:	learn: 0.1174940	total: 3.19s	remaining: 705ms
# 819:	learn: 0.1173921	total: 3.19s	remaining: 701ms
# 820:	learn: 0.1173330	total: 3.2s	remaining: 697ms
# 821:	learn: 0.1172729	total: 3.2s	remaining: 693ms
# 822:	learn: 0.1172168	total: 3.2s	remaining: 689ms
# 823:	learn: 0.1171554	total: 3.21s	remaining: 685ms
# 824:	learn: 0.1170814	total: 3.21s	remaining: 681ms
# 825:	learn: 0.1169697	total: 3.21s	remaining: 677ms
# 826:	learn: 0.1169120	total: 3.22s	remaining: 673ms
# 827:	learn: 0.1168447	total: 3.22s	remaining: 670ms
# 828:	learn: 0.1167823	total: 3.23s	remaining: 666ms
# 829:	learn: 0.1167146	total: 3.23s	remaining: 662ms
# 830:	learn: 0.1166487	total: 3.23s	remaining: 658ms
# 831:	learn: 0.1165565	total: 3.24s	remaining: 654ms
# 832:	learn: 0.1164976	total: 3.25s	remaining: 652ms
# 833:	learn: 0.1164696	total: 3.25s	remaining: 648ms
# 834:	learn: 0.1163866	total: 3.26s	remaining: 644ms
# 835:	learn: 0.1163366	total: 3.26s	remaining: 640ms
# 836:	learn: 0.1162603	total: 3.27s	remaining: 636ms
# 837:	learn: 0.1161753	total: 3.27s	remaining: 632ms
# 838:	learn: 0.1161140	total: 3.27s	remaining: 628ms
# 839:	learn: 0.1160756	total: 3.28s	remaining: 624ms
# 840:	learn: 0.1160483	total: 3.28s	remaining: 620ms
# 841:	learn: 0.1160033	total: 3.28s	remaining: 616ms
# 842:	learn: 0.1159326	total: 3.29s	remaining: 612ms
# 843:	learn: 0.1159000	total: 3.29s	remaining: 608ms
# 844:	learn: 0.1158308	total: 3.29s	remaining: 604ms
# 845:	learn: 0.1157932	total: 3.3s	remaining: 601ms
# 846:	learn: 0.1157433	total: 3.3s	remaining: 597ms
# 847:	learn: 0.1156498	total: 3.31s	remaining: 593ms
# 848:	learn: 0.1155754	total: 3.31s	remaining: 589ms
# 849:	learn: 0.1155353	total: 3.31s	remaining: 585ms
# 850:	learn: 0.1154599	total: 3.32s	remaining: 581ms
# 851:	learn: 0.1153694	total: 3.32s	remaining: 577ms
# 852:	learn: 0.1153122	total: 3.32s	remaining: 573ms
# 853:	learn: 0.1152384	total: 3.33s	remaining: 569ms
# 854:	learn: 0.1151807	total: 3.33s	remaining: 565ms
# 855:	learn: 0.1151334	total: 3.33s	remaining: 561ms
# 856:	learn: 0.1150781	total: 3.34s	remaining: 557ms
# 857:	learn: 0.1150090	total: 3.34s	remaining: 553ms
# 858:	learn: 0.1149731	total: 3.35s	remaining: 549ms
# 859:	learn: 0.1148968	total: 3.35s	remaining: 545ms
# 860:	learn: 0.1148471	total: 3.35s	remaining: 541ms
# 861:	learn: 0.1147999	total: 3.36s	remaining: 537ms
# 862:	learn: 0.1147346	total: 3.36s	remaining: 534ms
# 863:	learn: 0.1146596	total: 3.37s	remaining: 530ms
# 864:	learn: 0.1146100	total: 3.37s	remaining: 526ms
# 865:	learn: 0.1145738	total: 3.37s	remaining: 522ms
# 866:	learn: 0.1145160	total: 3.38s	remaining: 518ms
# 867:	learn: 0.1144545	total: 3.38s	remaining: 514ms
# 868:	learn: 0.1143922	total: 3.38s	remaining: 510ms
# 869:	learn: 0.1143255	total: 3.39s	remaining: 506ms
# 870:	learn: 0.1142576	total: 3.39s	remaining: 503ms
# 871:	learn: 0.1141650	total: 3.4s	remaining: 499ms
# 872:	learn: 0.1140761	total: 3.4s	remaining: 495ms
# 873:	learn: 0.1139815	total: 3.4s	remaining: 491ms
# 874:	learn: 0.1139429	total: 3.41s	remaining: 487ms
# 875:	learn: 0.1138741	total: 3.41s	remaining: 483ms
# 876:	learn: 0.1138234	total: 3.41s	remaining: 479ms
# 877:	learn: 0.1137805	total: 3.42s	remaining: 475ms
# 878:	learn: 0.1137404	total: 3.42s	remaining: 471ms
# 879:	learn: 0.1136896	total: 3.43s	remaining: 468ms
# 880:	learn: 0.1136277	total: 3.44s	remaining: 464ms
# 881:	learn: 0.1135472	total: 3.45s	remaining: 462ms
# 882:	learn: 0.1134533	total: 3.46s	remaining: 458ms
# 883:	learn: 0.1133319	total: 3.46s	remaining: 454ms
# 884:	learn: 0.1132674	total: 3.46s	remaining: 450ms
# 885:	learn: 0.1131933	total: 3.47s	remaining: 446ms
# 886:	learn: 0.1131181	total: 3.47s	remaining: 443ms
# 887:	learn: 0.1130539	total: 3.48s	remaining: 439ms
# 888:	learn: 0.1130053	total: 3.48s	remaining: 435ms
# 889:	learn: 0.1129641	total: 3.48s	remaining: 431ms
# 890:	learn: 0.1129065	total: 3.49s	remaining: 427ms
# 891:	learn: 0.1128435	total: 3.49s	remaining: 423ms
# 892:	learn: 0.1127787	total: 3.5s	remaining: 419ms
# 893:	learn: 0.1127278	total: 3.5s	remaining: 415ms
# 894:	learn: 0.1126549	total: 3.5s	remaining: 411ms
# 895:	learn: 0.1125882	total: 3.51s	remaining: 407ms
# 896:	learn: 0.1124762	total: 3.51s	remaining: 403ms
# 897:	learn: 0.1124181	total: 3.51s	remaining: 399ms
# 898:	learn: 0.1123388	total: 3.52s	remaining: 395ms
# 899:	learn: 0.1122896	total: 3.52s	remaining: 391ms
# 900:	learn: 0.1122430	total: 3.52s	remaining: 387ms
# 901:	learn: 0.1121863	total: 3.53s	remaining: 383ms
# 902:	learn: 0.1121254	total: 3.53s	remaining: 379ms
# 903:	learn: 0.1120840	total: 3.54s	remaining: 375ms
# 904:	learn: 0.1120511	total: 3.54s	remaining: 372ms
# 905:	learn: 0.1119739	total: 3.54s	remaining: 368ms
# 906:	learn: 0.1119138	total: 3.55s	remaining: 364ms
# 907:	learn: 0.1118535	total: 3.55s	remaining: 360ms
# 908:	learn: 0.1117854	total: 3.56s	remaining: 356ms
# 909:	learn: 0.1117365	total: 3.56s	remaining: 352ms
# 910:	learn: 0.1116801	total: 3.56s	remaining: 348ms
# 911:	learn: 0.1115938	total: 3.57s	remaining: 344ms
# 912:	learn: 0.1115166	total: 3.57s	remaining: 340ms
# 913:	learn: 0.1114588	total: 3.57s	remaining: 336ms
# 914:	learn: 0.1114062	total: 3.58s	remaining: 332ms
# 915:	learn: 0.1113275	total: 3.58s	remaining: 328ms
# 916:	learn: 0.1112667	total: 3.58s	remaining: 325ms
# 917:	learn: 0.1112149	total: 3.59s	remaining: 321ms
# 918:	learn: 0.1111680	total: 3.59s	remaining: 317ms
# 919:	learn: 0.1111095	total: 3.6s	remaining: 313ms
# 920:	learn: 0.1110725	total: 3.6s	remaining: 309ms
# 921:	learn: 0.1110267	total: 3.6s	remaining: 305ms
# 922:	learn: 0.1109661	total: 3.61s	remaining: 301ms
# 923:	learn: 0.1108900	total: 3.61s	remaining: 297ms
# 924:	learn: 0.1108519	total: 3.61s	remaining: 293ms
# 925:	learn: 0.1107970	total: 3.62s	remaining: 289ms
# 926:	learn: 0.1107296	total: 3.62s	remaining: 285ms
# 927:	learn: 0.1106894	total: 3.63s	remaining: 281ms
# 928:	learn: 0.1106119	total: 3.63s	remaining: 277ms
# 929:	learn: 0.1105432	total: 3.63s	remaining: 273ms
# 930:	learn: 0.1105119	total: 3.64s	remaining: 270ms
# 931:	learn: 0.1104561	total: 3.64s	remaining: 266ms
# 932:	learn: 0.1104116	total: 3.64s	remaining: 262ms
# 933:	learn: 0.1103592	total: 3.65s	remaining: 258ms
# 934:	learn: 0.1102774	total: 3.66s	remaining: 254ms
# 935:	learn: 0.1102254	total: 3.66s	remaining: 250ms
# 936:	learn: 0.1101565	total: 3.67s	remaining: 247ms
# 937:	learn: 0.1101058	total: 3.67s	remaining: 243ms
# 938:	learn: 0.1100288	total: 3.67s	remaining: 239ms
# 939:	learn: 0.1099483	total: 3.68s	remaining: 235ms
# 940:	learn: 0.1099158	total: 3.68s	remaining: 231ms
# 941:	learn: 0.1098540	total: 3.69s	remaining: 227ms
# 942:	learn: 0.1097625	total: 3.69s	remaining: 223ms
# 943:	learn: 0.1097013	total: 3.69s	remaining: 219ms
# 944:	learn: 0.1096594	total: 3.7s	remaining: 215ms
# 945:	learn: 0.1095763	total: 3.7s	remaining: 211ms
# 946:	learn: 0.1095153	total: 3.7s	remaining: 207ms
# 947:	learn: 0.1094854	total: 3.71s	remaining: 203ms
# 948:	learn: 0.1094136	total: 3.71s	remaining: 199ms
# 949:	learn: 0.1093402	total: 3.71s	remaining: 195ms
# 950:	learn: 0.1092734	total: 3.72s	remaining: 192ms
# 951:	learn: 0.1092166	total: 3.72s	remaining: 188ms
# 952:	learn: 0.1091672	total: 3.73s	remaining: 184ms
# 953:	learn: 0.1091137	total: 3.73s	remaining: 180ms
# 954:	learn: 0.1090554	total: 3.73s	remaining: 176ms
# 955:	learn: 0.1090074	total: 3.74s	remaining: 172ms
# 956:	learn: 0.1089473	total: 3.74s	remaining: 168ms
# 957:	learn: 0.1088796	total: 3.74s	remaining: 164ms
# 958:	learn: 0.1088035	total: 3.75s	remaining: 160ms
# 959:	learn: 0.1087101	total: 3.75s	remaining: 156ms
# 960:	learn: 0.1086747	total: 3.75s	remaining: 152ms
# 961:	learn: 0.1086150	total: 3.76s	remaining: 148ms
# 962:	learn: 0.1085901	total: 3.76s	remaining: 145ms
# 963:	learn: 0.1085256	total: 3.77s	remaining: 141ms
# 964:	learn: 0.1084655	total: 3.77s	remaining: 137ms
# 965:	learn: 0.1084019	total: 3.77s	remaining: 133ms
# 966:	learn: 0.1083645	total: 3.78s	remaining: 129ms
# 967:	learn: 0.1083048	total: 3.78s	remaining: 125ms
# 968:	learn: 0.1082378	total: 3.79s	remaining: 121ms
# 969:	learn: 0.1081995	total: 3.79s	remaining: 117ms
# 970:	learn: 0.1081639	total: 3.79s	remaining: 113ms
# 971:	learn: 0.1081229	total: 3.8s	remaining: 109ms
# 972:	learn: 0.1080623	total: 3.8s	remaining: 105ms
# 973:	learn: 0.1079996	total: 3.8s	remaining: 102ms
# 974:	learn: 0.1079340	total: 3.81s	remaining: 97.7ms
# 975:	learn: 0.1078902	total: 3.81s	remaining: 93.7ms
# 976:	learn: 0.1077798	total: 3.81s	remaining: 89.8ms
# 977:	learn: 0.1077227	total: 3.82s	remaining: 85.9ms
# 978:	learn: 0.1076544	total: 3.82s	remaining: 82ms
# 979:	learn: 0.1076023	total: 3.83s	remaining: 78.1ms
# 980:	learn: 0.1075694	total: 3.83s	remaining: 74.2ms
# 981:	learn: 0.1075360	total: 3.83s	remaining: 70.3ms
# 982:	learn: 0.1074768	total: 3.84s	remaining: 66.4ms
# 983:	learn: 0.1074248	total: 3.84s	remaining: 62.5ms
# 984:	learn: 0.1073597	total: 3.85s	remaining: 58.6ms
# 985:	learn: 0.1073147	total: 3.85s	remaining: 54.7ms
# 986:	learn: 0.1072736	total: 3.86s	remaining: 50.8ms
# 987:	learn: 0.1071969	total: 3.86s	remaining: 46.9ms
# 988:	learn: 0.1071219	total: 3.87s	remaining: 43ms
# 989:	learn: 0.1070723	total: 3.87s	remaining: 39.1ms
# 990:	learn: 0.1070372	total: 3.87s	remaining: 35.2ms
# 991:	learn: 0.1069639	total: 3.88s	remaining: 31.3ms
# 992:	learn: 0.1068859	total: 3.88s	remaining: 27.4ms
# 993:	learn: 0.1067999	total: 3.88s	remaining: 23.4ms
# 994:	learn: 0.1067162	total: 3.89s	remaining: 19.5ms
# 995:	learn: 0.1066455	total: 3.89s	remaining: 15.6ms
# 996:	learn: 0.1065893	total: 3.9s	remaining: 11.7ms
# 997:	learn: 0.1065178	total: 3.9s	remaining: 7.81ms
# 998:	learn: 0.1064643	total: 3.9s	remaining: 3.91ms
# 999:	learn: 0.1064255	total: 3.9s	remaining: 0us
# Scores: [0.21424799 0.20330259 0.20599935 0.19143575 0.21066836 0.19460349
#  0.20038732 0.20320058 0.207114   0.20316051]
# Mean: 0.2034119926526198
# Standard deviation: 0.006486612422206783

# %%
plot_predictions(validation_set_cp, Catboost_model)

# %%
plot_distribution(validation_set_cp, Catboost_model)

# %% [markdown]
# ## **Modelo Linear Regression**

# %% [markdown]
# ### Treino:

# %%
LinearRegression_model = train_model(train_set_cp, 'linear_regression', {})

# %% [markdown]
# ### Validação:

# %%
# SEM VALIDAÇÃO CRUZADA -> Usando o conjunto de validação
evaluate_model_performance(validation_set_cp, LinearRegression_model)
# Out:
# MAE: 0.16760550961716167
# MSE: 0.05048734722789241
# RMSE: 0.22469389673040166
# R²: 0.11872728689641998
# Predições do modelo:
# [0.41944786 0.77267427 0.41992574 ... 0.42716693 0.54539808 0.66666387]

# %%
# COM VALIDAÇÃO CRUZADA -> Usando o conjunto de validação
cross_validation(validation_set_cp, LinearRegression_model)
# Out:
# Scores: [0.21845148 0.21136824 0.21301916 0.18810765 0.20817964 0.19818934
#  0.2068024  0.20648184 0.21336711 0.2162475 ]
# Mean: 0.2080214359879875
# Standard deviation: 0.00859254703152334

# %%
# Visualizando dados: Previsão X Dados verdadeiros
plot_predictions(validation_set_cp, LinearRegression_model)

# %%
plot_distribution(validation_set_cp, LinearRegression_model)

# %% [markdown]
# ## **Modelo SVM**

# %%
SVM_model = train_model(train_set_cp, 'svm', {})

# %%
evaluate_model_performance(validation_set_cp, SVM_model)
# Out:
# MAE: 0.16591846355207843
# MSE: 0.04949093714619228
# RMSE: 0.22246558643123274
# R²: 0.13611994197294797
# Predições do modelo:
# [0.40098469 0.82354557 0.3721733  ... 0.31169844 0.58568354 0.7153788 ]

# %%
cross_validation(validation_set_cp, SVM_model)
# Out:
# Scores: [0.21833362 0.21079351 0.21002066 0.19663685 0.21340101 0.20167169
#  0.20877575 0.20711459 0.21371625 0.21659298]
# Mean: 0.2097056908841166
# Standard deviation: 0.006291397707757309

# %%
plot_predictions(validation_set_cp, SVM_model)

# %%
# feature_importance(train_set_cp, SVM_model)

# %% [markdown]
# # **AJUSTE DE HIPERPARÂMETROS**

# %%
X, y = split_target_features(train_set_cp)
X_val, y_val = split_target_features(validation_set_cp)

# Definir o modelo de regressão Ridge
ridge_model = Ridge()

# Definir a distribuição de alpha para testar
param_dist = {'alpha': np.logspace(-6, 6, 13),
              'fit_intercept': [True, False],
              'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'saga'],
              'max_iter': [1000, 5000],
              'tol': [1e-4, 1e-3]}  # valores logaritmicamente espaçados entre 10^-6 e 10^6

# Configurar o RandomizedSearchCV com 5-fold cross-validation
random_search = RandomizedSearchCV(estimator=ridge_model, param_distributions=param_dist, n_iter=100, cv=5, random_state=42)

# Treinar o modelo
random_search.fit(X, y)

# Mostrar os melhores parâmetros encontrados
print("Melhor valor de alpha:", random_search.best_params_)

# Avaliar o modelo no conjunto de teste
print("R² no teste:", random_search.score(X_val, y_val))
# Out:
# Melhor valor de alpha: {'tol': 0.001, 'solver': 'saga', 'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0}
# R² no teste: 0.11941223605065976

# %%
lgb_model = lgb.LGBMRegressor()

# Definir os parâmetros para testar
param_dist = {
    'learning_rate': np.logspace(-3, 0, 4),  # Valores de taxa de aprendizado em escala log
    'n_estimators': [50, 100, 200, 500],
    'max_depth': [3, 5, 7, 10],
    'num_leaves': [31, 50, 100, 200],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'min_child_samples': [20, 50, 100],
    'lambda_l1': [0, 1, 5],
    'lambda_l2': [0, 1, 5]
}

# Configurar o RandomizedSearchCV com 5-fold cross-validation
random_search = RandomizedSearchCV(estimator=lgb_model, param_distributions=param_dist, n_iter=50, cv=5)

# Treinar o modelo
random_search.fit(X, y)

# Mostrar os melhores parâmetros encontrados
print("Melhores parâmetros:", random_search.best_params_)

# Avaliar o modelo no conjunto de teste
print("R² no teste:", random_search.score(X_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-640-5ee6c87a647b> in <cell line: 0>()
#      18
#      19 # Treinar o modelo
# ---> 20 random_search.fit(X, y)
#      21
#      22 # Mostrar os melhores parâmetros encontrados
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
#    1026             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1949     def _run_search(self, evaluate_candidates):
#    1950         """Search n_iter candidates from param_distributions"""
# -> 1951         evaluate_candidates(
#    1952             ParameterSampler(
#    1953                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     968                     )
#     969
# --> 970                 out = parallel(
#     971                     delayed(_fit_and_score)(
#     972                         clone(base_estimator),
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#     140
#     141
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864             estimator.fit(X_train, **fit_params)
#     865         else:
# --> 866             estimator.fit(X_train, y_train, **fit_params)
#     867
#     868     except Exception:
#
# /usr/local/lib/python3.11/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1187     ) -> "LGBMRegressor":
#    1188         """Docstring is inherited from the LGBMModel."""
# -> 1189         super().fit(
#    1190             X,
#    1191             y,
#
# /usr/local/lib/python3.11/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     953         callbacks.append(record_evaluation(evals_result))
#     954
# --> 955         self._Booster = train(
#     956             params=params,
#     957             train_set=train_set,
#
# /usr/local/lib/python3.11/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     305             )
#     306
# --> 307         booster.update(fobj=fobj)
#     308
#     309         evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#
# /usr/local/lib/python3.11/dist-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    4134                 raise LightGBMError("Cannot update due to null objective function.")
#    4135             _safe_call(
# -> 4136                 _LIB.LGBM_BoosterUpdateOneIter(
#    4137                     self._handle,
#    4138                     ctypes.byref(is_finished),
#
# KeyboardInterrupt:

# %% [markdown]
# # **Ensemble**

# %%
from sklearn.ensemble import VotingRegressor

voting_regressor = VotingRegressor(
    estimators=[
        ('ridge', Ridge_model),
        ('svm', SVM_model),
        ('linear', LinearRegression_model),
        ('lgbm', LightGBM_model)
    ]
)

X_train, y_train = split_target_features(train_set_cp)
X_test, y_test = split_target_features(test_set_cp)

voting_regressor.fit(X_train, y_train)

y_pred_voting = voting_regressor.predict(X_test)

# %%
evaluate_model_performance(test_set_cp, voting_regressor)
# Out:
# MAE: 0.16754376616943542
# MSE: 0.049419218963913526
# RMSE: 0.22230433860793974
# R²: 0.10807069589474494
# Predições do modelo:
# [0.89875832 0.47110028 0.52741795 ... 0.38731687 0.13577044 0.74780036]

# %%
cross_validation(test_set_cp, voting_regressor)
# Out:
# Scores: [0.19831326 0.19983828 0.2023685  0.19243193 0.19926533 0.20200825
#  0.20018332 0.19825126 0.18900373 0.20353875]
# Mean: 0.19852026197885314
# Standard deviation: 0.004300763699637546

# %%
plot_predictions(test_set_cp, voting_regressor)

# %%
plot_distribution(test_set_cp, voting_regressor)

# %%
# Separando as Features e Target no Conjunto de Teste
X_test, y_test = split_target_features(test_set_cp)

# Lista de Modelos a Serem Avaliados
models = {
    'Voting Regressor (Ensemble)': voting_regressor
}

# Avaliação dos Modelos no Conjunto de Teste
for model_name, model in models.items():
    evaluate_model_performance(test_set_cp, model)

    # Visualização dos Resultados
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Gráfico de Previsões x Valores Reais
    plot_predictions(test_set_cp, model, ax=axes[0])

    # Distribuição dos Valores Reais x Predições
    plot_distribution(test_set_cp, model, ax=axes[1])

    # Distribuição dos Erros
    plot_error(test_set_cp, model, ax=axes[2])

    plt.tight_layout()
    plt.show()
# Out:
# MAE: 0.16754376616943542
# MSE: 0.049419218963913526
# RMSE: 0.22230433860793974
# R²: 0.10807069589474494
# Predições do modelo:
# [0.89875832 0.47110028 0.52741795 ... 0.38731687 0.13577044 0.74780036]
